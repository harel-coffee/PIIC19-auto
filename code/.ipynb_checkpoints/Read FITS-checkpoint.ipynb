# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import os, sys

dirpath = os.getcwd().split("code")[0]+"code/"
sys.path.append(dirpath)
from pre_process import clean_LC

folder = "../KOI_Data/sample/"

# %%
import os

fits_available = os.listdir(folder)
fits_available[:3]
# Out:
# ['kplr001025986-20160128150956_dvt.fits',
#  'kplr001026032-20160128150956_dvt.fits',
#  'kplr001293046-20160128150956_dvt.fits']

# %%
hdulist = fits.open(folder+fits_available[5])

hdulist.info()
# Out:
# Filename: ../KOI_Data/sample/kplr001432214-20160128150956_dvt.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      56   ()
#   1  TCE_1         1 BinTableHDU    106   71427R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   2  TCE_2         1 BinTableHDU    106   71427R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   3  Statistics    1 BinTableHDU    221   71427R x 50C   [D, E, J, E, E, E, E, J, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
hdulist[1].header
# Out:
# XTENSION= 'BINTABLE'           / marks the beginning of a new HDU
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   44 / length of first array dimension
# NAXIS2  =                71427 / length of second array dimension
# PCOUNT  =                    0 / group parameter count (not used)
# GCOUNT  =                    1 / group count (not used)
# TFIELDS =                   10 / number of table fields
# TTYPE1  = 'TIME    '           / column title: data time stamps
# TFORM1  = 'D       '           / column format: 64-bit floating point
# TUNIT1  = 'BJD - 2454833'      / column units: barycenter corrected JD
# TDISP1  = 'D14.7   '           / column display format
# TTYPE2  = 'TIMECORR'           / column title: Barycenter correction applied to
# TFORM2  = 'E       '           / column format: 32-bit floating point
# TUNIT2  = 'd       '           / column units: day
# TDISP2  = 'E13.6   '           / column display format
# TTYPE3  = 'CADENCENO'          / column title: unique cadence number
# TFORM3  = 'J       '           / column format: signed 32-bit integer
# TDISP3  = 'I10     '           / column display format
# TTYPE4  = 'PHASE   '           / column title: Phase using period and epoch
# TFORM4  = 'E       '           / column format: 32-bit floating point
# TUNIT4  = 'days    '           / column units: [-0.25*period, 0.75*period]
# TDISP4  = 'E14.7   '           / column display format
# TTYPE5  = 'LC_INIT '           / column title: Quarter stitched initial light cu
# TFORM5  = 'E       '           / column format: 32-bit floating point
# TUNIT5  = 'dimensionless'      / column units: null
# TDISP5  = 'E14.7   '           / column display format
# TTYPE6  = 'LC_INIT_ERR'        / column title: Error in the LC_INIT (gapped)
# TFORM6  = 'E       '           / column format: 32-bit floating point
# TUNIT6  = 'dimensionless'      / column units: null
# TDISP6  = 'E14.7   '           / column display format
# TTYPE7  = 'LC_WHITE'           / column title: Initial whitened time series fit
# TFORM7  = 'E       '           / column format: 32-bit floating point
# TUNIT7  = 'dimensionless'      / column units: null
# TDISP7  = 'E14.7   '           / column display format
# TTYPE8  = 'LC_DETREND'         / column title: Initial median detrended time ser
# TFORM8  = 'E       '           / column format: 32-bit floating point
# TUNIT8  = 'dimensionless'      / column units: null
# TDISP8  = 'E14.7   '           / column display format
# TTYPE9  = 'MODEL_INIT'         / column title: Model light curve
# TFORM9  = 'E       '           / column format: 32-bit floating point
# TUNIT9  = 'dimensionless'      / column units: null
# TDISP9  = 'E14.7   '           / column display format
# TTYPE10 = 'MODEL_WHITE'        / column title: Whitened model light curve
# TFORM10 = 'E       '           / column format: 32-bit floating point
# TUNIT10 = 'dimensionless'      / column units: null
# TDISP10 = 'E14.7   '           / column display format
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'TCE_1   '           / name of extension
# EXTVER  =                    1 / extension version number (not format version)
# TELESCOP= 'Kepler  '           / telescope
# INSTRUME= 'Kepler Photometer'  / detector type
# OBJECT  = 'KIC 1293046'        / string version of target id
# KEPLERID=              1293046 / unique Kepler target identifier
# RADESYS = 'ICRS    '           / reference frame of celestial coordinates
# RA_OBJ  =           291.026550 / [deg] right ascension
# DEC_OBJ =            36.916370 / [deg] declination
# EQUINOX =               2000.0 / equinox of celestial coordinate system
# EXPOSURE=        1303.40141748 / [d] time on source
# TIMEREF = 'SOLARSYSTEM'        / barycentric correction applied to times
# TASSIGN = 'SPACECRAFT'         / where time is assigned
# TIMESYS = 'TDB     '           / time system is barycentric JD
# BJDREFI =              2454833 / integer part of BJD reference date
# BJDREFF =           0.00000000 / fraction of the day in BJD reference date
# TIMEUNIT= 'd       '           / time unit for TIME, TSTART and TSTOP
# TELAPSE =        1459.51194243 / [d] TSTOP - TSTART
# LIVETIME=        1343.67766128 / [d] TELAPSE multiplied by DEADC
# TSTART  =         131.49906623 / observation start time in BJD-BJDREF
# TSTOP   =        1591.01100866 / observation stop time in BJD-BJDREF
# LC_START=       54964.01099382 / mid point of first cadence in MJD
# LC_END  =       56423.50115222 / mid point of last cadence in MJD
# DEADC   =           0.92063492 / deadtime correction
# TIMEPIXR=                  0.5 / bin time beginning=0 middle=0.5 end=1
# TIERRELA=             5.78E-07 / [d] relative time error
# TIERABSO=                      / [d] absolute time error
# INT_TIME=       6.019802903270 / [s] photon accumulation time per frame
# READTIME=       0.518948526144 / [s] readout time per frame
# FRAMETIM=       6.538751429414 / [s] frame time (INT_TIME + READTIME)
# NUM_FRM =                  270 / number of frames per time stamp
# TIMEDEL =     0.02043359821692 / [d] time resolution of data
# DATE-OBS= '2009-05-13T00:01:07.136Z' / TSTART as UTC calendar date
# DATE-END= '2013-05-11T12:16:22.281Z' / TSTOP as UTC calendar date
# BACKAPP =                    T / background is subtracted
# DEADAPP =                    T / deadtime applied
# VIGNAPP =                    T / vignetting or collimator correction applied
# NREADOUT=                  270 / number of read per cadence
# CDPP3_0 =   325.01190185546875 / [ppm] RMS CDPP on 3.0-hr time scales
# CDPP6_0 =    245.5120391845703 / [ppm] RMS CDPP on 6.0-hr time scales
# CDPP12_0=   185.21083068847656 / [ppm] RMS CDPP on 12.0-hr time scales
# TPERIOD =   36.267169223593804 / transit period [days]
# TEPOCH  =   155.08133695729734 / transit epoch in bkjd [days]
# TDEPTH  =    563.8135162341654 / fitted transit depth [ppm]
# TSNR    =    7.942333221435547 / transit signal-to-noise ratio
# TDUR    =   1.9634297903841218 / transit duration [hr]
# INDUR   =  0.08757761021281242 / ingress duration [hr]
# IMPACT  =   0.7064804826732687 / impact parameter
# INCLIN  =    89.61256073887888 / inclination [deg]
# DRRATIO =   104.47743043566473 / ratio of planet distance to star radius
# RADRATIO= 0.023358957305826995 / ratio of planet radius to star radius
# PRADIUS =   1.5803764103233384 / planet radius in earth radii
# MAXMES  =    7.472106456756592 / maximum multi-event statistic
# MAXSES  =   3.0164852142333984 / maximum single-event statistic
# NTRANS  =                   39 / number of transits for this TCE
# CONVRGE =                    T / convergence yes/no flag
# MEDDETR =   10.780000686645508 / length of the median detrender filter [hours]
# CHECKSUM= 'PS7aSS4TPS4YPS4Y'   / HDU checksum updated 2016-03-01T23:22:15Z

# %%
data = hdulist[1].data

time = data.field('TIME')
lc_init = data.field("LC_INIT")
lc_error = data.field("LC_INIT_ERR")
lc_white = data.field("LC_WHITE")
lc_detrend = data.field("LC_DETREND")
time
# Out:
# array([  131.51267172,   131.53310642,   131.55354103, ...,  1590.96061113,
#         1590.98104567,  1591.00148042])

# %%
#plot until
p_n = -1

# %%
plt.plot(lc_init[:p_n])
plt.title("Quarter stitched initial light cu")
plt.show()

# %%
plt.plot(lc_error[:p_n])
plt.title("Quarter stitched initial light curve ERROR")
plt.show()

# %%
plt.plot(lc_detrend[:p_n])
plt.title("Initial Detrend time series (median)")
plt.show()

# %%
plt.plot(lc_white[:p_n])
plt.title("Initial whitened time series fit")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def detrend_median(values, w=5):
    values = np.asarray(values)
    return_v = values.copy()
    for i in range(values.shape[0]):
        lim_inf = int(    i -(w/2))
        lim_sup = int((i+1) + (w/2))
        if lim_inf <0:
            lim_sup += np.abs(lim_inf)
            lim_inf = 0
        if lim_sup > values.shape[0]:
            lim_inf -= (lim_sup-values.shape[0])
            lim_sup = values.shape[0]
        median_filter = np.nanmedian(values[ lim_inf: lim_sup ])
        
        #print("limite inferior: ",lim_inf)
        #print("Valor central: ",i)
        #print("limite superior: ",lim_sup)
        #print(median_filter)
        if not np.isnan(median_filter):
            return_v[i] = values[i] - median_filter
    return return_v
def full_detrend_median(values, w=5):
    f_de = detrend_median(values,w) #forward detrend
    b_de = detrend_median(f_de[::-1],w) #backward detrend
    return b_de[::-1]

our_detrend = detrend_median(lc_init[:], 20) #entre 20 y 25... o 10
#our_detrend2 = full_detrend_median(lc_init[:], 10)
plt.plot(our_detrend[:p_n])
plt.title("Our Detrend")
plt.show()

#plt.plot(our_detrend2[:p_n])
#plt.title("Our Detrend v2")
#plt.show()
# Out:
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
final_lc = clean_LC(lc_init, kernel_median=25, detrend_median=True) 
plt.plot(final_lc[:p_n])
# Out:
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
final_lc = clean_LC(lc_init, kernel_median=25, kernel_pol=100) #pol mas alto parece andar mejor 
plt.plot(final_lc[:p_n])
# Out:
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
plt.plot(lc_detrend[:p_n])
plt.title("Initial Detrend time series (median)")
plt.show()

# %%
lc_SavGol, filter_app = SavGol(lc_detrend, return_filter=True,win=5)

# %%
plt.plot(lc_detrend[:p_n], label= "Real LC")
plt.plot(filter_app[:p_n], label= "SavGol Filter -fited")
plt.legend()
plt.plot()
# Out:
# []

# %%
import numpy as np
def remove_outliers(f, osigma=5, clean_limit=9999):
    '''
    Performs iterative sigma clipping to get outliers.
    '''
    f_clean = np.asarray(f).copy() #is already the residuals (value-median filter)
    
    #do_clean = True
    #i=1
    #while do_clean and i <= clean_limit:

    # Get the outliers
    #f_savgol = SavGol(f_clean)
    #f_savgol = f_clean
    med = np.nanmedian(f_clean)
    MAD = 1.4826 * np.nanmedian(np.abs(f_clean - med)) #no estoy seguro si va con el 1.4826
    inds = np.where((f_clean - 0 > + osigma * MAD) |
                    (f_clean - 0 < - osigma * MAD))[0]
    #remove outliers
    f_clean[inds] = np.nan

    #stop cleaning
    #if len(inds) == 0:
    #    do_clean = False
    #i+=1
    print("One clean done, erase %d values"%(len(inds)))
    return f_clean

# %%
plt.plot(lc_detrend)

# %%
plt.plot(lc_detrend[:p_n])

# %%
# con 10 borra muchos
# pipeline de kepler usa 100
#opciones mas baja se señala como 60 o 42
plt.plot(remove_outliers(final_lc, 100)[:p_n])
# Out:
# One clean done, erase 0 values
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/ipykernel/__main__.py:17: RuntimeWarning: invalid value encountered in greater
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/ipykernel/__main__.py:18: RuntimeWarning: invalid value encountered in less

# %%
#how to delete positive values??
