# %%
folder = "drive/My Drive/Colab Notebooks/KOI_Data/"
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def impute_on_pandas(df):
    return df.fillna(df.median(),inplace=False)

#df_sets = pd.read_csv(folder+"/koi_sets_unb.csv")
#mask_train = (df_sets["Set"] == "Train").values
#mask_test = (df_sets["Set"] == "Test").values
#mask_unlabeled = (df_sets["Set"] == "Unlabeled").values
#df_meta_train = df_meta[mask_train]
#df_meta_test = df_meta[mask_test]
#df_meta_unb = df_meta[mask_unlabeled]

df_meta = pd.read_csv(folder+"/koi_metadata.csv")
df_meta.head()
# Out:
#     KOI Name NExScI Disposition  ... KOI count  Transit Number
# 0  K00889.01          CONFIRMED  ...         1             153
# 1  K01009.01     FALSE POSITIVE  ...         1             225
# 2  K07621.01     FALSE POSITIVE  ...         1               4
# 3  K06252.01     FALSE POSITIVE  ...         1             164
# 4  K00958.01          CANDIDATE  ...         1              62
#
# [5 rows x 31 columns]

# %%
metadata_used = ["NExScI Disposition", 
                 "Period","First Transit Time (BJD)", "Duration",
                "Transit Depth", "Semi-major Axis", "r/R",
                 "Teq", "Transit Number"]
df_meta_obj = df_meta[metadata_used]

df_meta_obj = impute_on_pandas(df_meta_obj)
corr = df_meta_obj.corr()


ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)

corr
# Out:
#                             Period  ...  Transit Number
# Period                    1.000000  ...       -0.277104
# First Transit Time (BJD)  0.616285  ...       -0.233885
# Duration                  0.348810  ...       -0.245439
# Transit Depth            -0.047227  ...       -0.065527
# Semi-major Axis           0.971533  ...       -0.373006
# r/R                      -0.026161  ...       -0.029710
# Teq                      -0.349195  ...        0.606480
# Transit Number           -0.277104  ...        1.000000
#
# [8 rows x 8 columns]
