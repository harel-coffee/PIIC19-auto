# %% [markdown]
# La idea de este play ground es explorar la información de algunos dataset de este link:https://exoplanetarchive.ipac.caltech.edu/bulk_data_download/?fbclid=IwAR1GDR1g9FTuhdx1K7oOGO0Vh0I3QFGDyTSwOF15rF0hLnZuznXaj86XEr0
#
# para asi ver cuales sirve y cuales no. Tambien se explorara la aplicación de transformaciones para dejar las curvas de luz bonitas.

# %%
import numpy as np
#from astrobase import periodbase, checkplot
#from astrobase.hatsurveys import hatlc
from IPython.display import display, Image
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table

# %%
import os, sys
dirpath = os.getcwd().split("code")[0]+"code/"
sys.path.append(dirpath)
from pre_process import clean_LC, median_view, mask_values

# %% [markdown]
# # Funciones Genericas

# %%
import glob

def generate_path_list(path,extension):    
    fits_list = []
    for fits in glob.glob(path+'*.' + extension):
        fits_list.append(fits)
    print('Se encontraron %i %s'%(len(fits_list),extension))
    return fits_list

# %% [markdown]
# # SuperWasp

# %%
from astropy.io import ascii
path_list = generate_path_list('./SW_play_data_100_fits/Confirmed/','tbl')
n_sampled = np.random.randint(0,len(path_list))
dat = ascii.read(path_list[n_sampled])  
df = dat.to_pandas()
df.head()
# Out:
# Se encontraron 45 tbl
#        TMID     FLUX2  FLUX2_ERR  TAMFLUX2  TAMFLUX2_ERR             IMAGEID  \
# 0  73862579  20.74306   0.178862  21.13273      0.178862  223200605042114540
# 1  73862617  20.94525   0.179462  21.35091      0.179462  223200605042115330
# 2  73863175  21.29281   0.176401  21.85450      0.176401  223200605042124500
# 3  73863213  20.44194   0.175172  21.01584      0.175172  223200605042125280
# 4  73863848  20.11797   0.168669  20.83986      0.207928  223200605042136030
#
#     CCDX  CCDY  FLAG           HJD      MAG2  MAG2_ERR   TAMMAG2  TAMMAG2_ERR
# 0  16340  2142    32  2.453860e+06  11.70782  0.009362  11.68761     0.009189
# 1  16340  2142    32  2.453860e+06  11.69729  0.009303  11.67646     0.009126
# 2  16341  2069    32  2.453860e+06  11.67942  0.008995  11.65115     0.008764
# 3  16341  2070    32  2.453860e+06  11.72369  0.009304  11.69363     0.009050
# 4  16408  2064    32  2.453860e+06  11.74104  0.009103  11.70276     0.010833

# %%
plt.figure(figsize=(30,10))
plt.plot(df['HJD'], df["FLUX2"],'bo-')
plt.show()

# %%
#GET UNIFORM SAMPLING
new_time, new_flux = mask_values(df["HJD"], df['FLUX2'])

#GET VIEW OF KEPLER (30 min sampling rate)
time_keplerview, flux_keplerview = median_view(new_time, new_flux, bin_width=0.020433) # el de kepler
time_keplerview
# Out:
# New sampling rate: 0.000278
# (in minutes): 0.400320
# Old length: 8674
# New length: 1873715
# percentaje nulls/nans: 0.995371
# Old length: 1873715
# New length: 25496
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# array([2453964, 2453964, 2453964, ..., 2454485, 2454485, 2454485])

# %%
plt.plot(time_keplerview, flux_keplerview)

# %%
#DETREND AND MEDIAN FILTER
flux_processed = clean_LC(flux_keplerview, kernel_median=25, kernel_pol=49 )
plt.plot(flux_processed)
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %% [markdown]
# # Keppler

# %%
from astropy.io import ascii
path_list = generate_path_list('./KL_play_data_100_fits/confirmed/','tbl')
n_sampled = np.random.randint(0,len(path_list))
dat = ascii.read(path_list[n_sampled])  
df = dat.to_pandas()
df.head()
# Out:
# Se encontraron 45 tbl
#          TIME      TIME_BJD  TIMECORR  CADENCENO   SAP_FLUX  SAP_FLUX_ERR  \
# 0  906.845863  2.455740e+06  0.002431    39049.0  30944.934      5.211259
# 1  906.866298  2.455740e+06  0.002431    39050.0  30944.943      5.211295
# 2  906.886732  2.455740e+06  0.002432    39051.0  30950.969      5.211580
# 3  906.907166  2.455740e+06  0.002432    39052.0  30945.855      5.211198
# 4  906.927600  2.455740e+06  0.002433    39053.0  30933.410      5.210552
#
#      SAP_BKG  SAP_BKG_ERR  PDCSAP_FLUX  PDCSAP_FLUX_ERR    ...      \
# 0  830.66315     0.318906          NaN              NaN    ...
# 1  830.08472     0.318819    34643.652         5.764341    ...
# 2  829.46429     0.318979    34646.645         5.769618    ...
# 3  830.31683     0.318551    34638.633         5.768979    ...
# 4  830.07709     0.318790    34626.734         5.769846    ...
#
#    PSF_CENTR1  PSF_CENTR1_ERR  PSF_CENTR2  PSF_CENTR2_ERR  MOM_CENTR1  \
# 0         NaN             NaN         NaN             NaN   490.37312
# 1         NaN             NaN         NaN             NaN   490.37384
# 2         NaN             NaN         NaN             NaN   490.37411
# 3         NaN             NaN         NaN             NaN   490.37481
# 4         NaN             NaN         NaN             NaN   490.37481
#
#    MOM_CENTR1_ERR  MOM_CENTR2  MOM_CENTR2_ERR  POS_CORR1  POS_CORR2
# 0        0.000217   569.94598        0.000205   0.020473   0.083049
# 1        0.000217   569.94613        0.000205   0.020762   0.083053
# 2        0.000217   569.94621        0.000205   0.021116   0.083102
# 3        0.000217   569.94618        0.000205   0.021621   0.083364
# 4        0.000217   569.94637        0.000205   0.021761   0.083353
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(30,10))
plt.plot(df['TIME_BJD'], df["SAP_FLUX"],'bo-')
plt.show()

# %%
#GET UNIFORM SAMPLING
new_time, new_flux = mask_values(df["TIME_BJD"], df['SAP_FLUX'])

#GET VIEW OF KEPLER (30 min sampling rate)
time_keplerview, flux_keplerview = median_view(new_time, new_flux, bin_width=0.020433) # el de kepler
time_keplerview
# Out:
# ***************Mask values to get uniform sampling rate is being done..
# New sampling rate: 0.020433
# (in minutes): 29.423376
# Old length: 4573
# New length: 4573
# percentaje nulls/nans: 0.000000
# ***************Median view is being done...
# Old length: 4573
# New length: 4572
# Nothing to be done
# array([2455739.8458634 , 2455739.8662963 , 2455739.8867292 , ...,
#        2455833.22421506, 2455833.24464796, 2455833.26508086])

# %%
plt.figure(figsize=(30,10))
plt.plot(time_keplerview, flux_keplerview, 'bo-')

# %%
#DETREND AND MEDIAN FILTER
flux_processed = clean_LC(flux_keplerview, kernel_median=25, kernel_pol=49 )
plt.plot(flux_processed)
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %% [markdown]
# # KELT

# %%
path_list = generate_path_list('./KELT/','tbl')
n_sampled = np.random.randint(0,len(path_list))
dat = ascii.read(path_list[n_sampled])  
df = dat.to_pandas()
df.head()
# Out:
# Se encontraron 91 tbl
#            TIME       MAG  MAG_ERR
# 0  2.454035e+06  13.35949  0.00563
# 1  2.454035e+06  13.35013  0.00506
# 2  2.454035e+06  13.36577  0.00567
# 3  2.454035e+06  13.36874  0.00511
# 4  2.454035e+06  13.36194  0.00495

# %%
plt.figure(figsize=(30,10))
plt.plot(df['TIME'], df["MAG"],'bo-')
plt.show()

# %%
#GET UNIFORM SAMPLING
new_time, new_flux = mask_values(df["TIME"], df['MAG'])

#GET VIEW OF KEPLER (30 min sampling rate)
time_keplerview, flux_keplerview = median_view(new_time, new_flux, bin_width=0.020433) # el de kepler
time_keplerview
# Out:
# ***************Mask values to get uniform sampling rate is being done..
# New sampling rate: 0.002096
# (in minutes): 3.018240
# Old length: 1769
# New length: 362596
# percentaje nulls/nans: 0.995121
# ***************Median view is being done...
# Old length: 362596
# New length: 37195
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# array([2454034, 2454034, 2454034, ..., 2454794, 2454794, 2454794])

# %%
plt.figure(figsize=(30,10))
plt.plot(time_keplerview, flux_keplerview, 'bo-')

# %%
#DETREND AND MEDIAN FILTER
flux_processed = clean_LC(flux_keplerview, kernel_median=25, kernel_pol=49 )
plt.plot(flux_processed)
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %% [markdown]
# # PHOTOMETRIC

# %%
path_list = generate_path_list('./PHOTOMETRIC/','tbl')    
n_sampled = np.random.randint(0,len(path_list))
dat = ascii.read(path_list[n_sampled])  
df = dat.to_pandas()

time_column = df.columns[0]
mag_column = df.columns[1]
df.head()
# Out:
# Se encontraron 92 tbl
#             HJD  Relative_Magnitude  Accepted
# 0  2.453462e+06           -9.253764         1
# 1  2.453462e+06           -9.253045         1
# 2  2.453462e+06           -9.254073         1
# 3  2.453462e+06           -9.253437         1
# 4  2.453462e+06           -9.252850         1

# %%
plt.figure(figsize=(30,10))
plt.plot(df[time_column], df[mag_column],'bo-')
plt.show()

# %%
#GET UNIFORM SAMPLING
new_time, new_flux = mask_values(df[time_column], df[mag_column])

#GET VIEW OF KEPLER (30 min sampling rate)
time_keplerview, flux_keplerview = median_view(new_time, new_flux, bin_width=0.020433) # el de kepler
time_keplerview
# Out:
# ***************Mask values to get uniform sampling rate is being done..
# New sampling rate: 0.000347
# (in minutes): 0.499982
# Old length: 55101
# New length: 59310
# percentaje nulls/nans: 0.070966
# ***************Median view is being done...
# Old length: 59310
# New length: 1008
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# array([2453461.51867529, 2453461.53916066, 2453461.55964602, ...,
#        2453482.05022226, 2453482.07070763, 2453482.09101939])

# %%
plt.figure(figsize=(30,10))
plt.plot(time_keplerview, flux_keplerview, 'bo-')

# %%
#DETREND AND MEDIAN FILTER
flux_processed = clean_LC(flux_keplerview, kernel_median=25, kernel_pol=49 )
plt.plot(flux_processed)
# Out:
# /users/fmena/anaconda3/envs/tesis/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
