# %% [markdown]
# La idea de este play ground es explorar la información de algunos dataset de este link:https://exoplanetarchive.ipac.caltech.edu/bulk_data_download/?fbclid=IwAR1GDR1g9FTuhdx1K7oOGO0Vh0I3QFGDyTSwOF15rF0hLnZuznXaj86XEr0
#
# para asi ver cuales sirve y cuales no. Tambien se explorara la aplicación de transformaciones para dejar las curvas de luz bonitas.

# %%
import numpy as np
#from astrobase import periodbase, checkplot
#from astrobase.hatsurveys import hatlc
from IPython.display import display, Image
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table

# %%
import os, sys
dirpath = os.getcwd().split("code")[0]+"code/"
sys.path.append(dirpath)
from pre_process import clean_LC, median_view, mask_values,process_found, generate_representation

# %% [markdown]
# # Funciones Genericas

# %%
import glob

def generate_path_list(path,extension):    
    fits_list = []
    for fits in glob.glob(path+'*.' + extension):
        fits_list.append(fits)
    print('Se encontraron %i %s'%(len(fits_list),extension))
    return fits_list

# %% [markdown]
# # SuperWasp

# %%
from astropy.io import ascii
path_list = generate_path_list('./SW_play_data_100_fits/Confirmed/','tbl')
n_sampled = np.random.randint(0,len(path_list))
dat = ascii.read(path_list[n_sampled])  
df = dat.to_pandas()
df.head()
# Out:
# Se encontraron 45 tbl
#         TMID     FLUX2  FLUX2_ERR  TAMFLUX2  TAMFLUX2_ERR             IMAGEID  \
# 0  105592752  82.47345   0.434516  82.47345      0.434516  227200705070319210
# 1  105595572  83.02505   0.472332  83.02505      0.472332  227200705070406200
# 2  105595883  85.04523   0.502654  85.04523      0.502654  227200705070411300
# 3  136178043  83.83494   0.276196  83.83494      0.276196  227200804250315280
# 4  136179309  81.94515   0.266387  81.94515      0.266387  227200804250336330
#
#    CCDX   CCDY  FLAG           HJD      MAG2  MAG2_ERR   TAMMAG2  TAMMAG2_ERR
# 0  6305  23026     0  2.454228e+06  10.20921  0.005720  10.20921     0.005720
# 1  6191  23210     0  2.454228e+06  10.20198  0.006177  10.20198     0.006177
# 2  6185  23201     0  2.454228e+06  10.17587  0.006417  10.17587     0.006417
# 3  7932  21649     0  2.454582e+06  10.19144  0.003577  10.19144     0.003577
# 4  7948  21665     0  2.454582e+06  10.21619  0.003530  10.21619     0.003530

# %%
plt.figure(figsize=(30,10))
plt.plot(df['HJD'], df["FLUX2"],'bo-')
plt.show()

# %%
#GET UNIFORM SAMPLING
new_time, new_flux = mask_values(df["HJD"], df['FLUX2'])

#GET VIEW OF KEPLER (30 min sampling rate)
time_keplerview, flux_keplerview = median_view(new_time, new_flux, bin_width=0.020433) # el de kepler
time_keplerview
# Out:
# ***************Mask values to get uniform sampling rate is being done..
# New sampling rate: 0.002824
# (in minutes): 4.066560
# Old length: 13
# New length: 125367
# percentaje nulls/nans: 0.999896
# ***************Median view is being done...
# Old length: 125367
# New length: 17327
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# array([ 2454227.648217  ,  2454227.669397  ,  2454227.689165  , ...,
#         2454581.62109539,  2454581.64086339,  2454581.66063139])

# %%
#lo de arriba ahora en funcion
time_rep, lc_rep = generate_representation(df["HJD"], df["FLUX2"], sample_time=0, kepler_view=True)
# Out:
# ***************Mask values to get uniform sampling rate is being done..
# New sampling rate: 0.002824
# (in minutes): 4.066560
# Old length: 13
# New length: 125367
# percentaje nulls/nans: 0.999896
# ***************Median view is being done...
# Old length: 125367
# New length: 17326
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
plt.plot(time_keplerview, flux_keplerview)

# %%
#DETREND AND MEDIAN FILTER
flux_processed = clean_LC(flux_keplerview )
plt.plot(flux_processed)
# Out:
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# Clean done (remove outliers iterativetly), erase 6 values
# /home/fmena/Desktop/Postgrado/Astro/PIIC19/code/pre_process.py:114: RuntimeWarning: invalid value encountered in less
#   mask_nan = (f_clean - med < -sigm_low * MAD) | (f_clean - med > sigm_up * MAD)
# /home/fmena/Desktop/Postgrado/Astro/PIIC19/code/pre_process.py:114: RuntimeWarning: invalid value encountered in greater
#   mask_nan = (f_clean - med < -sigm_low * MAD) | (f_clean - med > sigm_up * MAD)

# %% [markdown]
# # Keppler

# %%
from astropy.io import ascii
path_list = generate_path_list('./KL_play_data_100_fits/confirmed/','tbl')
n_sampled = np.random.randint(0,len(path_list))
dat = ascii.read(path_list[n_sampled])  
df = dat.to_pandas()
df.head()
# Out:
# Se encontraron 45 tbl
#          TIME      TIME_BJD  TIMECORR  CADENCENO   SAP_FLUX  SAP_FLUX_ERR  \
# 0  906.845863  2.455740e+06  0.002431      39049  30944.934      5.211259
# 1  906.866298  2.455740e+06  0.002431      39050  30944.943      5.211295
# 2  906.886732  2.455740e+06  0.002432      39051  30950.969      5.211580
# 3  906.907166  2.455740e+06  0.002432      39052  30945.855      5.211198
# 4  906.927600  2.455740e+06  0.002433      39053  30933.410      5.210552
#
#      SAP_BKG  SAP_BKG_ERR  PDCSAP_FLUX  PDCSAP_FLUX_ERR    ...      \
# 0  830.66315     0.318906          NaN              NaN    ...
# 1  830.08472     0.318819    34643.652         5.764341    ...
# 2  829.46429     0.318979    34646.645         5.769618    ...
# 3  830.31683     0.318551    34638.633         5.768979    ...
# 4  830.07709     0.318790    34626.734         5.769846    ...
#
#    PSF_CENTR1  PSF_CENTR1_ERR  PSF_CENTR2  PSF_CENTR2_ERR  MOM_CENTR1  \
# 0         NaN             NaN         NaN             NaN   490.37312
# 1         NaN             NaN         NaN             NaN   490.37384
# 2         NaN             NaN         NaN             NaN   490.37411
# 3         NaN             NaN         NaN             NaN   490.37481
# 4         NaN             NaN         NaN             NaN   490.37481
#
#    MOM_CENTR1_ERR  MOM_CENTR2  MOM_CENTR2_ERR  POS_CORR1  POS_CORR2
# 0        0.000217   569.94598        0.000205   0.020473   0.083049
# 1        0.000217   569.94613        0.000205   0.020762   0.083053
# 2        0.000217   569.94621        0.000205   0.021116   0.083102
# 3        0.000217   569.94618        0.000205   0.021621   0.083364
# 4        0.000217   569.94637        0.000205   0.021761   0.083353
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(30,10))
plt.plot(df['TIME_BJD'], df["SAP_FLUX"],'bo-')
plt.show()

# %%
#GET UNIFORM SAMPLING
new_time, new_flux = mask_values(df["TIME_BJD"], df['SAP_FLUX'])

#GET VIEW OF KEPLER (30 min sampling rate)
time_keplerview, flux_keplerview = median_view(new_time, new_flux, bin_width=0.020433) # el de kepler
time_keplerview
# Out:
# ***************Mask values to get uniform sampling rate is being done..
# New sampling rate: 0.020433
# (in minutes): 29.423376
# Old length: 4573
# New length: 4573
# percentaje nulls/nans: 0.000000
# ***************Median view is being done...
# Old length: 4573
# New length: 4572
# Nothing to be done
# array([ 2455739.8458634 ,  2455739.8662963 ,  2455739.8867292 , ...,
#         2455833.22421506,  2455833.24464796,  2455833.26508086])

# %%
plt.figure(figsize=(30,10))
plt.plot(time_keplerview, flux_keplerview, 'bo-')

# %%
#DETREND AND MEDIAN FILTER
flux_processed = clean_LC(flux_keplerview )
plt.plot(flux_processed)
# Out:
# Clean done (remove outliers iterativetly), erase 4 values
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# /home/fmena/Desktop/Postgrado/Astro/PIIC19/code/pre_process.py:114: RuntimeWarning: invalid value encountered in less
#   mask_nan = (f_clean - med < -sigm_low * MAD) | (f_clean - med > sigm_up * MAD)
# /home/fmena/Desktop/Postgrado/Astro/PIIC19/code/pre_process.py:114: RuntimeWarning: invalid value encountered in greater
#   mask_nan = (f_clean - med < -sigm_low * MAD) | (f_clean - med > sigm_up * MAD)

# %%
aux  = process_found(flux_keplerview, kernel_median=25, kernel_pol=151, plot_show=True)
plt.plot(aux)
# Out:
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %% [markdown]
# # KELT

# %%
path_list = generate_path_list('./KELT/','tbl')
n_sampled = np.random.randint(0,len(path_list))
dat = ascii.read(path_list[n_sampled])  
df = dat.to_pandas()
df.head()
# Out:
# Se encontraron 91 tbl
#            TIME       MAG  MAG_ERR
# 0  2.454035e+06  14.30530  0.00779
# 1  2.454035e+06  14.29033  0.00711
# 2  2.454035e+06  14.31446  0.00725
# 3  2.454035e+06  14.29683  0.00740
# 4  2.454035e+06  14.29035  0.00746

# %%
plt.figure(figsize=(30,10))
plt.plot(df['TIME'], df["MAG"],'bo-')
plt.show()

# %%
#GET UNIFORM SAMPLING
new_time, new_flux = mask_values(df["TIME"], df['MAG'])

#GET VIEW OF KEPLER (30 min sampling rate)
time_keplerview, flux_keplerview = median_view(new_time, new_flux, bin_width=0.020433) # el de kepler
time_keplerview
# Out:
# ***************Mask values to get uniform sampling rate is being done..
# New sampling rate: 0.002096
# (in minutes): 3.018240
# Old length: 1792
# New length: 362596
# percentaje nulls/nans: 0.995058
# ***************Median view is being done...
# Old length: 362596
# New length: 37195
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# array([ 2454034.706762  ,  2454034.727722  ,  2454034.748682  , ...,
#         2454794.64514423,  2454794.66610423,  2454794.68601623])

# %%
plt.figure(figsize=(30,10))
plt.plot(time_keplerview, flux_keplerview, 'bo-')

# %%
#DETREND AND MEDIAN FILTER
flux_processed = clean_LC(flux_keplerview, kernel_median=25, kernel_pol=49 )
plt.plot(flux_processed)
# Out:
# /home/fmena/anaconda2/envs/py3/lib/python3.5/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# Clean done (remove outliers iterativetly), erase 0 values
# /home/fmena/Desktop/Postgrado/Astro/PIIC19/code/pre_process.py:114: RuntimeWarning: invalid value encountered in less
#   mask_nan = (f_clean - med < -sigm_low * MAD) | (f_clean - med > sigm_up * MAD)
# /home/fmena/Desktop/Postgrado/Astro/PIIC19/code/pre_process.py:114: RuntimeWarning: invalid value encountered in greater
#   mask_nan = (f_clean - med < -sigm_low * MAD) | (f_clean - med > sigm_up * MAD)

# %% [markdown]
# # PHOTOMETRIC

# %%
path_list = generate_path_list('./PHOTOMETRIC/','tbl')    
n_sampled = np.random.randint(0,len(path_list))
dat = ascii.read(path_list[n_sampled])  
df = dat.to_pandas()

time_column = df.columns[0]
mag_column = df.columns[1]
df.head()
# Out:
# Se encontraron 92 tbl
#             HJD  Normalized_Flux  Normalized_Flux_Uncertainty  Accepted
# 0  2.453671e+06         0.987927                      0.00005         1
# 1  2.453671e+06         0.987883                      0.00005         1
# 2  2.453671e+06         0.987394                      0.00005         1
# 3  2.453671e+06         0.987020                      0.00005         1
# 4  2.453671e+06         0.986546                      0.00005         1

# %%
plt.figure(figsize=(30,10))
plt.plot(df[time_column], df[mag_column],'bo-')
plt.show()

# %%
#GET UNIFORM SAMPLING
new_time, new_flux = mask_values(df[time_column], df[mag_column])

#GET VIEW OF KEPLER (30 min sampling rate)
time_keplerview, flux_keplerview = median_view(new_time, new_flux, bin_width=0.020433) # el de kepler
time_keplerview
# Out:
# ***************Mask values to get uniform sampling rate is being done..
# New sampling rate: 0.070420
# (in minutes): 101.404800
# Old length: 492
# New length: 505
# percentaje nulls/nans: 0.025743
# ***************Median view is being done...
# Old length: 505
# New length: 1737
# Nothing to be done
# array([ 2453670.55302   ,  2453670.62344   ,  2453670.69386   ,
#         2453670.76428   ,  2453670.8347    ,  2453670.90512   ,
#         2453670.97554   ,  2453671.04596   ,  2453671.11638   ,
#         2453671.1868    ,  2453671.25722   ,  2453671.32764   ,
#         2453671.39806   ,  2453671.46848   ,  2453671.5389    ,
#         2453671.60932   ,  2453671.67974   ,  2453671.75016   ,
#         2453671.82058   ,  2453671.891     ,  2453671.96142   ,
#         2453672.03184   ,  2453672.10225999,  2453672.17267999,
#         2453672.24309999,  2453672.31351999,  2453672.38393999,
#         2453672.45435999,  2453672.52477999,  2453672.59519999,
#         2453672.66561999,  2453672.73603999,  2453672.80645999,
#         2453672.87687999,  2453672.94729999,  2453673.01771999,
#         2453673.08813999,  2453673.15855999,  2453673.22897999,
#         2453673.29939999,  2453673.36981999,  2453673.44023999,
#         2453673.51065999,  2453673.58107999,  2453673.65149999,
#         2453673.72191999,  2453673.79233999,  2453673.86275999,
#         2453673.93317999,  2453674.00359999,  2453674.07401999,
#         2453674.14443999,  2453674.21485999,  2453674.28527999,
#         2453674.35569999,  2453674.42611999,  2453674.49653999,
#         2453674.56695999,  2453674.63737999,  2453674.70779999,
#         2453674.77821999,  2453674.84863999,  2453674.91905999,
#         2453674.98947999,  2453675.05989999,  2453675.13031999,
#         2453675.20073998,  2453675.27115998,  2453675.34157998,
#         2453675.41199998,  2453675.48241998,  2453675.55283998,
#         2453675.62325998,  2453675.69367998,  2453675.76409998,
#         2453675.83451998,  2453675.90493998,  2453675.97535998,
#         2453676.04577998,  2453676.11619998,  2453676.18661998,
#         2453676.25703998,  2453676.32745998,  2453676.39787998,
#         2453676.46829998,  2453676.53871998,  2453676.60913998,
#         2453676.67955998,  2453676.74997998,  2453676.82039998,
#         2453676.89081998,  2453676.96123998,  2453677.03165998,
#         2453677.10207998,  2453677.17249998,  2453677.24291998,
#         2453677.31333998,  2453677.38375998,  2453677.45417998,
#         2453677.52459998,  2453677.59501998,  2453677.66543998,
#         2453677.73585998,  2453677.80627998,  2453677.87669998,
#         2453677.94711998,  2453678.01753998,  2453678.08795998,
#         2453678.15837998,  2453678.22879998,  2453678.29921997,
#         2453678.36963997,  2453678.44005997,  2453678.51047997,
#         2453678.58089997,  2453678.65131997,  2453678.72173997,
#         2453678.79215997,  2453678.86257997,  2453678.93299997,
#         2453679.00341997,  2453679.07383997,  2453679.14425997,
#         2453679.21467997,  2453679.28509997,  2453679.35551997,
#         2453679.42593997,  2453679.49635997,  2453679.56677997,
#         2453679.63719997,  2453679.70761997,  2453679.77803997,
#         2453679.84845997,  2453679.91887997,  2453679.98929997,
#         2453680.05971997,  2453680.13013997,  2453680.20055997,
#         2453680.27097997,  2453680.34139997,  2453680.41181997,
#         2453680.48223997,  2453680.55265997,  2453680.62307997,
#         2453680.69349997,  2453680.76391997,  2453680.83433997,
#         2453680.90475997,  2453680.97517997,  2453681.04559997,
#         2453681.11601997,  2453681.18643997,  2453681.25685997,
#         2453681.32727996,  2453681.39769996,  2453681.46811996,
#         2453681.53853996,  2453681.60895996,  2453681.67937996,
#         2453681.74979996,  2453681.82021996,  2453681.89063996,
#         2453681.96105996,  2453682.03147996,  2453682.10189996,
#         2453682.17231996,  2453682.24273996,  2453682.31315996,
#         2453682.38357996,  2453682.45399996,  2453682.52441996,
#         2453682.59483996,  2453682.66525996,  2453682.73567996,
#         2453682.80609996,  2453682.87651996,  2453682.94693996,
#         2453683.01735996,  2453683.08777996,  2453683.15819996,
#         2453683.22861996,  2453683.29903996,  2453683.36945996,
#         2453683.43987996,  2453683.51029996,  2453683.58071996,
#         2453683.65113996,  2453683.72155996,  2453683.79197996,
#         2453683.86239996,  2453683.93281996,  2453684.00323996,
#         2453684.07365996,  2453684.14407996,  2453684.21449996,
#         2453684.28491996,  2453684.35533996,  2453684.42575995,
#         2453684.49617995,  2453684.56659995,  2453684.63701995,
#         2453684.70743995,  2453684.77785995,  2453684.84827995,
#         2453684.91869995,  2453684.98911995,  2453685.05953995,
#         2453685.12995995,  2453685.20037995,  2453685.27079995,
#         2453685.34121995,  2453685.41163995,  2453685.48205995,
#         2453685.55247995,  2453685.62289995,  2453685.69331995,
#         2453685.76373995,  2453685.83415995,  2453685.90457995,
#         2453685.97499995,  2453686.04541995,  2453686.11583995,
#         2453686.18625995,  2453686.25667995,  2453686.32709995,
#         2453686.39751995,  2453686.46793995,  2453686.53835995,
#         2453686.60877995,  2453686.67919995,  2453686.74961995,
#         2453686.82003995,  2453686.89045995,  2453686.96087995,
#         2453687.03129995,  2453687.10171995,  2453687.17213995,
#         2453687.24255995,  2453687.31297995,  2453687.38339995,
#         2453687.45381994,  2453687.52423994,  2453687.59465994,
#         2453687.66507994,  2453687.73549994,  2453687.80591994,
#         2453687.87633994,  2453687.94675994,  2453688.01717994,
#         2453688.08759994,  2453688.15801994,  2453688.22843994,
#         2453688.29885994,  2453688.36927994,  2453688.43969994,
#         2453688.51011994,  2453688.58053994,  2453688.65095994,
#         2453688.72137994,  2453688.79179994,  2453688.86221994,
#         2453688.93263994,  2453689.00305994,  2453689.07347994,
#         2453689.14389994,  2453689.21431994,  2453689.28473994,
#         2453689.35515994,  2453689.42557994,  2453689.49599994,
#         2453689.56641994,  2453689.63683994,  2453689.70725994,
#         2453689.77767994,  2453689.84809994,  2453689.91851994,
#         2453689.98893994,  2453690.05935994,  2453690.12977994,
#         2453690.20019994,  2453690.27061994,  2453690.34103994,
#         2453690.41145994,  2453690.48187994,  2453690.55229993,
#         2453690.62271993,  2453690.69313993,  2453690.76355993,
#         2453690.83397993,  2453690.90439993,  2453690.97481993,
#         2453691.04523993,  2453691.11565993,  2453691.18607993,
#         2453691.25649993,  2453691.32691993,  2453691.39733993,
#         2453691.46775993,  2453691.53817993,  2453691.60859993,
#         2453691.67901993,  2453691.74943993,  2453691.81985993,
#         2453691.89027993,  2453691.96069993,  2453692.03111993,
#         2453692.10153993,  2453692.17195993,  2453692.24237993,
#         2453692.31279993,  2453692.38321993,  2453692.45363993,
#         2453692.52405993,  2453692.59447993,  2453692.66489993,
#         2453692.73531993,  2453692.80573993,  2453692.87615993,
#         2453692.94657993,  2453693.01699993,  2453693.08741993,
#         2453693.15783993,  2453693.22825993,  2453693.29867993,
#         2453693.36909993,  2453693.43951993,  2453693.50993993,
#         2453693.58035993,  2453693.65077992,  2453693.72119992,
#         2453693.79161992,  2453693.86203992,  2453693.93245992,
#         2453694.00287992,  2453694.07329992,  2453694.14371992,
#         2453694.21413992,  2453694.28455992,  2453694.35497992,
#         2453694.42539992,  2453694.49581992,  2453694.56623992,
#         2453694.63665992,  2453694.70707992,  2453694.77749992,
#         2453694.84791992,  2453694.91833992,  2453694.98875992,
#         2453695.05917992,  2453695.12959992,  2453695.20001992,
#         2453695.27043992,  2453695.34085992,  2453695.41127992,
#         2453695.48169992,  2453695.55211992,  2453695.62253992,
#         2453695.69295992,  2453695.76337992,  2453695.83379992,
#         2453695.90421992,  2453695.97463992,  2453696.04505992,
#         2453696.11547992,  2453696.18589992,  2453696.25631992,
#         2453696.32673992,  2453696.39715992,  2453696.46757992,
#         2453696.53799992,  2453696.60841992,  2453696.67883991,
#         2453696.74925991,  2453696.81967991,  2453696.89009991,
#         2453696.96051991,  2453697.03093991,  2453697.10135991,
#         2453697.17177991,  2453697.24219991,  2453697.31261991,
#         2453697.38303991,  2453697.45345991,  2453697.52387991,
#         2453697.59429991,  2453697.66471991,  2453697.73513991,
#         2453697.80555991,  2453697.87597991,  2453697.94639991,
#         2453698.01681991,  2453698.08723991,  2453698.15765991,
#         2453698.22807991,  2453698.29849991,  2453698.36891991,
#         2453698.43933991,  2453698.50975991,  2453698.58017991,
#         2453698.65059991,  2453698.72101991,  2453698.79143991,
#         2453698.86185991,  2453698.93227991,  2453699.00269991,
#         2453699.07311991,  2453699.14353991,  2453699.21395991,
#         2453699.28437991,  2453699.35479991,  2453699.42521991,
#         2453699.49563991,  2453699.56605991,  2453699.63647991,
#         2453699.70689991,  2453699.7773199 ,  2453699.8477399 ,
#         2453699.9181599 ,  2453699.9885799 ,  2453700.0589999 ,
#         2453700.1294199 ,  2453700.1998399 ,  2453700.2702599 ,
#         2453700.3406799 ,  2453700.4110999 ,  2453700.4815199 ,
#         2453700.5519399 ,  2453700.6223599 ,  2453700.6927799 ,
#         2453700.7631999 ,  2453700.8336199 ,  2453700.9040399 ,
#         2453700.9744599 ,  2453701.0448799 ,  2453701.1152999 ,
#         2453701.1857199 ,  2453701.2561399 ,  2453701.3265599 ,
#         2453701.3969799 ,  2453701.4673999 ,  2453701.5378199 ,
#         2453701.6082399 ,  2453701.6786599 ,  2453701.7490799 ,
#         2453701.8194999 ,  2453701.8899199 ,  2453701.9603399 ,
#         2453702.0307599 ,  2453702.1011799 ,  2453702.1715999 ,
#         2453702.2420199 ,  2453702.3124399 ,  2453702.3828599 ,
#         2453702.4532799 ,  2453702.5236999 ,  2453702.5941199 ,
#         2453702.6645399 ,  2453702.7349599 ,  2453702.8053799 ,
#         2453702.87579989,  2453702.94621989,  2453703.01663989,
#         2453703.08705989,  2453703.15747989,  2453703.22789989,
#         2453703.29831989,  2453703.36873989,  2453703.43915989,
#         2453703.50957989,  2453703.57999989,  2453703.65041989,
#         2453703.72083989,  2453703.79125989,  2453703.86167989,
#         2453703.93209989,  2453704.00251989,  2453704.07293989,
#         2453704.14335989,  2453704.21377989,  2453704.28419989,
#         2453704.35461989,  2453704.42503989,  2453704.49545989,
#         2453704.56587989,  2453704.63629989,  2453704.70671989,
#         2453704.77713989,  2453704.84755989,  2453704.91797989,
#         2453704.98839989,  2453705.05881989,  2453705.12923989,
#         2453705.19965989,  2453705.27007989,  2453705.34049989,
#         2453705.41091989,  2453705.48133989,  2453705.55175989,
#         2453705.62217989,  2453705.69259989,  2453705.76301989,
#         2453705.83343989,  2453705.90385988,  2453705.97427988,
#         2453706.04469988])

# %%
plt.figure(figsize=(30,10))
plt.plot(time_keplerview, flux_keplerview, 'bo-')

# %%
#DETREND AND MEDIAN FILTER
flux_processed = clean_LC(flux_keplerview, kernel_median=25, kernel_pol=49 )
plt.plot(flux_processed)
# Out:
# Clean done (remove outliers iterativetly), erase 0 values
# /home/fmena/Desktop/Postgrado/Astro/PIIC19/code/pre_process.py:114: RuntimeWarning: invalid value encountered in less
#   mask_nan = (f_clean - med < -sigm_low * MAD) | (f_clean - med > sigm_up * MAD)
# /home/fmena/Desktop/Postgrado/Astro/PIIC19/code/pre_process.py:114: RuntimeWarning: invalid value encountered in greater
#   mask_nan = (f_clean - med < -sigm_low * MAD) | (f_clean - med > sigm_up * MAD)
