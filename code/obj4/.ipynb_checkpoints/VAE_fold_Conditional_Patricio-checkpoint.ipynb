# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os,sys, gc, keras, time

folder = "../../KOI_Data/"
folder_lc = "/work/work_teamEXOPLANET/KOI_LC/"
# Out:
# Using TensorFlow backend.

# %%
# NEW: metadata relacionada solo con el objetivo en transito
names_m = ['Period', 'Duration', 'Time of Transit Epoch', 'r/R', 'a/R',
       'Inclination', 'Impact Parameter', 'Fitted Stellar Density',
       'Limb Darkening Coeff1', 'Limb Darkening Coeff2']
metadata_transit = np.load("LC_features/MetadataLC.npy") #nans vienen imputados con mediana...

df_meta_obj = pd.DataFrame(metadata_transit, columns=names_m)
df_meta_obj.head()
# Out:
#        Period  Duration  Time of Transit Epoch    r/R      a/R  Inclination  \
# 0    8.884923  0.086252             169.991686  0.114   36.466        89.89
# 1    5.092465  0.152458             357.535940  0.014   10.670        89.14
# 2  275.073650  0.140417             315.248600  0.014  512.000        89.93
# 3    8.460439  0.197288             133.774490  0.478   14.087        85.68
# 4   21.761298  0.051792             166.540438  0.032  137.070        89.95
#
#    Impact Parameter  Fitted Stellar Density  Limb Darkening Coeff1  \
# 0             0.069                11.62061                  0.497
# 1             0.161                 0.88510                  0.551
# 2             0.595                33.55994                  0.437
# 3             1.061                 0.73874                  0.299
# 4             0.123               102.86534                  0.627
#
#    Limb Darkening Coeff2
# 0                  0.204
# 1                  0.165
# 2                  0.243
# ...

# %%
#eliminar valores que no importan en fase-- estarian dados por fuera
del_val = ["Time of Transit Epoch", "Period"] #quizas perido es necesario para extraer los otros metadatos..

#eliminar valores dependientes de otros??????????????????
del_val += ["Impact Parameter"]
del_val += ["Fitted Stellar Density", "Duration"] #dependen de periodo...

Y_values = df_meta_obj.drop(del_val, axis=1).values 
Y_values.shape
# Out:
# (8054, 8)

# %%
#masacara sobre curvas de luz que tienen comportamiento de transito Mandel-Agol
mask_transit = np.load("data/mask_transit_LC.npy") 
mask_transit
np.shape(mask_transit)
# Out:
# (8054,)

# %% [markdown]
# #### Etiquetas en datos entrenados/transitos

# %%
df_aux = pd.read_csv("../../KOI_Data/kepler_dataset.csv")

plt.figure(figsize=(10,5))
sns.countplot(df_aux["NExScI Disposition"],hue=mask_transit)
plt.title("Distribucion de etiquetas en usados en entrenar")
plt.show()

# %%
df_meta_transit = df_meta_obj[mask_transit]

Y_transit = Y_values[mask_transit] 

from sklearn.preprocessing import StandardScaler, RobustScaler
Ystd_transit = StandardScaler().fit_transform(Y_transit)
Ystd_transit.shape
# Out:
# (4317, 8)

# %%
### boxplot de las variables..
aux_pl = df_meta_obj.drop(["Time of Transit Epoch", "Period"], axis=1).columns
plt.figure(figsize=(15,5))
plt.boxplot(Ystd_transit)
plt.xticks(np.arange(Ystd_transit.shape[1])+1, aux_pl )
plt.show()
aux_df = pd.DataFrame(Ystd_transit)
aux_df.columns = aux_pl
aux_df.describe()
# Out:
#            Duration           r/R           a/R   Inclination  \
# count  4.317000e+03  4.317000e+03  4.317000e+03  4.317000e+03
# mean   2.237137e-15 -1.021839e-14 -1.393424e-15  1.044820e-13
# std    1.000116e+00  1.000116e+00  1.000116e+00  1.000116e+00
# min   -1.342305e+00 -5.944392e-01 -6.771879e-01 -1.454917e+01
# 25%   -6.330545e-01 -3.764355e-01 -4.955450e-01 -5.419423e-02
# 50%   -2.623250e-01 -2.310997e-01 -3.158230e-01  2.991997e-01
# 75%    3.043375e-01 -1.309604e-02  6.238814e-02  4.564794e-01
# max    1.025868e+01  1.653096e+01  1.819996e+01  5.050225e-01
#
#        Impact Parameter  Fitted Stellar Density  Limb Darkening Coeff1  \
# count      4.317000e+03            4.317000e+03           4.317000e+03
# mean       6.843418e-16            1.186990e-16          -6.799076e-14
# std        1.000116e+00            1.000116e+00           1.000116e+00
# min       -1.286820e+00           -2.359379e-01          -2.152344e+00
# ...

# %% [markdown]
# ### Create dataset

# %% [markdown]
# #### Representación Global Folded ya está generada y guardada

# %%
# !ls data/
# Out:
# LC_global_200T.npy   LC_globalA_300T.npy     Time_global_200T.npy
# LC_global_300T.npy   LC_globalA_400T.npy     Time_global_300T.npy
# LC_global_400T.npy   LC_globalA_500T.npy     Time_global_400T.npy
# LC_global_500T.npy   LC_globalA_600T.npy     Time_global_500T.npy
# LC_global_600T.npy   mask_transit_LC.npy     Time_global_600T.npy
# LC_globalA_200T.npy  mask_transit_LC_v2.npy

# %%
T = 300 #elegir cantidad de puntos en curva de luz

# %%
X_fold_lc = np.load("data/LC_global_%dT.npy"%T)     # curva de luz
X_fold_lc_aug = np.load("data/LC_globalA_%dT.npy"%T)# curva de luz dada vuelta (como data augmented)
X_fold_time = np.load("data/Time_global_%dT.npy"%T) # delta de los tiempos en la representacion de la curva luz
X_fold_lc.shape
# Out:
# (8054, 300)

# %%
## NEW : set mask
X_fold_lc_tr = X_fold_lc[mask_transit]
X_fold_lc_aug_tr = X_fold_lc_aug[mask_transit]
X_fold_time_tr = X_fold_time[mask_transit]
N,T = X_fold_lc_tr.shape
print(N,T)
# Out:
# 4317 300

# %%
## NEW : set mask
X_data_t = np.concatenate([X_fold_time_tr, X_fold_time_tr], axis=0)
X_data = np.concatenate([X_fold_lc_tr, X_fold_lc_aug_tr], axis=0)

if Ystd_transit.shape[0] != X_data.shape[0]:
    Ystd_transit = np.tile(Ystd_transit, (2,1)) #utilizando data augmentation

X_data_t = np.expand_dims(X_data_t, axis=-1)
X_data = np.expand_dims(X_data, axis=-1)

print("X train shape: ",X_data.shape)
print("X train time shape: ",X_data_t.shape)
print("Y train shape: ",Ystd_transit.shape)
# Out:
# X train shape:  (8634, 300, 1)
# X train time shape:  (8634, 300, 1)
# Y train shape:  (8634, 8)

# %% [markdown]
# ### Escalar

# %%
#NEW:
def scaled_MSE(y_true,y_pred,scale):
    return np.mean(np.mean( scale**2 * np.mean( (y_true - y_pred)**2 , axis=1), axis=0))

S_data = 1/np.std(X_data, axis=1)
S_mu = np.mean(S_data)
S_std = np.std(S_data) 

X_data = X_data*S_data[:,None,:]
X_data.shape
# Out:
# (8634, 300, 1)

# %% [markdown]
# ### Keras models

# %%
import keras
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import *

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import matplotlib.pyplot as plt


########################## EVALUACION #######################################
def get_res(x,xhat):
    x = np.squeeze(x)
    xhat = np.squeeze(xhat)
    return x - xhat

def RMSE_LC(x, xhat, res=[]):
    if len(res) == 0:
        res = get_res(x, xhat)
    return np.mean( np.sqrt(np.mean(np.square(res), axis=-1)) )

def MSE_LC(x, xhat, res=[]):
    if len(res) == 0:
        res = get_res(x, xhat)
    return np.mean(np.mean( np.square(res), axis=-1))

def MAE_LC(x, xhat, res=[]):
    if len(res) == 0:
        res = get_res(x, xhat)
    return np.mean( np.mean( np.abs(res), axis=-1))

def evaluate_reconst(x,xhat):
    print("----- EVALUANDO RECONSTRUCCION DE LA CURVA -----")
    res = get_res(x, xhat)
    plt.figure(figsize=(8,5))
    sns.distplot(res.flatten())
    plt.title("Distribucion de residuos promedio")
    plt.show()
    
    print("MSE      = ",MSE_LC(None,None, res))
    print("RMSE (+-)= ",RMSE_LC(None,None, res))
    print("MAE  (+-)= ",MAE_LC(None,None, res))
    
    print("--------- Smoothness ------------")
    xhat = np.squeeze(xhat)
    A = np.mean(np.apply_along_axis(autocorr_func, 1, xhat)[:,1])
    print("AutoCorr lag-one = ",A)
    M = np.mean(np.apply_along_axis(mean_diff, 1, xhat))
    print("Diff MEAN = ",M)
    S = np.mean(np.apply_along_axis(std_diff, 1, xhat))
    print("Diff STD = ",S)
    print("--------- Smoothness ------------")
        
def autocorr_func(x):
    #FATS: https://arxiv.org/pdf/1506.00010.pdf
    if np.sum(x) == 0:
        return 0
    inp = x - np.mean(x)
    result = np.correlate(inp, inp, mode='full')
    return result[len(x)-1:]/np.var(x, ddof=len(x)-1)

def std_diff(x):
    if np.sum(x) == 0:
        return 0
    aux = np.abs(np.diff(x, axis=-1))
    return np.std(aux)#/np.mean(aux)

def mean_diff(x):
    if np.sum(x) == 0:
        return 0
    aux = np.abs(np.diff(x, axis=-1))
    return np.mean(aux)#/np.mean(aux)

def plot_n_lc(real_lc, decoded_lc, n = 10, s=None):
    for _ in range(n):
        n_sampled = np.random.randint(0, real_lc.shape[0])
        
        if s !=None:
            print("Real scale = %f\nPred scale = %f"%(s[0][n_sampled], s[1][n_sampled] ))
        f, (ax1, ax2) = plt.subplots(1, 2, sharex=True,figsize= (15,5))
        ax1.plot(real_lc[n_sampled], 'b.-')
        ax1.set_title("Real")
        ax2.plot(decoded_lc[n_sampled], 'b.-')
        ax2.set_title("Reconstructed")
        plt.show()  

        plt.figure(figsize=(15,5))
        plt.plot(real_lc[n_sampled], 'bo-', label="Real")
        plt.plot(decoded_lc[n_sampled], 'g*-', label="Reconstructed")
        plt.title("Over data "+str(n_sampled))
        plt.legend()
        plt.show()
        print("----------------------------------------------------------------")

# %%
latent_dim = 32
_, T, channels = X_data.shape
D_dim = Ystd_transit.shape[1] #cantidad de valores en representacion condicional

# %% [markdown]
# ## Regular VAE

# %%
l = 0.001

# %%
def KL_loss(y_true, y_pred):
    return - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)

#### IF THIS IS USED,, KL WEIGHT NEEDED TO BE LOW ######
def MSE_loss(y_true, y_pred):
    v = K.mean( K.square( y_true - y_pred ), axis=1) #on time axis..    
    return K.flatten(v)

#### HAS TO BE USED IN ORDER TO LEARN #######
def SSE_loss(y_true, y_pred):
    v = K.sum( K.square( y_true - y_pred ), axis=1) #on time axis..    
    return K.flatten(v)

def vae_loss(y_true, y_pred):
    return MSE_loss(y_true, y_pred) + l*KL_loss(y_true, y_pred)

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], K.shape(z_mean)[1]), mean=0., stddev=1.)
    return z_mean + K.exp(0.5*z_log_var) * epsilon

# %%
x_lc = Input(shape = (T, channels) , name="LC_inp")
x_t = Input(shape = (T, channels) , name ="T_inp")

x = Concatenate(axis=-1)([x_t, x_lc]) #add time encode

#f1 = Bidirectional(CuDNNGRU(64, return_sequences=True))(x) #bidirectional
f1 = Bidirectional(GRU(64, return_sequences=True))(x) #bidirectional
#f1 = Bidirectional(CuDNNGRU(64, return_sequences=False))(f1) #bidirectional
f1 = Bidirectional(GRU(64, return_sequences=False))(f1) #bidirectional

z_mean = Dense(latent_dim,activation='linear')(f1)
z_log_var = Dense(latent_dim,activation='linear')(f1)

encoder = Model([x_t, x_lc], z_mean, name="encoder")
z = Lambda(sampling, output_shape=(latent_dim,), name='sample')([z_mean, z_log_var])
samp_encoder = Model([x_t, x_lc], z, name="encoder_sampling")


decoder_input = Input(shape=(latent_dim,))

decode = RepeatVector(T)(decoder_input)

decode = Concatenate(axis=-1)([x_t, decode]) #add time decode

#decode = Bidirectional(CuDNNGRU(64, return_sequences=True))(decode) #bidirectional
decode = Bidirectional(GRU(64, return_sequences=True))(decode) #bidirectional
#decode = Bidirectional(CuDNNGRU(64, return_sequences=True))(decode) #bidirectional
decode = Bidirectional(GRU(64, return_sequences=True))(decode) #bidirectional

decode = TimeDistributed(Dense(1, activation='linear'))(decode)
generator = Model([x_t, decoder_input], decode, name="generator")

# instantiate VAE model
out = generator([x_t, samp_encoder([x_t, x_lc]) ])
vae = Model([x_t, x_lc], out)

vae.compile(optimizer='adam', loss=vae_loss, metrics = [KL_loss, MSE_loss])
vae.summary()

# %%
batch_size = 128
vae.fit([X_data_t,X_data], X_data, epochs=200, batch_size=batch_size, validation_split=0.2)

# %%
print("Errores ",vae.evaluate([X_data_t,X_data], X_data, batch_size=512))
X_data_hat = vae.predict([X_data_t,X_data], batch_size=512)
plot_n_lc(X_data[:,:,0], X_data_hat, n= 10)

# %%
## generate random
n = 20
z_sampleds = np.random.normal(0, 1, size=(n,1,latent_dim))
time_i = X_data_t[0][None,:,:] #el tiempo del primer dato para probar samples en eso

for i in range(n):
    x_decoded = generator.predict([time_i, z_sampleds[i]])

    plt.figure(figsize=(10,5))
    plt.plot(x_decoded[0,:], '.-')
    plt.show()
    
    
plt.figure(figsize=(10,5))
for i in range(n):    
    x_decoded = generator.predict([time_i, z_sampleds[i]])

    plt.plot(x_decoded[0,:], '.-')
plt.show()

# %% [markdown]
# ## CONDITIONAL VAE
# links que encontré:
# * https://github.com/nnormandin/Conditional_VAE
# * https://wiseodd.github.io/techblog/2016/12/17/conditional-vae/

# %% [markdown]
# # Conditional VAE (Patricio)
# -- UPDATE EN LA IMPLEMENTTACIÓN... CORREGIDO CIERTAS COSAS

# %%
# CVAE

x_lc = Input(shape = (T, channels) , name="LC_inp")
x_t = Input(shape = (T, channels) , name ="T_inp")
y_lc = Input(shape = (D_dim,) , name ="Meta_inp")

#como es recurrente es necesario repetir la metadata en cada instante de tiempo.. 
#-- o agregarlo aparte en (return_seq false)
cond_rep = RepeatVector(T, name="Meta_rep")(y_lc)

x = Concatenate(axis=-1)([x_lc, x_t, cond_rep]) #has to be concatenate on axis -1

f1 = Bidirectional(CuDNNGRU(64, return_sequences=True))(x) #bidirectional
f1 = Bidirectional(CuDNNGRU(64, return_sequences=False))(f1) #bidirectional
z_mean = Dense(latent_dim,activation='linear')(f1)
z_log_var = Dense(latent_dim,activation='linear')(f1)

encoder = Model([x_t, x_lc, y_lc], z_mean, name="encoder")
z = Lambda(sampling, output_shape=(latent_dim,), name='sample')([z_mean, z_log_var])
samp_encoder = Model([x_t, x_lc, y_lc], z, name="encoder_sampling")


decoder_input = Input(shape=(latent_dim,), name="dc_inp")
decoder_inp_rep = RepeatVector(T, name="Enc_rep")(decoder_input)

decode = Concatenate(axis=-1)([x_t, decoder_inp_rep, cond_rep]) #add time and metadata to decode
#si afuera se agrega .. habria que concatenar en reteurn false..

decode = Bidirectional(CuDNNGRU(64, return_sequences=True))(decode) #bidirectional
#decode = Bidirectional(GRU(64, return_sequences=True))(decode) #bidirectional
decode = Bidirectional(CuDNNGRU(64, return_sequences=True))(decode) #bidirectional

decode = TimeDistributed(Dense(1, activation='linear'))(decode)
generator = Model([x_t, decoder_input, y_lc], decode, name="generator")

# instantiate VAE model
out = generator([x_t, samp_encoder([x_t, x_lc,y_lc]), y_lc ])
Cvae = Model([x_t, x_lc, y_lc], out)

Cvae.compile(optimizer='adam', loss=vae_loss, metrics = [KL_loss, MSE_loss])
Cvae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# T_inp (InputLayer)              (None, 300, 1)       0
# __________________________________________________________________________________________________
# LC_inp (InputLayer)             (None, 300, 1)       0
# __________________________________________________________________________________________________
# Meta_inp (InputLayer)           (None, 8)            0
# __________________________________________________________________________________________________
# encoder_sampling (Model)        (None, 32)           111936      T_inp[0][0]
#                                                                  LC_inp[0][0]
#                                                                  Meta_inp[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# seria necesario hacer un esquema o dibujo para entender.. la metadata se repite por cada instante de tiempo para hacer las codificaciones y reconstrucciones necesarias.. (le da la información de la metadata a cada instante..)

# %%
batch_size = 64
#Cvae.fit([X_data_t, X_data, Ystd_transit], X_data, epochs=200, batch_size=batch_size, validation_split=0.2)
Cvae.fit([X_data_t, X_data, Ystd_transit], X_data, epochs=300, batch_size=batch_size)
# Out:
# Epoch 1/300
# 8634/8634 [==============================] - 32s 4ms/step - loss: 1.0165 - KL_loss: 0.7959 - MSE_loss: 1.0157
# Epoch 2/300
# 8634/8634 [==============================] - 26s 3ms/step - loss: 1.0033 - KL_loss: 0.3059 - MSE_loss: 1.0030
# Epoch 3/300
# 8634/8634 [==============================] - 26s 3ms/step - loss: 1.0026 - KL_loss: 0.1713 - MSE_loss: 1.0024
# Epoch 4/300
# 8634/8634 [==============================] - 26s 3ms/step - loss: 1.0023 - KL_loss: 0.1287 - MSE_loss: 1.0022
# Epoch 5/300
# 8634/8634 [==============================] - 26s 3ms/step - loss: 1.0021 - KL_loss: 0.1210 - MSE_loss: 1.0020
# Epoch 6/300
# 8634/8634 [==============================] - 26s 3ms/step - loss: 1.0020 - KL_loss: 0.1531 - MSE_loss: 1.0018
# Epoch 7/300
# 8634/8634 [==============================] - 26s 3ms/step - loss: 1.0017 - KL_loss: 0.2186 - MSE_loss: 1.0015
# Epoch 8/300
# ...

# %%
X_data_hat = Cvae.predict([X_data_t[:N], X_data[:N], Ystd_transit[:N]], batch_size=512)

# %%
evaluate_reconst(X_data[:N], X_data_hat)

plot_n_lc(X_data[:N,:,0], X_data_hat, n= 15)
# Out:
# ----- EVALUANDO RECONSTRUCCION DE LA CURVA -----
# /home/casapanshop/anaconda2/envs/py3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# MSE      =  0.5415959415285867
# RMSE (+-)=  0.6945604476518754
# MAE  (+-)=  0.4856054914775199
# --------- Smoothness ------------
# AutoCorr lag-one =  0.5918929
# Diff MEAN =  0.081334375
# Diff STD =  0.4006958
# --------- Smoothness ------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ----------------------------------------------------------------
# ...

# %%
Cvae.save_weights("./models/%dT_%dD_%de_C-VAE.h5"%(T,latent_dim,300))

# %% [markdown]
# ## Generar:
# * ver los casos en que muere MA (depende del a libreria)

# %%
import pysyzygy as ps

def transform_delta(t):
    return np.hstack([[0],np.diff(t)])

def set_time_T(t,T):
    return np.interp(np.linspace(0, len(t),T), np.arange(len(t)), t)

from algo import simulate_MA
        
MA_sim_names = ["Period","Duration","T0","r/R", "a/R", "Inclination", "Impact Parameter", "Limb Darkening Coeff1","Limb Darkening Coeff2"]

meta_T_names = MA_sim_names[:-2] +["Fitted Stellar Density"]

# %%
## generate random
n = 20

for _ in range(n):
    n_sampled = np.random.randint(0, N)
    
    time_i = np.cumsum(X_data_t[n_sampled,:,0])

    f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex=True,figsize= (17,5))
    ax1.plot(time_i, X_data[n_sampled], 'b.-')
    ax1.set_title("Real")
    
    #Simular MA
    sim_dat = {v: df_meta_transit.iloc[n_sampled][v] for v in MA_sim_names if v != "T0"} #get metadata
    sim_dat["T0"] = time_i[int(np.round(len(time_i)/2))] #trabajando con folds global ...
    x_MA = (simulate_MA(time_i, sim_dat)-1)*S_data[n_sampled]
    
    ax2.plot(time_i, x_MA, 'b.-')
    ax2.set_title("Mandel-Agol")
    
    #Simular con C_VAE
    z_sampled = np.random.normal(0, 1, size=(1,latent_dim))
    Dtime_i = transform_delta(time_i)[None,:,None]
    meta_T = Ystd_transit[n_sampled][None,:]
    x_CVAE = generator.predict([Dtime_i, z_sampled, meta_T] )
    
    ax3.plot(time_i, x_CVAE[0], 'b.-')
    ax3.set_title("C-VAE")
    plt.show()   

    plt.figure(figsize=(15,5))
    plt.plot(time_i, X_data[n_sampled], 'bo-', label="Real")
    plt.plot(time_i, x_CVAE[0], 'g*-', label="C-VAE")
    plt.title("Over data "+str(n_sampled))
    plt.legend()
    plt.show()
    print("----------------------------------------------------------------")
# Out:
#      Period  Duration        T0    r/R    a/R  Inclination  Impact Parameter  \
# 0  7.053527  0.099925  3.526764  0.035  22.94        89.57             0.172
#
#    Limb Darkening Coeff1  Limb Darkening Coeff2
# 0                  0.508                  0.224
# ----------------------------------------------------------------
#      Period  Duration        T0    r/R   a/R  Inclination  Impact Parameter  \
# 0  2.151215   0.09275  1.075607  0.016  7.33        88.16             0.235
#
#    Limb Darkening Coeff1  Limb Darkening Coeff2
# 0                  0.586                  0.144
# ----------------------------------------------------------------
#       Period  Duration         T0    r/R   a/R  Inclination  Impact Parameter  \
# 0  80.410378  0.145292  40.205189  0.027  82.7        89.37             0.913
#
#    Limb Darkening Coeff1  Limb Darkening Coeff2
# 0                  0.398                  0.265
# ----------------------------------------------------------------
# ...

# %% [markdown]
# ### Random Normal Metadata con tiepo del dato

# %%
    meta_T = np.random.normal(0,1 ,size=(1,8)) #Ystd_transit[n_sampled][None,:]

# %% [markdown]
# ### Sobre un mismo dato generar hartas curvas
# comparar con Mandel-Agol

# %%
n_sampled = np.random.randint(0, N)
display(pd.DataFrame(df_meta_transit.iloc[n_sampled]).T)

time_i = np.cumsum(X_data_t[n_sampled,:,0])

plt.figure(figsize=(10,4))
plt.plot(time_i, X_data[n_sampled], 'b.-')
plt.title("Real")
plt.show()

Dtime_i = transform_delta(time_i)[None,:,None]
meta_T = Ystd_transit[n_sampled][None,:]

G =4
f, axx = plt.subplots(1, G, sharex=True,figsize= (17,4))
aux = []
for g in range(G):
    z_sampled = np.random.normal(0, 1, size=(1,latent_dim))
    x_CVAE = generator.predict([Dtime_i, z_sampled, meta_T] )[0,:,0]
    aux.append(x_CVAE)
    axx[g].plot(time_i, x_CVAE, 'b.-')
    axx[g].set_title("Generacion"+str(g))
plt.show()

plt.figure(figsize=(12,5))
for g in range(G):
    plt.plot(time_i, aux[g], '.-', label="Gen "+str(g))
    plt.title("Superpuestas")
    plt.legend()
plt.show()
# Out:
#         Period  Duration  Time of Transit Epoch    r/R     a/R  Inclination  \
# 3094  3.167893  0.090892             172.147959  0.026  11.389        89.87
#
#       Impact Parameter  Fitted Stellar Density     Teq  Limb Darkening Coeff1  \
# 3094             0.026                 2.78453  1221.0                  0.359
#
#       Limb Darkening Coeff2    Teff  Stellar Radius  Stellar Mass
# 3094                  0.287  5895.0            0.94         1.026

# %%
n_sampled = np.random.randint(0, N)
display(pd.DataFrame(df_meta_transit.iloc[n_sampled]).T)

time_i = np.cumsum(X_data_t[n_sampled,:,0])

plt.figure(figsize=(10,4))
plt.plot(time_i, X_data[n_sampled], 'b.-')
plt.title("Real")
plt.show()

Dtime_i = transform_delta(time_i)[None,:,None]
meta_T = Ystd_transit[n_sampled][None,:]

G =4
f, axx = plt.subplots(1, G, sharex=True,figsize= (17,4))
aux = []
for g in range(G):
    z_sampled = np.random.normal(0, 1, size=(1,latent_dim))
    x_CVAE = generator.predict([Dtime_i, z_sampled, meta_T] )[0,:,0]
    aux.append(x_CVAE)
    axx[g].plot(time_i, x_CVAE, 'b.-')
    axx[g].set_title("Generacion"+str(g))
plt.show()

plt.figure(figsize=(12,5))
for g in range(G):
    plt.plot(time_i, aux[g], '.-', label="Gen "+str(g))
    plt.title("Superpuestas")
    plt.legend()
plt.show()
# Out:
#          Period  Duration  Time of Transit Epoch    r/R   a/R  Inclination  \
# 1675  17.340873  0.141583              138.96694  0.012  34.5        89.19
#
#       Impact Parameter  Fitted Stellar Density    Teq  Limb Darkening Coeff1  \
# 1675             0.489                 2.59392  755.0                  0.359
#
#       Limb Darkening Coeff2    Teff  Stellar Radius  Stellar Mass
# 1675                  0.287  5885.0           1.111         1.004

# %% [markdown]
# ### fuera de tiempo??
# modelo solo aprende transitos en fase

# %%
n_sampled = np.random.randint(0, N)
display(pd.DataFrame(df_meta_transit.iloc[n_sampled]).T)

time_i = np.cumsum(np.squeeze(X_data_t[n_sampled]))

#duplicar tiempo (debieran aparcer 2 transitos)
time_i = np.concatenate([time_i, time_i+time_i.max()])
data = np.concatenate([X_data[n_sampled,:,0],X_data[n_sampled,:,0]] )

plt.figure(figsize=(10,4))
plt.plot(time_i, data , 'b.-')
plt.title("Real")
plt.show()

time_i_bT = set_time_T(time_i, T) #quizas sea necesario hacerlo siempre..

Dtime_i = transform_delta(time_i_bT)[None,:,None]
meta_T = Ystd_transit[n_sampled][None,:]

#f, axx = plt.subplots(1, G, sharex=True,figsize= (17,4))
z_sampled = np.random.normal(0, 1, size=(1,latent_dim))
x_CVAE = generator.predict([Dtime_i, z_sampled, meta_T] )[0,:,0]
plt.plot(time_i_bT, x_CVAE, 'b.-')
plt.title("Generacion "+str(g))
plt.show()
# Out:
#         Period  Duration  Time of Transit Epoch    r/R     a/R  Inclination  \
# 3415  4.347289    0.0876              172.23343  0.019  16.107        89.91
#
#       Impact Parameter  Fitted Stellar Density     Teq  Limb Darkening Coeff1  \
# 3415             0.025                 4.18264  1174.0                  0.419
#
#       Limb Darkening Coeff2    Teff  Stellar Radius  Stellar Mass
# 3415                  0.256  5754.0           1.122         1.014

# %% [markdown]
# ### Sobre errores de MA

# %%
for n_sampled in range(N):    
    time_i = np.cumsum(X_data_t[n_sampled,:,0])

    #Simular MA
    sim_dat = {v: df_meta_transit.iloc[n_sampled][v] for v in MA_sim_names if v != "T0"} #get metadata
    sim_dat["T0"] = time_i[int(np.round(len(time_i)/2))] #trabajando con folds global ...
    aux_MA = simulate_MA(time_i, sim_dat, plot_m=False)
    
    if np.std(aux_MA) == 0:
        x_MA = (aux_MA-1)*S_data[n_sampled]
        
        f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex=True,figsize= (17,5))
        ax1.plot(time_i, X_data[n_sampled], 'b.-')
        ax1.set_title("Real")

        ax2.plot(time_i, x_MA, 'b.-')
        ax2.set_title("Mandel-Agol")

        #Simular con C_VAE
        z_sampled = np.random.normal(0, 1, size=(1,latent_dim))
        Dtime_i = transform_delta(time_i)[None,:,None]
        meta_T = Ystd_transit[n_sampled][None,:]
        x_CVAE = generator.predict([Dtime_i, z_sampled, meta_T] )

        ax3.plot(time_i, x_CVAE[0], 'b.-')
        ax3.set_title("C-VAE")
        plt.show()   

        plt.figure(figsize=(15,5))
        plt.plot(time_i, X_data[n_sampled], 'bo-', label="Real")
        plt.plot(time_i, x_CVAE[0], 'g*-', label="C-VAE")
        plt.title("Over data "+str(n_sampled))
        plt.legend()
        plt.show()
        print("----------------------------------------------------------------")
# Out:
# ERROR GENERACION DE CURVA:  Error in elliptic integral function RC().
# ----------------------------------------------------------------
# ERROR GENERACION DE CURVA:  Object does not transit the star.
# ----------------------------------------------------------------

# %%
## generar sobre todos.. no solo transitos.. :o

# %%
### Measure error

# %%
X_train_MA = X_MA[mask_transit]
X_train_MA = (X_train_MA-1)*S_train[:N] #M-A esta en la escala original de los datos..
X_train_MA.shape

# %%
evaluate_reconst(X_train[:N], X_train_MA)

plot_n_lc(X_train[:N,:,0], X_train_MA, n= 15)
