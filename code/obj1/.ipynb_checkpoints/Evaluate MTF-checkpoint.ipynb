# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import gc, os, sys
gc.collect()

dirpath = os.getcwd().split("code")[0]+"code/"
sys.path.append(dirpath)
from pre_process import clean_LC,generate_representation
from evaluation import calculate_metrics, evaluate_metadata, evaluate_metadata_raw

    
folder = "../../KOI_Data/"
folder_lc = "/work/work_teamEXOPLANET/KOI_LC/"

# %%
fold = "../../KOI_Data/"
df_sets = pd.read_csv(fold+"/koi_sets.csv") 
mask_train = (df_sets["Set"] == "Train").values
mask_test = (df_sets["Set"] == "Test").values
mask_unlabeled = (df_sets["Set"] == "Unlabeled").values


df_meta = pd.read_csv(fold+"/koi_metadata.csv")
df_meta_train = df_meta[mask_train]
df_meta_test = df_meta[mask_test]
df_meta_unb = df_meta[mask_unlabeled]

df_meta_train.head()
# Out:
#      KOI Name NExScI Disposition   Kepler Name      Period  \
# 0   K00889.01          CONFIRMED   Kepler-75 b    8.884923
# 1   K01009.01     FALSE POSITIVE           NaN    5.092465
# 7   K07622.01     FALSE POSITIVE           NaN   36.267167
# 9   K00998.01     FALSE POSITIVE           NaN  161.788327
# 10  K00992.01          CONFIRMED  Kepler-745 b    9.931463
#
#     Time of Transit Epoch  First Transit Time (BJD)  Impact Parameter  \
# 0              169.991686               2455002.992             0.069
# 1              357.535940               2455190.536             0.161
# 7              155.081300               2454988.081             0.214
# 9              214.039000               2455047.039             0.267
# 10             136.491280               2454969.491             0.037
#
#     Duration  Transit Depth    r/R  ...    Teff  log(g)  Metallicity  \
# 0    2.07004        16053.4  0.114  ...  5332.0   4.500        -0.08
# ...

# %%
## load mtfs
s = 16

folder = "/work/work_teamEXOPLANET/"
MTF_data = np.load(folder+'/MTF_margarita/no_invertidos/MTF_u%d_d%d.npy'%(s,s))  
TIME_data = np.load(folder+'/MTF_gabo/npys/MTF_time_u%d_d%d.npy'%(s,s))  

#folder = "/media/fmena/Respaldo/KOI_LC/MTF/"
#MTF_data = np.load(folder+'/normal/MTF_u%d_d%d.npy'%(s,s))  
#TIME_data = np.load(folder+'/time/MTF_time_u%d_d%d.npy'%(s,s))  

MTF_data.shape
# Out:
# <ipython-input-37-06851934049f>:27: NumbaWarning: Cannot cache compiled function "det_state_2ways" as it uses dynamic globals (such as ctypes pointers and large global arrays)
#   @njit(parallel=False, cache=True, fastmath=True)
# (8054, 32, 32)

# %%
## load light curves

time_kepler = np.load(folder_lc+"npy/KOI_LC_time.npy")
process_lc = np.load(folder_lc+'/cleaned/LC_kepler_processed.npy')
N, T = time_kepler.shape
print((N,T))
# Out:
# (8054, 71427)
# recuperando curva 1
# Cantidad de tramos:  796
# Largo promedio de tramos:  80.82663316582915
# Mediana de largo de tramos:  79.0
# Min de largo de tramos:  2
# Max de largo de tramos:  149
# recuperando curva 1
# Cantidad de tramos:  707
# Largo promedio de tramos:  77.06506364922207
# Mediana de largo de tramos:  72.0
# Min de largo de tramos:  2
# Max de largo de tramos:  146
# recuperando curva 1
# Cantidad de tramos:  803
# Largo promedio de tramos:  79.91158156911581
# Mediana de largo de tramos:  78.0
# Min de largo de tramos:  2
# Max de largo de tramos:  149
# recuperando curva 1
# Cantidad de tramos:  788
# Largo promedio de tramos:  81.66116751269035
# Mediana de largo de tramos:  84.0
# Min de largo de tramos:  2
# Max de largo de tramos:  146
# recuperando curva 1
# Cantidad de tramos:  819
# Largo promedio de tramos:  78.4993894993895
# Mediana de largo de tramos:  76.0
# Min de largo de tramos:  2
# Max de largo de tramos:  149
# recuperando curva 1
# ...

# %%
def prepare_lc(fluxs): #dividir por min
    fluxs = np.asarray(fluxs)
    return fluxs/np.abs(np.nanmin(fluxs))
def extract_nans(fluxs, plot=True):
    ###extrae los nans y deja tramos de valores continuos
    lc_wind_nan = []
    lengths = []

    sublist = [] #para que sepa que el tipo es float
    for value in fluxs:
        if np.isnan(value) and len(sublist) != 0:
            if len(sublist) != 1: ##borrar tramos de largo 1??
                lc_wind_nan.append(np.asarray(sublist))
                lengths.append(len(sublist))
            sublist = [] #para que sepa que el tipo es float
        elif np.isnan(value) and len(sublist) == 0:
            continue
        else: #if value not nan
            sublist.append(value) 

    if plot:
        lengths = np.asarray(lengths)   
        print("Cantidad de tramos: ",len(lengths))
        print("Largo promedio de tramos: ", np.mean(lengths))
        print("Mediana de largo de tramos: ", np.median(lengths))
        print("Min de largo de tramos: ", np.min(lengths))
        print("Max de largo de tramos: ", np.max(lengths))
    return lc_wind_nan


i=0
for lc_our_detrend in process_lc[:20]:   
    print ("recuperando curva",i+1)
    fluxs = prepare_lc(lc_our_detrend) #divide by min
    lc_tramos =  extract_nans(fluxs) #extract nans

# %%
from code_MTF import det_state_2ways
states =    det_state_2ways(1,-1, n_sta_up=s, n_sta_low=s) 

from numba import njit
@njit(parallel=False, cache=True, fastmath=True)  #no se pudo paralelizar por el acceso a lista "ind -1"
def evaluate_MTF(matrix, time_series, states):
    
    prob_ev = []
    for ind in range(1,len(time_series)):
        init_s = det_celda(time_series[ind-1], states)
        fin_s = det_celda(time_series[ind], states)
        
        prob_ev.append(matrix[init_s,fin_s])
        
    return prob_ev

# %%
fluxs = prepare_lc(process_lc[0]) #divide by min

stop = 200

plt.plot(fluxs[:stop] ,".-")
plt.show()

v = evaluate_MTF(MTF_data[0], fluxs[:stop], states)
plt.plot(v, ".-")
plt.show()

# %%
fluxs = prepare_lc(process_lc[0]) #divide by min
lc_tramos =  extract_nans(fluxs) #extract nans


values = []
for tramo in lc_tramos:
    if len(tramo) > 5: # a minimum value
        v = evaluate_MTF(MTF_data[0], tramo, states)
        #values.append(np.prod(v))
        values.append(np.sum(np.log(v)))
    else:
        values.append(1)

idx_mins = np.argsort(values)[:10] #less probably that happens
idx_mins
# Out:
# Cantidad de tramos:  796
# Largo promedio de tramos:  80.82663316582915
# Mediana de largo de tramos:  79.0
# Min de largo de tramos:  2
# Max de largo de tramos:  149
# array([712, 419, 501, 237, 644, 673, 443, 450, 446, 233])

# %%
for idx_min in idx_mins:
    plt.plot(lc_tramos[idx_min])
    plt.show()

    v = evaluate_MTF(MTF_data[0], lc_tramos[idx_min], states)
    plt.plot(v)
    plt.show()

# %%
## evaluar continuo

# %%
plt.plot(lc_tramos[2])
plt.show()

v = evaluate_MTF(MTF_data[0], lc_tramos[2], states)
plt.plot(v)
plt.show()
