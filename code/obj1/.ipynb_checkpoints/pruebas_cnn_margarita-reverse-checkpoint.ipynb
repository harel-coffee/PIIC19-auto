# %%
#Save con Nodos
import os
from keras.models import load_model
import itertools
from matplotlib import pyplot as plt
from keras.utils import to_categorical
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import os, sys
dirpath = os.getcwd().split("code")[0]+"code/"
sys.path.append(dirpath)
from sklearn.utils import class_weight
import numpy as np

from evaluation import calculate_metrics
from sklearn.metrics import confusion_matrix,accuracy_score
import pandas as pd
from keras.regularizers import l2
from keras.activations import tanh
from keras.models import Sequential
from keras.layers import *
from keras.losses import categorical_crossentropy,binary_crossentropy
from keras.optimizers import SGD
from keras.callbacks import LearningRateScheduler
from keras import optimizers
from keras import backend as K
from time import time
import random
from random import shuffle,seed
from sklearn.metrics import classification_report
import math
from keras.regularizers import l2
from keras.callbacks import LearningRateScheduler
from keras.callbacks import EarlyStopping
from keras.backend import eval
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,f1_score, confusion_matrix
from sklearn.preprocessing import normalize
import time

def plot_confusion_matrix(cm, target_names, title='Confusion matrix (f1-score)',cmap=None, normalize=True):
    
    import itertools
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model.add(MaxPooling2D((2,2), strides=(1,1)))
model.add(Dropout(0.1))
model.add(Conv2D(128, (5, 5), strides=(1, 1), activation="relu", padding="same"))
model.add(Conv2D(256, (5, 5), strides=(1, 1), activation="relu", padding="same"))
#model.add(Flatten())
model.add(GlobalAveragePooling2D())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 02:29:56.892629 140316414314304 deprecation_wrapper.py:119] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 02:29:56.953380 140316414314304 deprecation_wrapper.py:119] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 02:29:56.989979 140316414314304 deprecation_wrapper.py:119] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0719 02:29:57.041554 140316414314304 deprecation_wrapper.py:119] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0719 02:29:57.047049 140316414314304 deprecation_wrapper.py:119] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0719 02:29:57.064478 140316414314304 deprecation.py:506] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0719 02:29:57.201309 140316414314304 deprecation_wrapper.py:119] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0719 02:29:57.228829 140316414314304 deprecation_wrapper.py:119] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0719 02:29:57.233934 140316414314304 deprecation.py:323] From /users/mbugueno/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 15, 15, 64)        640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       204928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 256)       819456
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,419,777
# Trainable params: 1,419,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1 = Sequential()
model1.add(Conv2D(64, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model1.add(MaxPooling2D((2,2)))
model1.add(Dropout(0.1))
model1.add(Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"))
model1.add(Conv2D(256, (3, 3), strides=(1, 1), activation="relu", padding="same"))
#model1.add(Flatten())
model1.add(GlobalAveragePooling2D())
model1.add(Dense(256,activation='relu'))
model1.add(Dropout(0.2))
model1.add(Dense(128, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))
model1.summary()

model1.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 15, 15, 64)        640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 468,481
# Trainable params: 468,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
fold = "../../KOI_Data/"
df_sets = pd.read_csv(fold+"/koi_sets_unb.csv") 
mask_train = (df_sets["Set"] == "Train").values
mask_test = (df_sets["Set"] == "Test").values
mask_unlabeled = (df_sets["Set"] == "Unlabeled").values
df_sets.head()
# Out:
#     KOI Name        Set
# 0  K00889.01       Test
# 1  K01009.01      Train
# 2  K07621.01      Train
# 3  K06252.01      Train
# 4  K00958.01  Unlabeled

# %%
df_meta = pd.read_csv(fold+"/koi_metadata.csv")
df_meta_train = df_meta[mask_train]
df_meta_test = df_meta[mask_test]
df_meta_unb = df_meta[mask_unlabeled]

df_meta_train.head()
# Out:
#     KOI Name NExScI Disposition Kepler Name      Period  \
# 1  K01009.01     FALSE POSITIVE         NaN    5.092465
# 2  K07621.01     FALSE POSITIVE         NaN  275.073650
# 3  K06252.01     FALSE POSITIVE         NaN    8.460439
# 6  K04162.01     FALSE POSITIVE         NaN    0.539366
# 9  K00998.01     FALSE POSITIVE         NaN  161.788327
#
#    Time of Transit Epoch  First Transit Time (BJD)  Impact Parameter  \
# 1              357.53594               2455190.536             0.161
# 2              315.24860               2455148.249             0.595
# 3              133.77449               2454966.774             1.061
# 6              131.97457               2454964.975             0.988
# 9              214.03900               2455047.039             0.267
#
#    Duration  Transit Depth    r/R  ...    Teff  log(g)  Metallicity  \
# 1   3.65900          254.0  0.014  ...  5037.0   4.547        -0.20
# 2   3.37000          228.9  0.014  ...  5604.0   4.226        -0.12
# 3   4.73492        76412.9  0.478  ...  5951.0   4.638        -1.06
# 6   5.43400          145.0  0.016  ...  6341.0   3.301        -0.10
# 9   5.31000        87750.0  0.273  ...  6018.0   4.327         0.18
#
#    Stellar Radius  Stellar Mass  Max single event sigma  Max Multievent sigma  \
# 1           0.751         0.727                   3.648                15.175
# 2           1.187         0.864                   5.909                 8.012
# 3           0.702         0.796                 452.526              3704.503
# 6           5.302         2.050                   4.847                 9.076
# 9           1.212         1.142                 341.666               806.993
#
#    Transit Model SNR  KOI count  Transit Number
# 1               17.1          1             225
# 2                7.5          1               4
# 3             1797.4          1             164
# 6               57.6          1            1239
# 9              704.5          1               9
#
# [5 rows x 31 columns]

# %%
kois_train=df_meta_train['KOI Name'].values
labels_train=df_meta_train['NExScI Disposition'].values
kois_val=df_meta_test['KOI Name'].values
labels_val=df_meta_test['NExScI Disposition'].values
kois_test=df_meta_unb['KOI Name'].values
labels_test=df_meta_unb['NExScI Disposition'].values

# %%
labels_train[:5]
# Out:
# array(['FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE',
#        'FALSE POSITIVE', 'FALSE POSITIVE'], dtype=object)

# %%
def to_int(labels):
    y_true=[]
    for y in labels:
        if y=='CONFIRMED':
            y_true.append(1)
        else:
            y_true.append(0)
    return y_true

# %%
folder_fp='/work/work_teamEXOPLANET/MTF/falsos_positivos/'
folder_c='/work/work_teamEXOPLANET/MTF_gabo/'
falsos=os.listdir(folder_fp)
confirmed=os.listdir(folder_c+'confirmados')
candidates=os.listdir(folder_c+'candidatos')
#load data
x_train=[]
y_train=[]
i=0
for koi in kois_train:
    print ("Cargando objeto", koi, 'con identificador',i, 'es decir, etiqueta', labels_train[i])
    
    if labels_train[i]=='FALSE POSITIVE':
        x_train.append(np.load(folder_fp+koi+'.npy'))
        y_train.append(0)
        try: 
            x_train.append(np.load(folder_c+'falsos_positivos_2/'+koi+'.npy'))
            y_train.append(0)
        except:
            i+=1
            continue
    else:
        x_train.append(np.load(folder_c+'confirmados/'+koi+'.npy'))
        y_train.append(1)
        try:
            x_train.append(np.load(folder_c+'confirmados_2/'+koi+'.npy'))
            y_train.append(1)
        except:
            i+=1
            continue
    i+=1
# Out:
# Cargando objeto K01009.01 con identificador 0 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07621.01 con identificador 1 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06252.01 con identificador 2 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04162.01 con identificador 3 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00998.01 con identificador 4 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00992.01 con identificador 5 es decir, etiqueta CONFIRMED
# Cargando objeto K00982.01 con identificador 6 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03924.01 con identificador 7 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07623.01 con identificador 8 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00362.01 con identificador 9 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03658.01 con identificador 10 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00993.01 con identificador 11 es decir, etiqueta CONFIRMED
# Cargando objeto K00993.02 con identificador 12 es decir, etiqueta CONFIRMED
# Cargando objeto K00993.03 con identificador 13 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01008.01 con identificador 14 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04224.01 con identificador 15 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04212.01 con identificador 16 es decir, etiqueta CONFIRMED
# Cargando objeto K01007.01 con identificador 17 es decir, etiqueta CONFIRMED
# Cargando objeto K04925.01 con identificador 18 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07625.01 con identificador 19 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04927.01 con identificador 20 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01001.01 con identificador 21 es decir, etiqueta CONFIRMED
# Cargando objeto K01001.02 con identificador 22 es decir, etiqueta CONFIRMED
# Cargando objeto K04928.01 con identificador 23 es decir, etiqueta CONFIRMED
# Cargando objeto K02634.01 con identificador 24 es decir, etiqueta CONFIRMED
# Cargando objeto K07626.01 con identificador 25 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00147.01 con identificador 26 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08084.01 con identificador 27 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03999.01 con identificador 28 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06257.01 con identificador 29 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06258.01 con identificador 30 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03585.01 con identificador 31 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02201.01 con identificador 32 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02403.01 con identificador 33 es decir, etiqueta CONFIRMED
# Cargando objeto K06094.01 con identificador 34 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06260.01 con identificador 35 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00999.01 con identificador 36 es decir, etiqueta CONFIRMED
# Cargando objeto K00999.02 con identificador 37 es decir, etiqueta CONFIRMED
# Cargando objeto K01028.01 con identificador 38 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06261.01 con identificador 39 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03670.01 con identificador 40 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00988.01 con identificador 41 es decir, etiqueta CONFIRMED
# Cargando objeto K00988.02 con identificador 42 es decir, etiqueta CONFIRMED
# Cargando objeto K07629.01 con identificador 43 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02033.01 con identificador 44 es decir, etiqueta CONFIRMED
# Cargando objeto K04935.01 con identificador 45 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06264.01 con identificador 46 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04936.01 con identificador 47 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06265.01 con identificador 48 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03549.01 con identificador 49 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02053.01 con identificador 50 es decir, etiqueta CONFIRMED
# Cargando objeto K02053.02 con identificador 51 es decir, etiqueta CONFIRMED
# Cargando objeto K06266.01 con identificador 52 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01004.01 con identificador 53 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05982.01 con identificador 54 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04937.01 con identificador 55 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02682.01 con identificador 56 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03712.01 con identificador 57 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03461.01 con identificador 58 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03461.02 con identificador 59 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06268.01 con identificador 60 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03920.01 con identificador 61 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03745.01 con identificador 62 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06269.01 con identificador 63 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04909.01 con identificador 64 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06270.01 con identificador 65 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00440.02 con identificador 66 es decir, etiqueta CONFIRMED
# Cargando objeto K01944.02 con identificador 67 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02280.01 con identificador 68 es decir, etiqueta CONFIRMED
# Cargando objeto K00792.01 con identificador 69 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00603.01 con identificador 70 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03642.01 con identificador 71 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00166.01 con identificador 72 es decir, etiqueta CONFIRMED
# Cargando objeto K06273.01 con identificador 73 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03997.01 con identificador 74 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02812.01 con identificador 75 es decir, etiqueta CONFIRMED
# Cargando objeto K00793.01 con identificador 76 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05983.01 con identificador 77 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07632.01 con identificador 78 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03674.01 con identificador 79 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07633.01 con identificador 80 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03702.01 con identificador 81 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02156.01 con identificador 82 es decir, etiqueta CONFIRMED
# Cargando objeto K06277.01 con identificador 83 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00488.01 con identificador 84 es decir, etiqueta CONFIRMED
# Cargando objeto K01021.01 con identificador 85 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03855.01 con identificador 86 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06278.01 con identificador 87 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03704.01 con identificador 88 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07634.01 con identificador 89 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06279.01 con identificador 90 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06280.01 con identificador 91 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00084.01 con identificador 92 es decir, etiqueta CONFIRMED
# Cargando objeto K02648.01 con identificador 93 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03217.01 con identificador 94 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01025.01 con identificador 95 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00489.01 con identificador 96 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06282.01 con identificador 97 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04629.01 con identificador 98 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04948.01 con identificador 99 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06283.01 con identificador 100 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02203.01 con identificador 101 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03681.01 con identificador 102 es decir, etiqueta CONFIRMED
# Cargando objeto K03835.01 con identificador 103 es decir, etiqueta CONFIRMED
# Cargando objeto K01031.01 con identificador 104 es decir, etiqueta CONFIRMED
# Cargando objeto K00299.01 con identificador 105 es decir, etiqueta CONFIRMED
# Cargando objeto K06285.01 con identificador 106 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01976.01 con identificador 107 es decir, etiqueta CONFIRMED
# Cargando objeto K04600.01 con identificador 108 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00400.01 con identificador 109 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03853.01 con identificador 110 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04950.01 con identificador 111 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03253.01 con identificador 112 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06286.01 con identificador 113 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04045.01 con identificador 114 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04352.01 con identificador 115 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04951.01 con identificador 116 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04102.01 con identificador 117 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04111.01 con identificador 118 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04003.01 con identificador 119 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06288.01 con identificador 120 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06289.01 con identificador 121 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04532.01 con identificador 122 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04953.01 con identificador 123 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04746.01 con identificador 124 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00794.01 con identificador 125 es decir, etiqueta CONFIRMED
# Cargando objeto K01024.01 con identificador 126 es decir, etiqueta CONFIRMED
# Cargando objeto K03053.01 con identificador 127 es decir, etiqueta CONFIRMED
# Cargando objeto K01022.02 con identificador 128 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06096.01 con identificador 129 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06292.01 con identificador 130 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02979.01 con identificador 131 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01094.01 con identificador 132 es decir, etiqueta CONFIRMED
# Cargando objeto K04400.01 con identificador 133 es decir, etiqueta CONFIRMED
# Cargando objeto K04702.01 con identificador 134 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01110.01 con identificador 135 es decir, etiqueta CONFIRMED
# Cargando objeto K01110.02 con identificador 136 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01116.01 con identificador 137 es decir, etiqueta CONFIRMED
# Cargando objeto K04956.01 con identificador 138 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01104.01 con identificador 139 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06294.01 con identificador 140 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01099.01 con identificador 141 es decir, etiqueta CONFIRMED
# Cargando objeto K02896.01 con identificador 142 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00986.01 con identificador 143 es decir, etiqueta CONFIRMED
# Cargando objeto K00986.02 con identificador 144 es decir, etiqueta CONFIRMED
# Cargando objeto K01113.02 con identificador 145 es decir, etiqueta CONFIRMED
# Cargando objeto K06295.01 con identificador 146 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02170.01 con identificador 147 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06296.01 con identificador 148 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02277.01 con identificador 149 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03993.01 con identificador 150 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06300.01 con identificador 151 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01788.01 con identificador 152 es decir, etiqueta CONFIRMED
# Cargando objeto K01788.02 con identificador 153 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02032.01 con identificador 154 es decir, etiqueta CONFIRMED
# Cargando objeto K00197.01 con identificador 155 es decir, etiqueta CONFIRMED
# Cargando objeto K04959.01 con identificador 156 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01824.01 con identificador 157 es decir, etiqueta CONFIRMED
# Cargando objeto K01824.02 con identificador 158 es decir, etiqueta CONFIRMED
# Cargando objeto K02692.01 con identificador 159 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02335.01 con identificador 160 es decir, etiqueta CONFIRMED
# Cargando objeto K03379.01 con identificador 161 es decir, etiqueta CONFIRMED
# Cargando objeto K06098.01 con identificador 162 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06302.01 con identificador 163 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02540.01 con identificador 164 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07642.01 con identificador 165 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01119.01 con identificador 166 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01119.02 con identificador 167 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00264.01 con identificador 168 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03648.01 con identificador 169 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01091.01 con identificador 170 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06303.01 con identificador 171 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03362.01 con identificador 172 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03373.01 con identificador 173 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06304.01 con identificador 174 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07643.01 con identificador 175 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04091.01 con identificador 176 es decir, etiqueta CONFIRMED
# Cargando objeto K04720.01 con identificador 177 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01088.01 con identificador 178 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00795.01 con identificador 179 es decir, etiqueta CONFIRMED
# Cargando objeto K00796.01 con identificador 180 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03763.01 con identificador 181 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01117.01 con identificador 182 es decir, etiqueta CONFIRMED
# Cargando objeto K04114.01 con identificador 183 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01950.01 con identificador 184 es decir, etiqueta CONFIRMED
# Cargando objeto K06307.01 con identificador 185 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02099.01 con identificador 186 es decir, etiqueta CONFIRMED
# Cargando objeto K03277.01 con identificador 187 es decir, etiqueta CONFIRMED
# Cargando objeto K03945.01 con identificador 188 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01087.01 con identificador 189 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03918.01 con identificador 190 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04187.01 con identificador 191 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06308.01 con identificador 192 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02055.02 con identificador 193 es decir, etiqueta CONFIRMED
# Cargando objeto K01786.01 con identificador 194 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00401.01 con identificador 195 es decir, etiqueta CONFIRMED
# Cargando objeto K00401.02 con identificador 196 es decir, etiqueta CONFIRMED
# Cargando objeto K00401.03 con identificador 197 es decir, etiqueta CONFIRMED
# Cargando objeto K07646.01 con identificador 198 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01108.01 con identificador 199 es decir, etiqueta CONFIRMED
# Cargando objeto K01108.02 con identificador 200 es decir, etiqueta CONFIRMED
# Cargando objeto K02314.01 con identificador 201 es decir, etiqueta CONFIRMED
# Cargando objeto K04966.01 con identificador 202 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06309.01 con identificador 203 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03996.01 con identificador 204 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01100.01 con identificador 205 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02917.01 con identificador 206 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01107.01 con identificador 207 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04031.01 con identificador 208 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03992.01 con identificador 209 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06100.01 con identificador 210 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07647.01 con identificador 211 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06310.01 con identificador 212 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06311.01 con identificador 213 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00381.01 con identificador 214 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02928.01 con identificador 215 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06101.01 con identificador 216 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00382.01 con identificador 217 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01102.02 con identificador 218 es decir, etiqueta CONFIRMED
# Cargando objeto K01102.04 con identificador 219 es decir, etiqueta CONFIRMED
# Cargando objeto K01090.01 con identificador 220 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02413.02 con identificador 221 es decir, etiqueta CONFIRMED
# Cargando objeto K03057.01 con identificador 222 es decir, etiqueta CONFIRMED
# Cargando objeto K07649.01 con identificador 223 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01093.01 con identificador 224 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00490.01 con identificador 225 es decir, etiqueta CONFIRMED
# Cargando objeto K00490.02 con identificador 226 es decir, etiqueta CONFIRMED
# Cargando objeto K00490.03 con identificador 227 es decir, etiqueta CONFIRMED
# Cargando objeto K00490.04 con identificador 228 es decir, etiqueta CONFIRMED
# Cargando objeto K04968.01 con identificador 229 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01106.02 con identificador 230 es decir, etiqueta CONFIRMED
# Cargando objeto K03515.01 con identificador 231 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03185.01 con identificador 232 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01098.01 con identificador 233 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04141.01 con identificador 234 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05984.01 con identificador 235 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02863.01 con identificador 236 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02824.01 con identificador 237 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06312.01 con identificador 238 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04347.01 con identificador 239 es decir, etiqueta CONFIRMED
# Cargando objeto K03977.01 con identificador 240 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01101.01 con identificador 241 es decir, etiqueta CONFIRMED
# Cargando objeto K06316.01 con identificador 242 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04035.01 con identificador 243 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00006.01 con identificador 244 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06317.01 con identificador 245 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07651.01 con identificador 246 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06319.01 con identificador 247 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00377.01 con identificador 248 es decir, etiqueta CONFIRMED
# Cargando objeto K03084.01 con identificador 249 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01830.02 con identificador 250 es decir, etiqueta CONFIRMED
# Cargando objeto K06321.01 con identificador 251 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03635.01 con identificador 252 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01994.01 con identificador 253 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04174.01 con identificador 254 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03011.01 con identificador 255 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04533.01 con identificador 256 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06323.01 con identificador 257 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03247.01 con identificador 258 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02740.01 con identificador 259 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03172.01 con identificador 260 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01114.01 con identificador 261 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02265.01 con identificador 262 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06324.01 con identificador 263 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06325.01 con identificador 264 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03795.01 con identificador 265 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01845.01 con identificador 266 es decir, etiqueta CONFIRMED
# Cargando objeto K06326.01 con identificador 267 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03677.01 con identificador 268 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04973.01 con identificador 269 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06327.01 con identificador 270 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03278.01 con identificador 271 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00402.01 con identificador 272 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02278.01 con identificador 273 es decir, etiqueta CONFIRMED
# Cargando objeto K02278.02 con identificador 274 es decir, etiqueta CONFIRMED
# Cargando objeto K03215.01 con identificador 275 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00800.01 con identificador 276 es decir, etiqueta CONFIRMED
# Cargando objeto K00800.02 con identificador 277 es decir, etiqueta CONFIRMED
# Cargando objeto K04860.01 con identificador 278 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06328.01 con identificador 279 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01181.01 con identificador 280 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01772.01 con identificador 281 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07652.01 con identificador 282 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05985.01 con identificador 283 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07653.01 con identificador 284 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01196.03 con identificador 285 es decir, etiqueta CONFIRMED
# Cargando objeto K04112.01 con identificador 286 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03021.01 con identificador 287 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00801.01 con identificador 288 es decir, etiqueta CONFIRMED
# Cargando objeto K06330.01 con identificador 289 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00384.01 con identificador 290 es decir, etiqueta CONFIRMED
# Cargando objeto K07654.01 con identificador 291 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02444.01 con identificador 292 es decir, etiqueta CONFIRMED
# Cargando objeto K04975.01 con identificador 293 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02662.01 con identificador 294 es decir, etiqueta CONFIRMED
# Cargando objeto K03415.01 con identificador 295 es decir, etiqueta CONFIRMED
# Cargando objeto K06333.01 con identificador 296 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00549.02 con identificador 297 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01204.01 con identificador 298 es decir, etiqueta CONFIRMED
# Cargando objeto K04980.01 con identificador 299 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03509.01 con identificador 300 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06334.01 con identificador 301 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06335.01 con identificador 302 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00976.01 con identificador 303 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03593.01 con identificador 304 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01218.01 con identificador 305 es decir, etiqueta CONFIRMED
# Cargando objeto K08087.01 con identificador 306 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01185.01 con identificador 307 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04042.01 con identificador 308 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04802.01 con identificador 309 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01735.01 con identificador 310 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00385.01 con identificador 311 es decir, etiqueta CONFIRMED
# Cargando objeto K01198.01 con identificador 312 es decir, etiqueta CONFIRMED
# Cargando objeto K01198.02 con identificador 313 es decir, etiqueta CONFIRMED
# Cargando objeto K01198.03 con identificador 314 es decir, etiqueta CONFIRMED
# Cargando objeto K07656.01 con identificador 315 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04982.01 con identificador 316 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02276.01 con identificador 317 es decir, etiqueta CONFIRMED
# Cargando objeto K07543.01 con identificador 318 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03725.01 con identificador 319 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04800.01 con identificador 320 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05986.01 con identificador 321 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07657.01 con identificador 322 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00118.01 con identificador 323 es decir, etiqueta CONFIRMED
# Cargando objeto K05987.01 con identificador 324 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08088.01 con identificador 325 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03641.02 con identificador 326 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00624.01 con identificador 327 es decir, etiqueta CONFIRMED
# Cargando objeto K04137.01 con identificador 328 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06338.01 con identificador 329 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03628.01 con identificador 330 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01217.01 con identificador 331 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00069.01 con identificador 332 es decir, etiqueta CONFIRMED
# Cargando objeto K01183.01 con identificador 333 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02126.01 con identificador 334 es decir, etiqueta CONFIRMED
# Cargando objeto K02194.01 con identificador 335 es decir, etiqueta CONFIRMED
# Cargando objeto K02194.02 con identificador 336 es decir, etiqueta CONFIRMED
# Cargando objeto K06343.01 con identificador 337 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01194.01 con identificador 338 es decir, etiqueta CONFIRMED
# Cargando objeto K01194.03 con identificador 339 es decir, etiqueta CONFIRMED
# Cargando objeto K00803.01 con identificador 340 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01213.01 con identificador 341 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03899.01 con identificador 342 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06344.01 con identificador 343 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06345.01 con identificador 344 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00052.01 con identificador 345 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03440.01 con identificador 346 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03440.02 con identificador 347 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00492.01 con identificador 348 es decir, etiqueta CONFIRMED
# Cargando objeto K00968.01 con identificador 349 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03398.01 con identificador 350 es decir, etiqueta CONFIRMED
# Cargando objeto K03418.01 con identificador 351 es decir, etiqueta CONFIRMED
# Cargando objeto K03308.01 con identificador 352 es decir, etiqueta CONFIRMED
# Cargando objeto K03308.02 con identificador 353 es decir, etiqueta CONFIRMED
# Cargando objeto K00975.01 con identificador 354 es decir, etiqueta CONFIRMED
# Cargando objeto K06103.01 con identificador 355 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00301.01 con identificador 356 es decir, etiqueta CONFIRMED
# Cargando objeto K00301.02 con identificador 357 es decir, etiqueta CONFIRMED
# Cargando objeto K03010.01 con identificador 358 es decir, etiqueta CONFIRMED
# Cargando objeto K00242.01 con identificador 359 es decir, etiqueta CONFIRMED
# Cargando objeto K01192.02 con identificador 360 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06347.01 con identificador 361 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04997.01 con identificador 362 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04641.01 con identificador 363 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01195.01 con identificador 364 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03511.01 con identificador 365 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03862.01 con identificador 366 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04479.01 con identificador 367 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07659.01 con identificador 368 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07660.01 con identificador 369 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04385.02 con identificador 370 es decir, etiqueta CONFIRMED
# Cargando objeto K04249.01 con identificador 371 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01766.01 con identificador 372 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00386.01 con identificador 373 es decir, etiqueta CONFIRMED
# Cargando objeto K00386.02 con identificador 374 es decir, etiqueta CONFIRMED
# Cargando objeto K06350.01 con identificador 375 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02034.01 con identificador 376 es decir, etiqueta CONFIRMED
# Cargando objeto K02034.02 con identificador 377 es decir, etiqueta CONFIRMED
# Cargando objeto K01214.01 con identificador 378 es decir, etiqueta CONFIRMED
# Cargando objeto K02279.02 con identificador 379 es decir, etiqueta CONFIRMED
# Cargando objeto K08243.01 con identificador 380 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07663.01 con identificador 381 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03893.01 con identificador 382 es decir, etiqueta CONFIRMED
# Cargando objeto K02536.01 con identificador 383 es decir, etiqueta CONFIRMED
# Cargando objeto K03966.01 con identificador 384 es decir, etiqueta CONFIRMED
# Cargando objeto K01207.01 con identificador 385 es decir, etiqueta CONFIRMED
# Cargando objeto K07664.01 con identificador 386 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08244.01 con identificador 387 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00805.01 con identificador 388 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03544.01 con identificador 389 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03615.01 con identificador 390 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00045.01 con identificador 391 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00442.01 con identificador 392 es decir, etiqueta CONFIRMED
# Cargando objeto K00442.02 con identificador 393 es decir, etiqueta CONFIRMED
# Cargando objeto K00442.03 con identificador 394 es decir, etiqueta CONFIRMED
# Cargando objeto K01212.01 con identificador 395 es decir, etiqueta CONFIRMED
# Cargando objeto K07544.01 con identificador 396 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07544.02 con identificador 397 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02308.01 con identificador 398 es decir, etiqueta CONFIRMED
# Cargando objeto K07665.01 con identificador 399 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05005.01 con identificador 400 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04057.01 con identificador 401 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03402.01 con identificador 402 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00208.01 con identificador 403 es decir, etiqueta CONFIRMED
# Cargando objeto K03963.01 con identificador 404 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02141.01 con identificador 405 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06359.01 con identificador 406 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06360.01 con identificador 407 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00806.01 con identificador 408 es decir, etiqueta CONFIRMED
# Cargando objeto K00806.02 con identificador 409 es decir, etiqueta CONFIRMED
# Cargando objeto K00027.01 con identificador 410 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00443.01 con identificador 411 es decir, etiqueta CONFIRMED
# Cargando objeto K04203.01 con identificador 412 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02763.01 con identificador 413 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00493.01 con identificador 414 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03834.01 con identificador 415 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06363.01 con identificador 416 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06364.01 con identificador 417 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01903.01 con identificador 418 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05011.01 con identificador 419 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05012.01 con identificador 420 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04086.01 con identificador 421 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06365.01 con identificador 422 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03700.01 con identificador 423 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07669.01 con identificador 424 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01216.01 con identificador 425 es decir, etiqueta CONFIRMED
# Cargando objeto K00444.01 con identificador 426 es decir, etiqueta CONFIRMED
# Cargando objeto K00229.01 con identificador 427 es decir, etiqueta CONFIRMED
# Cargando objeto K02995.01 con identificador 428 es decir, etiqueta CONFIRMED
# Cargando objeto K05014.01 con identificador 429 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05015.01 con identificador 430 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06366.01 con identificador 431 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06367.01 con identificador 432 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07671.01 con identificador 433 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03808.01 con identificador 434 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07672.01 con identificador 435 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03002.01 con identificador 436 es decir, etiqueta CONFIRMED
# Cargando objeto K01197.01 con identificador 437 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05018.01 con identificador 438 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04681.01 con identificador 439 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01211.01 con identificador 440 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00391.01 con identificador 441 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00996.01 con identificador 442 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03276.01 con identificador 443 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06371.01 con identificador 444 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03294.01 con identificador 445 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05990.01 con identificador 446 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07674.01 con identificador 447 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00995.01 con identificador 448 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02887.01 con identificador 449 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01188.01 con identificador 450 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03938.01 con identificador 451 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04423.01 con identificador 452 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05023.01 con identificador 453 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02289.01 con identificador 454 es decir, etiqueta CONFIRMED
# Cargando objeto K02289.02 con identificador 455 es decir, etiqueta CONFIRMED
# Cargando objeto K01205.01 con identificador 456 es decir, etiqueta CONFIRMED
# Cargando objeto K05991.01 con identificador 457 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00809.01 con identificador 458 es decir, etiqueta CONFIRMED
# Cargando objeto K00221.01 con identificador 459 es decir, etiqueta CONFIRMED
# Cargando objeto K06373.01 con identificador 460 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01215.01 con identificador 461 es decir, etiqueta CONFIRMED
# Cargando objeto K00392.01 con identificador 462 es decir, etiqueta CONFIRMED
# Cargando objeto K00392.02 con identificador 463 es decir, etiqueta CONFIRMED
# Cargando objeto K05025.01 con identificador 464 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04493.01 con identificador 465 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08090.01 con identificador 466 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04117.01 con identificador 467 es decir, etiqueta CONFIRMED
# Cargando objeto K07545.01 con identificador 468 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02864.01 con identificador 469 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03381.02 con identificador 470 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01203.01 con identificador 471 es decir, etiqueta CONFIRMED
# Cargando objeto K01203.02 con identificador 472 es decir, etiqueta CONFIRMED
# Cargando objeto K01210.01 con identificador 473 es decir, etiqueta CONFIRMED
# Cargando objeto K04908.01 con identificador 474 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05028.01 con identificador 475 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00393.01 con identificador 476 es decir, etiqueta CONFIRMED
# Cargando objeto K03542.01 con identificador 477 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00015.01 con identificador 478 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01186.01 con identificador 479 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07677.01 con identificador 480 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01760.01 con identificador 481 es decir, etiqueta CONFIRMED
# Cargando objeto K02904.01 con identificador 482 es decir, etiqueta CONFIRMED
# Cargando objeto K03556.01 con identificador 483 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00604.01 con identificador 484 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05992.01 con identificador 485 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06376.01 con identificador 486 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06377.01 con identificador 487 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05032.01 con identificador 488 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01881.01 con identificador 489 es decir, etiqueta CONFIRMED
# Cargando objeto K02684.01 con identificador 490 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03793.01 con identificador 491 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01220.01 con identificador 492 es decir, etiqueta CONFIRMED
# Cargando objeto K00231.01 con identificador 493 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00495.01 con identificador 494 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05994.01 con identificador 495 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00811.01 con identificador 496 es decir, etiqueta CONFIRMED
# Cargando objeto K06379.01 con identificador 497 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02119.01 con identificador 498 es decir, etiqueta CONFIRMED
# Cargando objeto K02381.01 con identificador 499 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08091.01 con identificador 500 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05034.01 con identificador 501 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04887.01 con identificador 502 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04026.01 con identificador 503 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06380.01 con identificador 504 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06382.01 con identificador 505 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01318.01 con identificador 506 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01329.01 con identificador 507 es decir, etiqueta CONFIRMED
# Cargando objeto K07682.01 con identificador 508 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03525.01 con identificador 509 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03785.01 con identificador 510 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07547.01 con identificador 511 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02850.01 con identificador 512 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06383.01 con identificador 513 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03777.01 con identificador 514 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01323.01 con identificador 515 es decir, etiqueta CONFIRMED
# Cargando objeto K06385.01 con identificador 516 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03124.01 con identificador 517 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05038.01 con identificador 518 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01336.01 con identificador 519 es decir, etiqueta CONFIRMED
# Cargando objeto K01336.02 con identificador 520 es decir, etiqueta CONFIRMED
# Cargando objeto K01336.03 con identificador 521 es decir, etiqueta CONFIRMED
# Cargando objeto K01319.01 con identificador 522 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03594.01 con identificador 523 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01322.01 con identificador 524 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01344.01 con identificador 525 es decir, etiqueta CONFIRMED
# Cargando objeto K07683.01 con identificador 526 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04742.01 con identificador 527 es decir, etiqueta CONFIRMED
# Cargando objeto K02866.01 con identificador 528 es decir, etiqueta CONFIRMED
# Cargando objeto K00812.01 con identificador 529 es decir, etiqueta CONFIRMED
# Cargando objeto K00812.02 con identificador 530 es decir, etiqueta CONFIRMED
# Cargando objeto K00812.03 con identificador 531 es decir, etiqueta CONFIRMED
# Cargando objeto K00812.04 con identificador 532 es decir, etiqueta CONFIRMED
# Cargando objeto K06387.01 con identificador 533 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02210.02 con identificador 534 es decir, etiqueta CONFIRMED
# Cargando objeto K06109.01 con identificador 535 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02202.01 con identificador 536 es decir, etiqueta CONFIRMED
# Cargando objeto K07686.01 con identificador 537 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01768.01 con identificador 538 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04046.02 con identificador 539 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01330.01 con identificador 540 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03156.02 con identificador 541 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03156.04 con identificador 542 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01334.01 con identificador 543 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06110.01 con identificador 544 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04468.01 con identificador 545 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01860.04 con identificador 546 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06390.01 con identificador 547 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05045.01 con identificador 548 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06391.01 con identificador 549 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03413.01 con identificador 550 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01320.01 con identificador 551 es decir, etiqueta CONFIRMED
# Cargando objeto K00550.01 con identificador 552 es decir, etiqueta CONFIRMED
# Cargando objeto K04836.01 con identificador 553 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02998.01 con identificador 554 es decir, etiqueta CONFIRMED
# Cargando objeto K00185.01 con identificador 555 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00144.01 con identificador 556 es decir, etiqueta CONFIRMED
# Cargando objeto K06394.01 con identificador 557 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03928.01 con identificador 558 es decir, etiqueta CONFIRMED
# Cargando objeto K01337.01 con identificador 559 es decir, etiqueta CONFIRMED
# Cargando objeto K06395.01 con identificador 560 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02190.01 con identificador 561 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00403.01 con identificador 562 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00028.01 con identificador 563 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03748.01 con identificador 564 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04678.01 con identificador 565 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02311.03 con identificador 566 es decir, etiqueta CONFIRMED
# Cargando objeto K00222.01 con identificador 567 es decir, etiqueta CONFIRMED
# Cargando objeto K00222.02 con identificador 568 es decir, etiqueta CONFIRMED
# Cargando objeto K06396.01 con identificador 569 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05052.01 con identificador 570 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02134.01 con identificador 571 es decir, etiqueta CONFIRMED
# Cargando objeto K03528.01 con identificador 572 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06397.01 con identificador 573 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02122.01 con identificador 574 es decir, etiqueta CONFIRMED
# Cargando objeto K01895.01 con identificador 575 es decir, etiqueta CONFIRMED
# Cargando objeto K01895.02 con identificador 576 es decir, etiqueta CONFIRMED
# Cargando objeto K01895.03 con identificador 577 es decir, etiqueta CONFIRMED
# Cargando objeto K00551.01 con identificador 578 es decir, etiqueta CONFIRMED
# Cargando objeto K00551.02 con identificador 579 es decir, etiqueta CONFIRMED
# Cargando objeto K02819.01 con identificador 580 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03324.01 con identificador 581 es decir, etiqueta CONFIRMED
# Cargando objeto K01342.01 con identificador 582 es decir, etiqueta CONFIRMED
# Cargando objeto K01342.02 con identificador 583 es decir, etiqueta CONFIRMED
# Cargando objeto K08092.01 con identificador 584 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07689.01 con identificador 585 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06400.01 con identificador 586 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03439.01 con identificador 587 es decir, etiqueta CONFIRMED
# Cargando objeto K01325.01 con identificador 588 es decir, etiqueta CONFIRMED
# Cargando objeto K06402.01 con identificador 589 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06112.01 con identificador 590 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01333.01 con identificador 591 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06113.01 con identificador 592 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01803.02 con identificador 593 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00244.01 con identificador 594 es decir, etiqueta CONFIRMED
# Cargando objeto K06403.01 con identificador 595 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06404.01 con identificador 596 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07691.01 con identificador 597 es decir, etiqueta FALSE POSITIVE
# ...
# Cargando objeto K08230.01 con identificador 4495 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07484.01 con identificador 4496 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07485.01 con identificador 4497 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03633.01 con identificador 4498 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01471.01 con identificador 4499 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04062.01 con identificador 4500 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03445.01 con identificador 4501 es decir, etiqueta CONFIRMED
# Cargando objeto K06247.01 con identificador 4502 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08294.01 con identificador 4503 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08231.01 con identificador 4504 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04350.01 con identificador 4505 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03464.01 con identificador 4506 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03471.01 con identificador 4507 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00072.01 con identificador 4508 es decir, etiqueta CONFIRMED
# Cargando objeto K00072.02 con identificador 4509 es decir, etiqueta CONFIRMED
# Cargando objeto K00297.01 con identificador 4510 es decir, etiqueta CONFIRMED
# Cargando objeto K07490.01 con identificador 4511 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01483.01 con identificador 4512 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00779.01 con identificador 4513 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03900.01 con identificador 4514 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04475.01 con identificador 4515 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03085.01 con identificador 4516 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04481.01 con identificador 4517 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00544.01 con identificador 4518 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01462.01 con identificador 4519 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07492.01 con identificador 4520 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08069.01 con identificador 4521 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02425.01 con identificador 4522 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02301.01 con identificador 4523 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07495.01 con identificador 4524 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00781.01 con identificador 4525 es decir, etiqueta CONFIRMED
# Cargando objeto K07496.01 con identificador 4526 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05944.01 con identificador 4527 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07497.01 con identificador 4528 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00782.01 con identificador 4529 es decir, etiqueta CONFIRMED
# Cargando objeto K02647.01 con identificador 4530 es decir, etiqueta CONFIRMED
# Cargando objeto K02820.01 con identificador 4531 es decir, etiqueta CONFIRMED
# Cargando objeto K02772.01 con identificador 4532 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07498.01 con identificador 4533 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08071.01 con identificador 4534 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07499.01 con identificador 4535 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08072.01 con identificador 4536 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02433.01 con identificador 4537 es decir, etiqueta CONFIRMED
# Cargando objeto K02433.05 con identificador 4538 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07500.01 con identificador 4539 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03587.01 con identificador 4540 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05947.01 con identificador 4541 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07501.01 con identificador 4542 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00545.01 con identificador 4543 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04089.01 con identificador 4544 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00129.01 con identificador 4545 es decir, etiqueta CONFIRMED
# Cargando objeto K06248.01 con identificador 4546 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08073.01 con identificador 4547 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07502.01 con identificador 4548 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02729.01 con identificador 4549 es decir, etiqueta CONFIRMED
# Cargando objeto K08074.01 con identificador 4550 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03792.01 con identificador 4551 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08233.01 con identificador 4552 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07505.01 con identificador 4553 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00358.01 con identificador 4554 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00186.01 con identificador 4555 es decir, etiqueta CONFIRMED
# Cargando objeto K01507.01 con identificador 4556 es decir, etiqueta CONFIRMED
# Cargando objeto K00783.01 con identificador 4557 es decir, etiqueta CONFIRMED
# Cargando objeto K02996.01 con identificador 4558 es decir, etiqueta CONFIRMED
# Cargando objeto K07507.01 con identificador 4559 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02888.01 con identificador 4560 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00265.01 con identificador 4561 es decir, etiqueta CONFIRMED
# Cargando objeto K03261.01 con identificador 4562 es decir, etiqueta CONFIRMED
# Cargando objeto K03262.01 con identificador 4563 es decir, etiqueta CONFIRMED
# Cargando objeto K02072.01 con identificador 4564 es decir, etiqueta CONFIRMED
# Cargando objeto K02218.01 con identificador 4565 es decir, etiqueta CONFIRMED
# Cargando objeto K02218.02 con identificador 4566 es decir, etiqueta CONFIRMED
# Cargando objeto K00546.01 con identificador 4567 es decir, etiqueta CONFIRMED
# Cargando objeto K00484.01 con identificador 4568 es decir, etiqueta CONFIRMED
# Cargando objeto K01502.01 con identificador 4569 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03746.01 con identificador 4570 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01487.01 con identificador 4571 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00784.02 con identificador 4572 es decir, etiqueta CONFIRMED
# Cargando objeto K03282.01 con identificador 4573 es decir, etiqueta CONFIRMED
# Cargando objeto K00623.01 con identificador 4574 es decir, etiqueta CONFIRMED
# Cargando objeto K00623.02 con identificador 4575 es decir, etiqueta CONFIRMED
# Cargando objeto K00623.03 con identificador 4576 es decir, etiqueta CONFIRMED
# Cargando objeto K00623.04 con identificador 4577 es decir, etiqueta CONFIRMED
# Cargando objeto K08234.01 con identificador 4578 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07511.01 con identificador 4579 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02388.01 con identificador 4580 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07512.01 con identificador 4581 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00359.01 con identificador 4582 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03895.01 con identificador 4583 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04297.01 con identificador 4584 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04540.01 con identificador 4585 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01492.01 con identificador 4586 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04592.01 con identificador 4587 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03765.01 con identificador 4588 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02665.01 con identificador 4589 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00786.01 con identificador 4590 es decir, etiqueta CONFIRMED
# Cargando objeto K02155.01 con identificador 4591 es decir, etiqueta CONFIRMED
# Cargando objeto K00547.01 con identificador 4592 es decir, etiqueta CONFIRMED
# Cargando objeto K08296.01 con identificador 4593 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02597.01 con identificador 4594 es decir, etiqueta CONFIRMED
# Cargando objeto K02597.02 con identificador 4595 es decir, etiqueta CONFIRMED
# Cargando objeto K02407.01 con identificador 4596 es decir, etiqueta CONFIRMED
# Cargando objeto K08235.01 con identificador 4597 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02004.01 con identificador 4598 es decir, etiqueta CONFIRMED
# Cargando objeto K02004.02 con identificador 4599 es decir, etiqueta CONFIRMED
# Cargando objeto K03260.01 con identificador 4600 es decir, etiqueta CONFIRMED
# Cargando objeto K07514.01 con identificador 4601 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01536.01 con identificador 4602 es decir, etiqueta CONFIRMED
# Cargando objeto K02780.01 con identificador 4603 es decir, etiqueta CONFIRMED
# Cargando objeto K03491.01 con identificador 4604 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07515.01 con identificador 4605 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00980.01 con identificador 4606 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08297.01 con identificador 4607 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02875.01 con identificador 4608 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02714.01 con identificador 4609 es decir, etiqueta CONFIRMED
# Cargando objeto K02714.02 con identificador 4610 es decir, etiqueta CONFIRMED
# Cargando objeto K02714.03 con identificador 4611 es decir, etiqueta CONFIRMED
# Cargando objeto K06249.01 con identificador 4612 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03333.01 con identificador 4613 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02565.01 con identificador 4614 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03644.01 con identificador 4615 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07516.01 con identificador 4616 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00621.01 con identificador 4617 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07517.01 con identificador 4618 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00153.01 con identificador 4619 es decir, etiqueta CONFIRMED
# Cargando objeto K08236.01 con identificador 4620 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05961.01 con identificador 4621 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02387.01 con identificador 4622 es decir, etiqueta CONFIRMED
# Cargando objeto K02384.01 con identificador 4623 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01506.01 con identificador 4624 es decir, etiqueta CONFIRMED
# Cargando objeto K03167.01 con identificador 4625 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05962.01 con identificador 4626 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01522.01 con identificador 4627 es decir, etiqueta CONFIRMED
# Cargando objeto K07518.01 con identificador 4628 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02059.01 con identificador 4629 es decir, etiqueta CONFIRMED
# Cargando objeto K07519.01 con identificador 4630 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00438.01 con identificador 4631 es decir, etiqueta CONFIRMED
# Cargando objeto K00438.02 con identificador 4632 es decir, etiqueta CONFIRMED
# Cargando objeto K02541.01 con identificador 4633 es decir, etiqueta CONFIRMED
# Cargando objeto K02541.02 con identificador 4634 es decir, etiqueta CONFIRMED
# Cargando objeto K03858.01 con identificador 4635 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07521.01 con identificador 4636 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00279.03 con identificador 4637 es decir, etiqueta CONFIRMED
# Cargando objeto K00485.01 con identificador 4638 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03575.01 con identificador 4639 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07524.01 con identificador 4640 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07525.01 con identificador 4641 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07526.01 con identificador 4642 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07528.01 con identificador 4643 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00787.01 con identificador 4644 es decir, etiqueta CONFIRMED
# Cargando objeto K00787.02 con identificador 4645 es decir, etiqueta CONFIRMED
# Cargando objeto K07529.01 con identificador 4646 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07530.01 con identificador 4647 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01503.01 con identificador 4648 es decir, etiqueta CONFIRMED
# Cargando objeto K02331.01 con identificador 4649 es decir, etiqueta CONFIRMED
# Cargando objeto K07531.01 con identificador 4650 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00486.01 con identificador 4651 es decir, etiqueta CONFIRMED
# Cargando objeto K03009.01 con identificador 4652 es decir, etiqueta CONFIRMED
# Cargando objeto K03778.01 con identificador 4653 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04370.01 con identificador 4654 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03122.01 con identificador 4655 es decir, etiqueta CONFIRMED
# Cargando objeto K02933.01 con identificador 4656 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07532.01 con identificador 4657 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07533.01 con identificador 4658 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04321.01 con identificador 4659 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02424.01 con identificador 4660 es decir, etiqueta CONFIRMED
# Cargando objeto K08080.01 con identificador 4661 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02745.01 con identificador 4662 es decir, etiqueta CONFIRMED
# Cargando objeto K03662.01 con identificador 4663 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08081.01 con identificador 4664 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00602.01 con identificador 4665 es decir, etiqueta CONFIRMED
# Cargando objeto K00790.01 con identificador 4666 es decir, etiqueta CONFIRMED
# Cargando objeto K00790.02 con identificador 4667 es decir, etiqueta CONFIRMED
# Cargando objeto K00439.01 con identificador 4668 es decir, etiqueta CONFIRMED
# Cargando objeto K00181.01 con identificador 4669 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04190.01 con identificador 4670 es decir, etiqueta CONFIRMED
# Cargando objeto K01446.01 con identificador 4671 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01577.01 con identificador 4672 es decir, etiqueta CONFIRMED
# Cargando objeto K08239.01 con identificador 4673 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01583.01 con identificador 4674 es decir, etiqueta CONFIRMED
# Cargando objeto K03626.01 con identificador 4675 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00376.01 con identificador 4676 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00376.02 con identificador 4677 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08083.01 con identificador 4678 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01611.01 con identificador 4679 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01555.01 con identificador 4680 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05976.01 con identificador 4681 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08240.01 con identificador 4682 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01983.01 con identificador 4683 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04303.01 con identificador 4684 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03663.01 con identificador 4685 es decir, etiqueta CONFIRMED
# Cargando objeto K03311.01 con identificador 4686 es decir, etiqueta CONFIRMED
# Cargando objeto K05980.01 con identificador 4687 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03848.01 con identificador 4688 es decir, etiqueta CONFIRMED
# Cargando objeto K00298.01 con identificador 4689 es decir, etiqueta CONFIRMED
# Cargando objeto K00487.01 con identificador 4690 es decir, etiqueta CONFIRMED
# Cargando objeto K02184.01 con identificador 4691 es decir, etiqueta FALSE POSITIVE

# %%
x_val=[]
y_val=[]
i=0
for koi in kois_val:
    print ("Cargando objeto", koi, 'con identificador',i, 'es decir, etiqueta', labels_train[i])
    if labels_val[i]=='FALSE POSITIVE':
        x_val.append(np.load(folder_fp+koi+'.npy'))
        y_val.append(0)
        try: 
            x_val.append(np.load(folder_c+'falsos_positivos_2/'+koi+'.npy'))
            y_val.append(0)
        except:
            i+=1
            continue
    else:
        x_val.append(np.load(folder_c+'confirmados/'+koi+'.npy'))
        y_val.append(1)
        try:
            x_val.append(np.load(folder_c+'confirmados_2/'+koi+'.npy'))
            y_val.append(1)
        except:
            i+=1
            continue
    i+=1
# Out:
# Cargando objeto K00889.01 con identificador 0 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07622.01 con identificador 1 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04924.01 con identificador 2 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01002.01 con identificador 3 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03351.01 con identificador 4 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02534.01 con identificador 5 es decir, etiqueta CONFIRMED
# Cargando objeto K04929.01 con identificador 6 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02178.01 con identificador 7 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06093.01 con identificador 8 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01987.01 con identificador 9 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07627.01 con identificador 10 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04934.01 con identificador 11 es decir, etiqueta CONFIRMED
# Cargando objeto K03735.01 con identificador 12 es decir, etiqueta CONFIRMED
# Cargando objeto K07631.01 con identificador 13 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01020.01 con identificador 14 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03598.01 con identificador 15 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04939.01 con identificador 16 es decir, etiqueta CONFIRMED
# Cargando objeto K02671.01 con identificador 17 es decir, etiqueta CONFIRMED
# Cargando objeto K06271.01 con identificador 18 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00363.01 con identificador 19 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00440.01 con identificador 20 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04941.01 con identificador 21 es decir, etiqueta CONFIRMED
# Cargando objeto K03699.01 con identificador 22 es decir, etiqueta CONFIRMED
# Cargando objeto K01003.01 con identificador 23 es decir, etiqueta CONFIRMED
# Cargando objeto K06272.01 con identificador 24 es decir, etiqueta CONFIRMED
# Cargando objeto K01000.01 con identificador 25 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01023.01 con identificador 26 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00053.01 con identificador 27 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00379.01 con identificador 28 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00378.01 con identificador 29 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03687.01 con identificador 30 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00380.01 con identificador 31 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04944.01 con identificador 32 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04945.01 con identificador 33 es decir, etiqueta CONFIRMED
# Cargando objeto K04946.01 con identificador 34 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04376.01 con identificador 35 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04947.01 con identificador 36 es decir, etiqueta CONFIRMED
# Cargando objeto K03709.01 con identificador 37 es decir, etiqueta CONFIRMED
# Cargando objeto K06284.01 con identificador 38 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03161.01 con identificador 39 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06095.01 con identificador 40 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06287.01 con identificador 41 es decir, etiqueta CONFIRMED
# Cargando objeto K04071.01 con identificador 42 es decir, etiqueta CONFIRMED
# Cargando objeto K02907.01 con identificador 43 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06290.01 con identificador 44 es decir, etiqueta CONFIRMED
# Cargando objeto K07637.01 con identificador 45 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08086.01 con identificador 46 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01022.01 con identificador 47 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04387.01 con identificador 48 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03446.01 con identificador 49 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07639.01 con identificador 50 es decir, etiqueta CONFIRMED
# Cargando objeto K01113.01 con identificador 51 es decir, etiqueta CONFIRMED
# Cargando objeto K03786.01 con identificador 52 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07640.01 con identificador 53 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06297.01 con identificador 54 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06298.01 con identificador 55 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03814.01 con identificador 56 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06099.01 con identificador 57 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00273.01 con identificador 58 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06305.01 con identificador 59 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06306.01 con identificador 60 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01115.01 con identificador 61 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02784.01 con identificador 62 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01111.01 con identificador 63 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03380.01 con identificador 64 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04965.01 con identificador 65 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00798.01 con identificador 66 es decir, etiqueta CONFIRMED
# Cargando objeto K01949.01 con identificador 67 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02055.01 con identificador 68 es decir, etiqueta CONFIRMED
# Cargando objeto K01105.01 con identificador 69 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02773.01 con identificador 70 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01108.03 con identificador 71 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03072.01 con identificador 72 es decir, etiqueta CONFIRMED
# Cargando objeto K04055.01 con identificador 73 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03643.01 con identificador 74 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01102.01 con identificador 75 es decir, etiqueta CONFIRMED
# Cargando objeto K01102.03 con identificador 76 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00966.01 con identificador 77 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02413.01 con identificador 78 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03057.02 con identificador 79 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01106.01 con identificador 80 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07650.01 con identificador 81 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06313.01 con identificador 82 es decir, etiqueta CONFIRMED
# Cargando objeto K06314.01 con identificador 83 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01089.01 con identificador 84 es decir, etiqueta CONFIRMED
# Cargando objeto K00121.01 con identificador 85 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04397.01 con identificador 86 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01759.01 con identificador 87 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03781.01 con identificador 88 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01830.01 con identificador 89 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02157.01 con identificador 90 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06322.01 con identificador 91 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03632.01 con identificador 92 es decir, etiqueta CONFIRMED
# Cargando objeto K04275.01 con identificador 93 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00965.01 con identificador 94 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03796.01 con identificador 95 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00441.01 con identificador 96 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03764.01 con identificador 97 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01196.01 con identificador 98 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01196.02 con identificador 99 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03590.01 con identificador 100 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06332.01 con identificador 101 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03582.01 con identificador 102 es decir, etiqueta CONFIRMED
# Cargando objeto K00549.01 con identificador 103 es decir, etiqueta CONFIRMED
# Cargando objeto K00300.01 con identificador 104 es decir, etiqueta CONFIRMED
# Cargando objeto K04527.01 con identificador 105 es decir, etiqueta CONFIRMED
# Cargando objeto K07655.01 con identificador 106 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01202.01 con identificador 107 es decir, etiqueta CONFIRMED
# Cargando objeto K06336.01 con identificador 108 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06337.01 con identificador 109 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02430.01 con identificador 110 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03641.01 con identificador 111 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00491.01 con identificador 112 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00624.02 con identificador 113 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00624.03 con identificador 114 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07658.01 con identificador 115 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06339.01 con identificador 116 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06340.01 con identificador 117 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03629.01 con identificador 118 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01177.01 con identificador 119 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03736.01 con identificador 120 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04191.01 con identificador 121 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03854.01 con identificador 122 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01194.02 con identificador 123 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01190.01 con identificador 124 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01221.01 con identificador 125 es decir, etiqueta CONFIRMED
# Cargando objeto K01221.02 con identificador 126 es decir, etiqueta CONFIRMED
# Cargando objeto K03862.02 con identificador 127 es decir, etiqueta CONFIRMED
# Cargando objeto K02596.01 con identificador 128 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07661.01 con identificador 129 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02667.01 con identificador 130 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03081.01 con identificador 131 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06348.01 con identificador 132 es decir, etiqueta CONFIRMED
# Cargando objeto K01179.01 con identificador 133 es decir, etiqueta CONFIRMED
# Cargando objeto K06349.01 con identificador 134 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02903.01 con identificador 135 es decir, etiqueta CONFIRMED
# Cargando objeto K06351.01 con identificador 136 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02279.01 con identificador 137 es decir, etiqueta CONFIRMED
# Cargando objeto K00302.01 con identificador 138 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02808.01 con identificador 139 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04476.01 con identificador 140 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00387.01 con identificador 141 es decir, etiqueta CONFIRMED
# Cargando objeto K02261.01 con identificador 142 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03005.01 con identificador 143 es decir, etiqueta CONFIRMED
# Cargando objeto K04103.01 con identificador 144 es decir, etiqueta CONFIRMED
# Cargando objeto K01176.01 con identificador 145 es decir, etiqueta CONFIRMED
# Cargando objeto K07666.01 con identificador 146 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06356.01 con identificador 147 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01189.01 con identificador 148 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05988.01 con identificador 149 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06362.01 con identificador 150 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00149.01 con identificador 151 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00807.01 con identificador 152 es decir, etiqueta CONFIRMED
# Cargando objeto K05010.01 con identificador 153 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00808.01 con identificador 154 es decir, etiqueta CONFIRMED
# Cargando objeto K05013.01 con identificador 155 es decir, etiqueta CONFIRMED
# Cargando objeto K00389.01 con identificador 156 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01187.01 con identificador 157 es decir, etiqueta CONFIRMED
# Cargando objeto K00390.01 con identificador 158 es decir, etiqueta CONFIRMED
# Cargando objeto K02284.01 con identificador 159 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05989.01 con identificador 160 es decir, etiqueta CONFIRMED
# Cargando objeto K03293.01 con identificador 161 es decir, etiqueta CONFIRMED
# Cargando objeto K03388.01 con identificador 162 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07675.01 con identificador 163 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01199.01 con identificador 164 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04761.01 con identificador 165 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05020.01 con identificador 166 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02932.01 con identificador 167 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00230.01 con identificador 168 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01182.01 con identificador 169 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01178.01 con identificador 170 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04084.01 con identificador 171 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01215.02 con identificador 172 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03435.01 con identificador 173 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02447.01 con identificador 174 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01912.01 con identificador 175 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01203.03 con identificador 176 es decir, etiqueta CONFIRMED
# Cargando objeto K04539.01 con identificador 177 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01811.01 con identificador 178 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00494.01 con identificador 179 es decir, etiqueta CONFIRMED
# Cargando objeto K01760.02 con identificador 180 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06107.01 con identificador 181 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01184.01 con identificador 182 es decir, etiqueta CONFIRMED
# Cargando objeto K05993.01 con identificador 183 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01180.01 con identificador 184 es decir, etiqueta CONFIRMED
# Cargando objeto K00969.01 con identificador 185 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02013.01 con identificador 186 es decir, etiqueta CONFIRMED
# Cargando objeto K03912.01 con identificador 187 es decir, etiqueta CONFIRMED
# Cargando objeto K02731.01 con identificador 188 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02239.01 con identificador 189 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06386.01 con identificador 190 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01339.01 con identificador 191 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04033.01 con identificador 192 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07684.01 con identificador 193 es decir, etiqueta CONFIRMED
# Cargando objeto K02210.01 con identificador 194 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00281.01 con identificador 195 es decir, etiqueta CONFIRMED
# Cargando objeto K01791.01 con identificador 196 es decir, etiqueta CONFIRMED
# Cargando objeto K05041.01 con identificador 197 es decir, etiqueta CONFIRMED
# Cargando objeto K03880.01 con identificador 198 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06388.01 con identificador 199 es decir, etiqueta CONFIRMED
# Cargando objeto K04046.01 con identificador 200 es decir, etiqueta CONFIRMED
# Cargando objeto K01330.02 con identificador 201 es decir, etiqueta CONFIRMED
# Cargando objeto K03156.03 con identificador 202 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01334.02 con identificador 203 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06389.01 con identificador 204 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03678.01 con identificador 205 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01335.01 con identificador 206 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01860.01 con identificador 207 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01860.02 con identificador 208 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00394.01 con identificador 209 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00395.01 con identificador 210 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08245.01 con identificador 211 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06393.01 con identificador 212 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02728.01 con identificador 213 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02709.01 con identificador 214 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05050.01 con identificador 215 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06398.01 con identificador 216 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02776.01 con identificador 217 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00813.01 con identificador 218 es decir, etiqueta CONFIRMED
# Cargando objeto K05995.01 con identificador 219 es decir, etiqueta CONFIRMED
# Cargando objeto K01317.01 con identificador 220 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05054.01 con identificador 221 es decir, etiqueta CONFIRMED
# Cargando objeto K01615.01 con identificador 222 es decir, etiqueta CONFIRMED
# Cargando objeto K07690.01 con identificador 223 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02652.01 con identificador 224 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01803.03 con identificador 225 es decir, etiqueta CONFIRMED
# Cargando objeto K00244.02 con identificador 226 es decir, etiqueta CONFIRMED
# Cargando objeto K06405.01 con identificador 227 es decir, etiqueta CONFIRMED
# Cargando objeto K06406.01 con identificador 228 es decir, etiqueta CONFIRMED
# Cargando objeto K02166.01 con identificador 229 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00397.01 con identificador 230 es decir, etiqueta CONFIRMED
# Cargando objeto K02922.01 con identificador 231 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03659.01 con identificador 232 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01340.01 con identificador 233 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07694.01 con identificador 234 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02514.01 con identificador 235 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06415.01 con identificador 236 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06416.01 con identificador 237 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05061.01 con identificador 238 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02441.01 con identificador 239 es decir, etiqueta CONFIRMED
# Cargando objeto K01338.01 con identificador 240 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03829.01 con identificador 241 es decir, etiqueta CONFIRMED
# Cargando objeto K01657.01 con identificador 242 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00626.01 con identificador 243 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02814.01 con identificador 244 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06420.01 con identificador 245 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06421.01 con identificador 246 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06423.01 con identificador 247 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04847.01 con identificador 248 es decir, etiqueta CONFIRMED
# Cargando objeto K00223.02 con identificador 249 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04787.01 con identificador 250 es decir, etiqueta CONFIRMED
# Cargando objeto K06116.01 con identificador 251 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01324.01 con identificador 252 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00627.01 con identificador 253 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06424.01 con identificador 254 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06430.01 con identificador 255 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00628.01 con identificador 256 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03437.01 con identificador 257 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03580.01 con identificador 258 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00630.01 con identificador 259 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04642.01 con identificador 260 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04128.01 con identificador 261 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06435.01 con identificador 262 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04219.01 con identificador 263 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04707.01 con identificador 264 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06436.01 con identificador 265 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00817.02 con identificador 266 es decir, etiqueta CONFIRMED
# Cargando objeto K01996.01 con identificador 267 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04884.01 con identificador 268 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05996.01 con identificador 269 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06446.01 con identificador 270 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00497.01 con identificador 271 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02249.01 con identificador 272 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04825.01 con identificador 273 es decir, etiqueta CONFIRMED
# Cargando objeto K06451.01 con identificador 274 es decir, etiqueta CONFIRMED
# Cargando objeto K06452.01 con identificador 275 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07707.01 con identificador 276 es decir, etiqueta CONFIRMED
# Cargando objeto K00632.01 con identificador 277 es decir, etiqueta CONFIRMED
# Cargando objeto K02395.01 con identificador 278 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00232.01 con identificador 279 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00232.02 con identificador 280 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00232.03 con identificador 281 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00232.04 con identificador 282 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07709.01 con identificador 283 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06458.01 con identificador 284 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01662.01 con identificador 285 es decir, etiqueta CONFIRMED
# Cargando objeto K04606.01 con identificador 286 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04537.01 con identificador 287 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04573.01 con identificador 288 es decir, etiqueta CONFIRMED
# Cargando objeto K04688.01 con identificador 289 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07710.01 con identificador 290 es decir, etiqueta CONFIRMED
# Cargando objeto K06461.01 con identificador 291 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01884.01 con identificador 292 es decir, etiqueta CONFIRMED
# Cargando objeto K04695.01 con identificador 293 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00500.04 con identificador 294 es decir, etiqueta CONFIRMED
# Cargando objeto K02844.01 con identificador 295 es decir, etiqueta CONFIRMED
# Cargando objeto K00634.01 con identificador 296 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06464.01 con identificador 297 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06467.01 con identificador 298 es decir, etiqueta CONFIRMED
# Cargando objeto K04717.01 con identificador 299 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05997.01 con identificador 300 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05100.01 con identificador 301 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06471.01 con identificador 302 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01973.01 con identificador 303 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01663.01 con identificador 304 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00819.01 con identificador 305 es decir, etiqueta CONFIRMED
# Cargando objeto K01665.01 con identificador 306 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03715.01 con identificador 307 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06476.01 con identificador 308 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03936.01 con identificador 309 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06478.01 con identificador 310 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03852.01 con identificador 311 es decir, etiqueta CONFIRMED
# Cargando objeto K02258.01 con identificador 312 es decir, etiqueta CONFIRMED
# Cargando objeto K05110.01 con identificador 313 es decir, etiqueta CONFIRMED
# Cargando objeto K02951.01 con identificador 314 es decir, etiqueta CONFIRMED
# Cargando objeto K05111.01 con identificador 315 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00405.01 con identificador 316 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02406.01 con identificador 317 es decir, etiqueta CONFIRMED
# Cargando objeto K01666.01 con identificador 318 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01605.01 con identificador 319 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07713.01 con identificador 320 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02966.01 con identificador 321 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03679.01 con identificador 322 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06490.01 con identificador 323 es decir, etiqueta CONFIRMED
# Cargando objeto K00026.01 con identificador 324 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06492.01 con identificador 325 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06493.01 con identificador 326 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06498.01 con identificador 327 es decir, etiqueta CONFIRMED
# Cargando objeto K08252.01 con identificador 328 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04280.01 con identificador 329 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04080.01 con identificador 330 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06503.01 con identificador 331 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03718.01 con identificador 332 es decir, etiqueta CONFIRMED
# Cargando objeto K04354.01 con identificador 333 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00822.01 con identificador 334 es decir, etiqueta CONFIRMED
# Cargando objeto K04211.01 con identificador 335 es decir, etiqueta CONFIRMED
# Cargando objeto K04211.02 con identificador 336 es decir, etiqueta CONFIRMED
# Cargando objeto K04127.01 con identificador 337 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02973.01 con identificador 338 es decir, etiqueta CONFIRMED
# Cargando objeto K04244.01 con identificador 339 es decir, etiqueta CONFIRMED
# Cargando objeto K01668.01 con identificador 340 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02955.01 con identificador 341 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01777.01 con identificador 342 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00638.02 con identificador 343 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06524.01 con identificador 344 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04789.01 con identificador 345 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00640.01 con identificador 346 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02698.01 con identificador 347 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03707.01 con identificador 348 es decir, etiqueta CONFIRMED
# Cargando objeto K07719.01 con identificador 349 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02708.01 con identificador 350 es decir, etiqueta CONFIRMED
# Cargando objeto K01603.01 con identificador 351 es decir, etiqueta CONFIRMED
# Cargando objeto K00642.01 con identificador 352 es decir, etiqueta CONFIRMED
# Cargando objeto K01564.01 con identificador 353 es decir, etiqueta CONFIRMED
# Cargando objeto K01670.01 con identificador 354 es decir, etiqueta CONFIRMED
# Cargando objeto K02719.01 con identificador 355 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06537.01 con identificador 356 es decir, etiqueta CONFIRMED
# Cargando objeto K07721.01 con identificador 357 es decir, etiqueta CONFIRMED
# Cargando objeto K03468.01 con identificador 358 es decir, etiqueta CONFIRMED
# Cargando objeto K03903.01 con identificador 359 es decir, etiqueta CONFIRMED
# Cargando objeto K01673.01 con identificador 360 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06550.01 con identificador 361 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01545.02 con identificador 362 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00502.01 con identificador 363 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06551.01 con identificador 364 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06554.01 con identificador 365 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06558.01 con identificador 366 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01589.04 con identificador 367 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03275.01 con identificador 368 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03806.01 con identificador 369 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06561.01 con identificador 370 es decir, etiqueta CONFIRMED
# Cargando objeto K03887.01 con identificador 371 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06563.01 con identificador 372 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00643.01 con identificador 373 es decir, etiqueta CONFIRMED
# Cargando objeto K00503.01 con identificador 374 es decir, etiqueta CONFIRMED
# Cargando objeto K01674.01 con identificador 375 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00248.02 con identificador 376 es decir, etiqueta CONFIRMED
# Cargando objeto K04327.01 con identificador 377 es decir, etiqueta CONFIRMED
# Cargando objeto K00645.01 con identificador 378 es decir, etiqueta CONFIRMED
# Cargando objeto K00833.01 con identificador 379 es decir, etiqueta CONFIRMED
# Cargando objeto K03444.02 con identificador 380 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06000.01 con identificador 381 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06002.01 con identificador 382 es decir, etiqueta CONFIRMED
# Cargando objeto K04323.02 con identificador 383 es decir, etiqueta CONFIRMED
# Cargando objeto K02478.01 con identificador 384 es decir, etiqueta CONFIRMED
# Cargando objeto K03988.01 con identificador 385 es decir, etiqueta CONFIRMED
# Cargando objeto K06003.01 con identificador 386 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06004.01 con identificador 387 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06573.01 con identificador 388 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03967.02 con identificador 389 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06005.01 con identificador 390 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06129.01 con identificador 391 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06006.01 con identificador 392 es decir, etiqueta CONFIRMED
# Cargando objeto K06575.01 con identificador 393 es decir, etiqueta CONFIRMED
# Cargando objeto K01836.01 con identificador 394 es decir, etiqueta CONFIRMED
# Cargando objeto K07726.01 con identificador 395 es decir, etiqueta CONFIRMED
# Cargando objeto K02510.01 con identificador 396 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03292.01 con identificador 397 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00834.02 con identificador 398 es decir, etiqueta CONFIRMED
# Cargando objeto K01567.02 con identificador 399 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01567.03 con identificador 400 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02713.01 con identificador 401 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04064.01 con identificador 402 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01778.01 con identificador 403 es decir, etiqueta CONFIRMED
# Cargando objeto K00409.01 con identificador 404 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00410.01 con identificador 405 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07729.01 con identificador 406 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03840.01 con identificador 407 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02161.01 con identificador 408 es decir, etiqueta CONFIRMED
# Cargando objeto K01585.01 con identificador 409 es decir, etiqueta CONFIRMED
# Cargando objeto K06583.01 con identificador 410 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06008.01 con identificador 411 es decir, etiqueta CONFIRMED
# Cargando objeto K05173.01 con identificador 412 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06010.01 con identificador 413 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04155.01 con identificador 414 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03485.01 con identificador 415 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04368.01 con identificador 416 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06012.01 con identificador 417 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03894.01 con identificador 418 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03969.01 con identificador 419 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02895.01 con identificador 420 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03798.01 con identificador 421 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04598.01 con identificador 422 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02707.02 con identificador 423 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04841.01 con identificador 424 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03199.01 con identificador 425 es decir, etiqueta CONFIRMED
# Cargando objeto K01930.02 con identificador 426 es decir, etiqueta CONFIRMED
# Cargando objeto K01930.03 con identificador 427 es decir, etiqueta CONFIRMED
# Cargando objeto K07730.01 con identificador 428 es decir, etiqueta CONFIRMED
# Cargando objeto K02668.01 con identificador 429 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04119.01 con identificador 430 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02854.01 con identificador 431 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02741.01 con identificador 432 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00257.01 con identificador 433 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02456.01 con identificador 434 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01677.01 con identificador 435 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06592.01 con identificador 436 es decir, etiqueta CONFIRMED
# Cargando objeto K00837.01 con identificador 437 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02501.01 con identificador 438 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02499.01 con identificador 439 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03797.01 con identificador 440 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02160.01 con identificador 441 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00224.01 con identificador 442 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03223.01 con identificador 443 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01571.01 con identificador 444 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03819.01 con identificador 445 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01621.01 con identificador 446 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00608.01 con identificador 447 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04220.01 con identificador 448 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05180.01 con identificador 449 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03949.01 con identificador 450 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02369.01 con identificador 451 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02254.01 con identificador 452 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00609.01 con identificador 453 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02345.01 con identificador 454 es decir, etiqueta CONFIRMED
# Cargando objeto K01565.01 con identificador 455 es decir, etiqueta CONFIRMED
# Cargando objeto K08256.01 con identificador 456 es decir, etiqueta CONFIRMED
# Cargando objeto K00448.01 con identificador 457 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00839.01 con identificador 458 es decir, etiqueta CONFIRMED
# Cargando objeto K02676.01 con identificador 459 es decir, etiqueta CONFIRMED
# Cargando objeto K03731.01 con identificador 460 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00412.01 con identificador 461 es decir, etiqueta CONFIRMED
# Cargando objeto K00610.01 con identificador 462 es decir, etiqueta CONFIRMED
# Cargando objeto K04097.02 con identificador 463 es decir, etiqueta CONFIRMED
# Cargando objeto K03144.01 con identificador 464 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03784.01 con identificador 465 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00505.01 con identificador 466 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00505.03 con identificador 467 es decir, etiqueta CONFIRMED
# Cargando objeto K00505.04 con identificador 468 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00283.01 con identificador 469 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04594.01 con identificador 470 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03000.01 con identificador 471 es decir, etiqueta CONFIRMED
# Cargando objeto K02752.01 con identificador 472 es decir, etiqueta CONFIRMED
# Cargando objeto K01011.01 con identificador 473 es decir, etiqueta CONFIRMED
# Cargando objeto K06623.01 con identificador 474 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06624.01 con identificador 475 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01006.01 con identificador 476 es decir, etiqueta CONFIRMED
# Cargando objeto K03951.01 con identificador 477 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04913.02 con identificador 478 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03810.01 con identificador 479 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06625.01 con identificador 480 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00449.01 con identificador 481 es decir, etiqueta CONFIRMED
# Cargando objeto K01005.01 con identificador 482 es decir, etiqueta CONFIRMED
# Cargando objeto K03412.01 con identificador 483 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01039.01 con identificador 484 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02614.01 con identificador 485 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06137.02 con identificador 486 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01043.01 con identificador 487 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03645.01 con identificador 488 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04293.01 con identificador 489 es decir, etiqueta CONFIRMED
# Cargando objeto K03332.01 con identificador 490 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07743.01 con identificador 491 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01787.01 con identificador 492 es decir, etiqueta CONFIRMED
# Cargando objeto K03071.01 con identificador 493 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01055.01 con identificador 494 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08258.01 con identificador 495 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00414.02 con identificador 496 es decir, etiqueta CONFIRMED
# Cargando objeto K03331.01 con identificador 497 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00843.01 con identificador 498 es decir, etiqueta CONFIRMED
# Cargando objeto K05209.01 con identificador 499 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00654.01 con identificador 500 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03947.02 con identificador 501 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06637.01 con identificador 502 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01052.03 con identificador 503 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04726.01 con identificador 504 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01053.01 con identificador 505 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02498.01 con identificador 506 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03319.03 con identificador 507 es decir, etiqueta CONFIRMED
# Cargando objeto K00655.01 con identificador 508 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00191.04 con identificador 509 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06018.01 con identificador 510 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02742.01 con identificador 511 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03476.01 con identificador 512 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01047.01 con identificador 513 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07756.01 con identificador 514 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04271.01 con identificador 515 es decir, etiqueta CONFIRMED
# Cargando objeto K00657.01 con identificador 516 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00304.01 con identificador 517 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08260.01 con identificador 518 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02070.01 con identificador 519 es decir, etiqueta CONFIRMED
# Cargando objeto K02071.01 con identificador 520 es decir, etiqueta CONFIRMED
# Cargando objeto K01061.01 con identificador 521 es decir, etiqueta CONFIRMED
# Cargando objeto K02167.01 con identificador 522 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00450.01 con identificador 523 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00200.01 con identificador 524 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00051.01 con identificador 525 es decir, etiqueta CONFIRMED
# Cargando objeto K06657.01 con identificador 526 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05233.01 con identificador 527 es decir, etiqueta CONFIRMED
# Cargando objeto K00305.01 con identificador 528 es decir, etiqueta CONFIRMED
# Cargando objeto K08116.01 con identificador 529 es decir, etiqueta CONFIRMED
# Cargando objeto K02098.02 con identificador 530 es decir, etiqueta CONFIRMED
# Cargando objeto K08117.01 con identificador 531 es decir, etiqueta CONFIRMED
# Cargando objeto K03458.01 con identificador 532 es decir, etiqueta CONFIRMED
# Cargando objeto K06020.01 con identificador 533 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06665.01 con identificador 534 es decir, etiqueta CONFIRMED
# Cargando objeto K02886.01 con identificador 535 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02336.01 con identificador 536 es decir, etiqueta CONFIRMED
# Cargando objeto K05243.01 con identificador 537 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06021.01 con identificador 538 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07766.01 con identificador 539 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03812.01 con identificador 540 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01794.01 con identificador 541 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08261.01 con identificador 542 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07768.01 con identificador 543 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07770.01 con identificador 544 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01687.01 con identificador 545 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02211.01 con identificador 546 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07771.01 con identificador 547 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03694.01 con identificador 548 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00451.01 con identificador 549 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01882.01 con identificador 550 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05250.01 con identificador 551 es decir, etiqueta CONFIRMED
# Cargando objeto K05251.01 con identificador 552 es decir, etiqueta CONFIRMED
# Cargando objeto K07772.01 con identificador 553 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05252.01 con identificador 554 es decir, etiqueta CONFIRMED
# Cargando objeto K02019.01 con identificador 555 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04068.01 con identificador 556 es decir, etiqueta CONFIRMED
# Cargando objeto K06679.01 con identificador 557 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02753.01 con identificador 558 es decir, etiqueta CONFIRMED
# Cargando objeto K00508.02 con identificador 559 es decir, etiqueta CONFIRMED
# Cargando objeto K06684.01 con identificador 560 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05260.01 con identificador 561 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03869.01 con identificador 562 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02702.01 con identificador 563 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01688.01 con identificador 564 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01122.01 con identificador 565 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05267.01 con identificador 566 es decir, etiqueta CONFIRMED
# Cargando objeto K02618.01 con identificador 567 es decir, etiqueta CONFIRMED
# Cargando objeto K02021.01 con identificador 568 es decir, etiqueta CONFIRMED
# Cargando objeto K01127.01 con identificador 569 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05270.02 con identificador 570 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05271.01 con identificador 571 es decir, etiqueta CONFIRMED
# Cargando objeto K06690.01 con identificador 572 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06691.01 con identificador 573 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02404.02 con identificador 574 es decir, etiqueta CONFIRMED
# Cargando objeto K02873.01 con identificador 575 es decir, etiqueta CONFIRMED
# Cargando objeto K05273.01 con identificador 576 es decir, etiqueta CONFIRMED
# Cargando objeto K01744.01 con identificador 577 es decir, etiqueta CONFIRMED
# Cargando objeto K00509.02 con identificador 578 es decir, etiqueta CONFIRMED
# Cargando objeto K06700.01 con identificador 579 es decir, etiqueta CONFIRMED
# Cargando objeto K01626.01 con identificador 580 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03035.01 con identificador 581 es decir, etiqueta CONFIRMED
# Cargando objeto K06703.01 con identificador 582 es decir, etiqueta CONFIRMED
# Cargando objeto K00510.01 con identificador 583 es decir, etiqueta CONFIRMED
# Cargando objeto K00510.02 con identificador 584 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00854.01 con identificador 585 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06709.01 con identificador 586 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01241.01 con identificador 587 es decir, etiqueta CONFIRMED
# Cargando objeto K01241.02 con identificador 588 es decir, etiqueta CONFIRMED
# Cargando objeto K00511.01 con identificador 589 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01231.01 con identificador 590 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01826.01 con identificador 591 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07781.01 con identificador 592 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01690.01 con identificador 593 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06719.01 con identificador 594 es decir, etiqueta CONFIRMED
# Cargando objeto K06720.01 con identificador 595 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03152.01 con identificador 596 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00416.01 con identificador 597 es decir, etiqueta FALSE POSITIVE
# ...
# Cargando objeto K04816.01 con identificador 1368 es decir, etiqueta CONFIRMED
# Cargando objeto K01989.01 con identificador 1369 es decir, etiqueta CONFIRMED
# Cargando objeto K01313.01 con identificador 1370 es decir, etiqueta CONFIRMED
# Cargando objeto K03925.03 con identificador 1371 es decir, etiqueta CONFIRMED
# Cargando objeto K04611.01 con identificador 1372 es decir, etiqueta CONFIRMED
# Cargando objeto K00174.01 con identificador 1373 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07377.01 con identificador 1374 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07382.01 con identificador 1375 es decir, etiqueta CONFIRMED
# Cargando objeto K00432.01 con identificador 1376 es decir, etiqueta CONFIRMED
# Cargando objeto K08034.01 con identificador 1377 es decir, etiqueta CONFIRMED
# Cargando objeto K00756.01 con identificador 1378 es decir, etiqueta CONFIRMED
# Cargando objeto K00535.01 con identificador 1379 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00117.02 con identificador 1380 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08216.01 con identificador 1381 es decir, etiqueta CONFIRMED
# Cargando objeto K02936.01 con identificador 1382 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00194.01 con identificador 1383 es decir, etiqueta CONFIRMED
# Cargando objeto K00757.01 con identificador 1384 es decir, etiqueta CONFIRMED
# Cargando objeto K00757.03 con identificador 1385 es decir, etiqueta CONFIRMED
# Cargando objeto K07387.01 con identificador 1386 es decir, etiqueta CONFIRMED
# Cargando objeto K03063.01 con identificador 1387 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00291.02 con identificador 1388 es decir, etiqueta CONFIRMED
# Cargando objeto K03121.01 con identificador 1389 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00433.02 con identificador 1390 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01284.01 con identificador 1391 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01887.01 con identificador 1392 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05846.01 con identificador 1393 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00343.02 con identificador 1394 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00112.02 con identificador 1395 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06233.01 con identificador 1396 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01643.01 con identificador 1397 es decir, etiqueta CONFIRMED
# Cargando objeto K01432.01 con identificador 1398 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01432.04 con identificador 1399 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00759.02 con identificador 1400 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03060.01 con identificador 1401 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01440.01 con identificador 1402 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01644.01 con identificador 1403 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00170.01 con identificador 1404 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03327.01 con identificador 1405 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01889.01 con identificador 1406 es decir, etiqueta CONFIRMED
# Cargando objeto K02442.01 con identificador 1407 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03364.01 con identificador 1408 es decir, etiqueta CONFIRMED
# Cargando objeto K00124.01 con identificador 1409 es decir, etiqueta CONFIRMED
# Cargando objeto K05865.01 con identificador 1410 es decir, etiqueta CONFIRMED
# Cargando objeto K08219.01 con identificador 1411 es decir, etiqueta CONFIRMED
# Cargando objeto K07409.01 con identificador 1412 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02485.01 con identificador 1413 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02485.03 con identificador 1414 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00276.01 con identificador 1415 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07412.01 con identificador 1416 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04039.01 con identificador 1417 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03334.01 con identificador 1418 es decir, etiqueta CONFIRMED
# Cargando objeto K04308.01 con identificador 1419 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08045.01 con identificador 1420 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01647.02 con identificador 1421 es decir, etiqueta CONFIRMED
# Cargando objeto K05875.01 con identificador 1422 es decir, etiqueta CONFIRMED
# Cargando objeto K00348.01 con identificador 1423 es decir, etiqueta CONFIRMED
# Cargando objeto K03724.01 con identificador 1424 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00293.01 con identificador 1425 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00763.01 con identificador 1426 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04517.01 con identificador 1427 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06236.02 con identificador 1428 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03003.01 con identificador 1429 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00482.01 con identificador 1430 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00294.01 con identificador 1431 es decir, etiqueta CONFIRMED
# Cargando objeto K01774.01 con identificador 1432 es decir, etiqueta CONFIRMED
# Cargando objeto K03110.01 con identificador 1433 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07433.01 con identificador 1434 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01802.01 con identificador 1435 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02015.01 con identificador 1436 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03744.01 con identificador 1437 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02645.01 con identificador 1438 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01651.01 con identificador 1439 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07440.01 con identificador 1440 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07441.01 con identificador 1441 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02069.01 con identificador 1442 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00330.01 con identificador 1443 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00330.02 con identificador 1444 es decir, etiqueta CONFIRMED
# Cargando objeto K01653.01 con identificador 1445 es decir, etiqueta CONFIRMED
# Cargando objeto K01428.01 con identificador 1446 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00277.01 con identificador 1447 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02195.01 con identificador 1448 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00766.01 con identificador 1449 es decir, etiqueta CONFIRMED
# Cargando objeto K02143.01 con identificador 1450 es decir, etiqueta CONFIRMED
# Cargando objeto K02482.01 con identificador 1451 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03015.01 con identificador 1452 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04036.01 con identificador 1453 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00351.01 con identificador 1454 es decir, etiqueta CONFIRMED
# Cargando objeto K00351.06 con identificador 1455 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02705.01 con identificador 1456 es decir, etiqueta CONFIRMED
# Cargando objeto K02771.01 con identificador 1457 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04845.01 con identificador 1458 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08225.01 con identificador 1459 es decir, etiqueta CONFIRMED
# Cargando objeto K07447.01 con identificador 1460 es decir, etiqueta CONFIRMED
# Cargando objeto K00769.01 con identificador 1461 es decir, etiqueta CONFIRMED
# Cargando objeto K02399.01 con identificador 1462 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07616.01 con identificador 1463 es decir, etiqueta CONFIRMED
# Cargando objeto K00772.01 con identificador 1464 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01422.03 con identificador 1465 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02296.01 con identificador 1466 es decir, etiqueta CONFIRMED
# Cargando objeto K07454.01 con identificador 1467 es decir, etiqueta CONFIRMED
# Cargando objeto K05906.01 con identificador 1468 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00773.01 con identificador 1469 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03101.01 con identificador 1470 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00168.03 con identificador 1471 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03749.01 con identificador 1472 es decir, etiqueta CONFIRMED
# Cargando objeto K03874.01 con identificador 1473 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08057.01 con identificador 1474 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03109.01 con identificador 1475 es decir, etiqueta CONFIRMED
# Cargando objeto K01437.03 con identificador 1476 es decir, etiqueta CONFIRMED
# Cargando objeto K05919.01 con identificador 1477 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00983.02 con identificador 1478 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03885.01 con identificador 1479 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04229.01 con identificador 1480 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07464.01 con identificador 1481 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01532.01 con identificador 1482 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00541.01 con identificador 1483 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07469.01 con identificador 1484 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01535.01 con identificador 1485 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00542.01 con identificador 1486 es decir, etiqueta CONFIRMED
# Cargando objeto K00133.01 con identificador 1487 es decir, etiqueta CONFIRMED
# Cargando objeto K02376.01 con identificador 1488 es decir, etiqueta CONFIRMED
# Cargando objeto K01465.01 con identificador 1489 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07473.01 con identificador 1490 es decir, etiqueta CONFIRMED
# Cargando objeto K03116.01 con identificador 1491 es decir, etiqueta CONFIRMED
# Cargando objeto K07476.01 con identificador 1492 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04745.01 con identificador 1493 es decir, etiqueta CONFIRMED
# Cargando objeto K01531.01 con identificador 1494 es decir, etiqueta CONFIRMED
# Cargando objeto K07478.01 con identificador 1495 es decir, etiqueta CONFIRMED
# Cargando objeto K00620.01 con identificador 1496 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00620.03 con identificador 1497 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02269.01 con identificador 1498 es decir, etiqueta CONFIRMED
# Cargando objeto K08065.01 con identificador 1499 es decir, etiqueta CONFIRMED
# Cargando objeto K02173.02 con identificador 1500 es decir, etiqueta CONFIRMED
# Cargando objeto K00543.01 con identificador 1501 es decir, etiqueta CONFIRMED
# Cargando objeto K07486.01 con identificador 1502 es decir, etiqueta CONFIRMED
# Cargando objeto K07487.01 con identificador 1503 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07488.01 con identificador 1504 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01828.01 con identificador 1505 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05940.01 con identificador 1506 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04607.01 con identificador 1507 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04461.01 con identificador 1508 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07491.01 con identificador 1509 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04729.01 con identificador 1510 es decir, etiqueta CONFIRMED
# Cargando objeto K00011.01 con identificador 1511 es decir, etiqueta CONFIRMED
# Cargando objeto K00780.01 con identificador 1512 es decir, etiqueta CONFIRMED
# Cargando objeto K08070.01 con identificador 1513 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07494.01 con identificador 1514 es decir, etiqueta CONFIRMED
# Cargando objeto K08295.01 con identificador 1515 es decir, etiqueta CONFIRMED
# Cargando objeto K02026.01 con identificador 1516 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01530.01 con identificador 1517 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01512.01 con identificador 1518 es decir, etiqueta CONFIRMED
# Cargando objeto K02433.02 con identificador 1519 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02433.07 con identificador 1520 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04375.01 con identificador 1521 es decir, etiqueta CONFIRMED
# Cargando objeto K07503.01 con identificador 1522 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06092.01 con identificador 1523 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04905.01 con identificador 1524 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08075.01 con identificador 1525 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07508.01 con identificador 1526 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00546.02 con identificador 1527 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02061.01 con identificador 1528 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00784.01 con identificador 1529 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04512.01 con identificador 1530 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00785.01 con identificador 1531 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00360.01 con identificador 1532 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02396.01 con identificador 1533 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02142.01 con identificador 1534 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02088.01 con identificador 1535 es decir, etiqueta CONFIRMED
# Cargando objeto K00153.02 con identificador 1536 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02372.01 con identificador 1537 es decir, etiqueta CONFIRMED
# Cargando objeto K02264.01 con identificador 1538 es decir, etiqueta CONFIRMED
# Cargando objeto K04148.01 con identificador 1539 es decir, etiqueta CONFIRMED
# Cargando objeto K05963.01 con identificador 1540 es decir, etiqueta CONFIRMED
# Cargando objeto K07521.02 con identificador 1541 es decir, etiqueta CONFIRMED
# Cargando objeto K00279.01 con identificador 1542 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00279.02 con identificador 1543 es decir, etiqueta CONFIRMED
# Cargando objeto K07522.01 con identificador 1544 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07523.01 con identificador 1545 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07527.01 con identificador 1546 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01474.01 con identificador 1547 es decir, etiqueta CONFIRMED
# Cargando objeto K01478.01 con identificador 1548 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00788.01 con identificador 1549 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00361.01 con identificador 1550 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01516.01 con identificador 1551 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08079.01 con identificador 1552 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02463.01 con identificador 1553 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06251.01 con identificador 1554 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07536.01 con identificador 1555 es decir, etiqueta CONFIRMED
# Cargando objeto K07538.01 con identificador 1556 es decir, etiqueta CONFIRMED
# Cargando objeto K00215.01 con identificador 1557 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04264.01 con identificador 1558 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08237.01 con identificador 1559 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03794.01 con identificador 1560 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07541.01 con identificador 1561 es decir, etiqueta CONFIRMED
# Cargando objeto K00548.01 con identificador 1562 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00791.01 con identificador 1563 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02847.01 con identificador 1564 es decir, etiqueta FALSE POSITIVE

# %%
x_test=[]
i=0
for koi in kois_test:
    print ("Cargando objeto", koi, 'con identificador',i, 'es decir, etiqueta', labels_train[i])
    x_test.append(np.load(folder_c+'candidatos/'+koi+'.npy'))
    try:
        x_test.append(np.load(folder_c+'candidatos_2/'+koi+'.npy'))
    except:
        i+=1
        continue
    i+=1
# Out:
# Cargando objeto K00958.01 con identificador 0 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00984.01 con identificador 1 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00994.01 con identificador 2 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00992.02 con identificador 3 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04359.01 con identificador 4 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03145.01 con identificador 5 es decir, etiqueta CONFIRMED
# Cargando objeto K03145.02 con identificador 6 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04053.01 con identificador 7 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04644.01 con identificador 8 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07624.01 con identificador 9 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04212.02 con identificador 10 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02538.01 con identificador 11 es decir, etiqueta CONFIRMED
# Cargando objeto K04926.01 con identificador 12 es decir, etiqueta CONFIRMED
# Cargando objeto K02351.01 con identificador 13 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02534.02 con identificador 14 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06093.02 con identificador 15 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02130.01 con identificador 16 es decir, etiqueta CONFIRMED
# Cargando objeto K06259.01 con identificador 17 es decir, etiqueta CONFIRMED
# Cargando objeto K06259.02 con identificador 18 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01029.01 con identificador 19 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08085.01 con identificador 20 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07628.01 con identificador 21 es decir, etiqueta CONFIRMED
# Cargando objeto K06263.01 con identificador 22 es decir, etiqueta CONFIRMED
# Cargando objeto K07630.01 con identificador 23 es decir, etiqueta CONFIRMED
# Cargando objeto K04709.01 con identificador 24 es decir, etiqueta CONFIRMED
# Cargando objeto K02610.01 con identificador 25 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02610.02 con identificador 26 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00151.01 con identificador 27 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04938.01 con identificador 28 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06267.01 con identificador 29 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01944.01 con identificador 30 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02603.01 con identificador 31 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00103.01 con identificador 32 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00379.02 con identificador 33 es decir, etiqueta CONFIRMED
# Cargando objeto K06274.01 con identificador 34 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02009.01 con identificador 35 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06276.01 con identificador 36 es decir, etiqueta CONFIRMED
# Cargando objeto K04655.01 con identificador 37 es decir, etiqueta CONFIRMED
# Cargando objeto K04581.01 con identificador 38 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01030.01 con identificador 39 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07635.01 con identificador 40 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02064.01 con identificador 41 es decir, etiqueta CONFIRMED
# Cargando objeto K03681.02 con identificador 42 es decir, etiqueta CONFIRMED
# Cargando objeto K07636.01 con identificador 43 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03077.01 con identificador 44 es decir, etiqueta CONFIRMED
# Cargando objeto K03077.02 con identificador 45 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03053.02 con identificador 46 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03459.01 con identificador 47 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02489.01 con identificador 48 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01942.01 con identificador 49 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01942.02 con identificador 50 es decir, etiqueta CONFIRMED
# Cargando objeto K06293.01 con identificador 51 es decir, etiqueta CONFIRMED
# Cargando objeto K07638.01 con identificador 52 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03416.01 con identificador 53 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04298.01 con identificador 54 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03259.01 con identificador 55 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01118.01 con identificador 56 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02081.01 con identificador 57 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02232.01 con identificador 58 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02232.02 con identificador 59 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04659.01 con identificador 60 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04857.01 con identificador 61 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01103.01 con identificador 62 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04957.02 con identificador 63 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06299.01 con identificador 64 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03034.01 con identificador 65 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04849.01 con identificador 66 es decir, etiqueta CONFIRMED
# Cargando objeto K07641.01 con identificador 67 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02807.01 con identificador 68 es decir, etiqueta CONFIRMED
# Cargando objeto K04875.01 con identificador 69 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06301.01 con identificador 70 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04389.01 con identificador 71 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02380.01 con identificador 72 es decir, etiqueta CONFIRMED
# Cargando objeto K02186.01 con identificador 73 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04844.01 con identificador 74 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01878.01 con identificador 75 es decir, etiqueta CONFIRMED
# Cargando objeto K04963.01 con identificador 76 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03483.01 con identificador 77 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04145.01 con identificador 78 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04395.01 con identificador 79 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03225.01 con identificador 80 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01112.01 con identificador 81 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07644.01 con identificador 82 es decir, etiqueta CONFIRMED
# Cargando objeto K04144.01 con identificador 83 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00797.01 con identificador 84 es decir, etiqueta CONFIRMED
# Cargando objeto K03203.01 con identificador 85 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02490.01 con identificador 86 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02055.03 con identificador 87 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07645.01 con identificador 88 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03395.01 con identificador 89 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04548.01 con identificador 90 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02150.01 con identificador 91 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02150.02 con identificador 92 es decir, etiqueta CONFIRMED
# Cargando objeto K03068.01 con identificador 93 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03068.02 con identificador 94 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07648.01 con identificador 95 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03343.01 con identificador 96 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04967.01 con identificador 97 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02066.01 con identificador 98 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01106.03 con identificador 99 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00799.01 con identificador 100 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01089.02 con identificador 101 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02052.01 con identificador 102 es decir, etiqueta CONFIRMED
# Cargando objeto K03075.01 con identificador 103 es decir, etiqueta CONFIRMED
# Cargando objeto K01095.01 con identificador 104 es decir, etiqueta CONFIRMED
# Cargando objeto K01845.02 con identificador 105 es decir, etiqueta CONFIRMED
# Cargando objeto K04972.01 con identificador 106 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02723.01 con identificador 107 es decir, etiqueta CONFIRMED
# Cargando objeto K06329.01 con identificador 108 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03448.01 con identificador 109 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06331.01 con identificador 110 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00268.01 con identificador 111 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03876.01 con identificador 112 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02288.01 con identificador 113 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02043.01 con identificador 114 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04205.01 con identificador 115 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00802.01 con identificador 116 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03340.01 con identificador 117 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03340.02 con identificador 118 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04626.01 con identificador 119 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04987.01 con identificador 120 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03279.01 con identificador 121 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02755.01 con identificador 122 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00366.01 con identificador 123 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06342.01 con identificador 124 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04535.01 con identificador 125 es decir, etiqueta CONFIRMED
# Cargando objeto K02194.03 con identificador 126 es decir, etiqueta CONFIRMED
# Cargando objeto K04357.01 con identificador 127 es decir, etiqueta CONFIRMED
# Cargando objeto K04992.01 con identificador 128 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04456.01 con identificador 129 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04307.01 con identificador 130 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03398.02 con identificador 131 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03398.03 con identificador 132 es decir, etiqueta CONFIRMED
# Cargando objeto K08242.01 con identificador 133 es decir, etiqueta CONFIRMED
# Cargando objeto K01901.01 con identificador 134 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06103.02 con identificador 135 es decir, etiqueta CONFIRMED
# Cargando objeto K00804.01 con identificador 136 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04385.01 con identificador 137 es decir, etiqueta CONFIRMED
# Cargando objeto K04385.03 con identificador 138 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04999.01 con identificador 139 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01861.01 con identificador 140 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07662.01 con identificador 141 es decir, etiqueta CONFIRMED
# Cargando objeto K02750.01 con identificador 142 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06352.01 con identificador 143 es decir, etiqueta CONFIRMED
# Cargando objeto K08089.01 con identificador 144 es decir, etiqueta CONFIRMED
# Cargando objeto K06353.01 con identificador 145 es decir, etiqueta CONFIRMED
# Cargando objeto K03423.01 con identificador 146 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04103.02 con identificador 147 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06355.01 con identificador 148 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03142.01 con identificador 149 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03108.01 con identificador 150 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03520.01 con identificador 151 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05007.01 con identificador 152 es decir, etiqueta CONFIRMED
# Cargando objeto K05007.02 con identificador 153 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04853.01 con identificador 154 es decir, etiqueta CONFIRMED
# Cargando objeto K06104.01 con identificador 155 es decir, etiqueta CONFIRMED
# Cargando objeto K07668.01 con identificador 156 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06358.01 con identificador 157 es decir, etiqueta CONFIRMED
# Cargando objeto K04526.01 con identificador 158 es decir, etiqueta CONFIRMED
# Cargando objeto K04526.02 con identificador 159 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00388.01 con identificador 160 es decir, etiqueta CONFIRMED
# Cargando objeto K06361.01 con identificador 161 es decir, etiqueta CONFIRMED
# Cargando objeto K07670.01 con identificador 162 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05016.01 con identificador 163 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03389.01 con identificador 164 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04780.01 con identificador 165 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07673.01 con identificador 166 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06368.01 con identificador 167 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01191.01 con identificador 168 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00004.01 con identificador 169 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04685.01 con identificador 170 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07676.01 con identificador 171 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00221.02 con identificador 172 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04084.03 con identificador 173 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00810.01 con identificador 174 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01193.01 con identificador 175 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02084.01 con identificador 176 es decir, etiqueta CONFIRMED
# Cargando objeto K06375.01 con identificador 177 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02519.01 con identificador 178 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07678.01 con identificador 179 es decir, etiqueta CONFIRMED
# Cargando objeto K02295.01 con identificador 180 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07679.01 con identificador 181 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00100.01 con identificador 182 es decir, etiqueta CONFIRMED
# Cargando objeto K04570.01 con identificador 183 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01201.01 con identificador 184 es decir, etiqueta CONFIRMED
# Cargando objeto K01761.01 con identificador 185 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03066.01 con identificador 186 es decir, etiqueta CONFIRMED
# Cargando objeto K07680.01 con identificador 187 es decir, etiqueta CONFIRMED
# Cargando objeto K03041.01 con identificador 188 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07681.01 con identificador 189 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01328.01 con identificador 190 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01336.04 con identificador 191 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04166.01 con identificador 192 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05040.01 con identificador 193 es decir, etiqueta CONFIRMED
# Cargando objeto K02117.01 con identificador 194 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00280.01 con identificador 195 es decir, etiqueta CONFIRMED
# Cargando objeto K07685.01 con identificador 196 es decir, etiqueta CONFIRMED
# Cargando objeto K07685.02 con identificador 197 es decir, etiqueta CONFIRMED
# Cargando objeto K01864.01 con identificador 198 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03156.01 con identificador 199 es decir, etiqueta CONFIRMED
# Cargando objeto K01860.03 con identificador 200 es decir, etiqueta CONFIRMED
# Cargando objeto K03864.01 con identificador 201 es decir, etiqueta CONFIRMED
# Cargando objeto K03864.02 con identificador 202 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02386.01 con identificador 203 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02531.01 con identificador 204 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04427.01 con identificador 205 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02172.01 con identificador 206 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02172.02 con identificador 207 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01934.01 con identificador 208 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02216.01 con identificador 209 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02821.01 con identificador 210 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00396.01 con identificador 211 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07687.01 con identificador 212 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03202.01 con identificador 213 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03358.01 con identificador 214 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04810.01 con identificador 215 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06399.01 con identificador 216 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01331.01 con identificador 217 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01619.01 con identificador 218 es decir, etiqueta CONFIRMED
# Cargando objeto K04774.01 con identificador 219 es decir, etiqueta CONFIRMED
# Cargando objeto K06401.01 con identificador 220 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01803.01 con identificador 221 es decir, etiqueta CONFIRMED
# Cargando objeto K01738.01 con identificador 222 es decir, etiqueta CONFIRMED
# Cargando objeto K03258.01 con identificador 223 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07693.01 con identificador 224 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02942.01 con identificador 225 es decir, etiqueta CONFIRMED
# Cargando objeto K02942.02 con identificador 226 es decir, etiqueta CONFIRMED
# Cargando objeto K08246.01 con identificador 227 es decir, etiqueta CONFIRMED
# Cargando objeto K00625.01 con identificador 228 es decir, etiqueta CONFIRMED
# Cargando objeto K03168.01 con identificador 229 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02303.02 con identificador 230 es decir, etiqueta CONFIRMED
# Cargando objeto K01338.02 con identificador 231 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01338.03 con identificador 232 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01656.01 con identificador 233 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03878.02 con identificador 234 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02229.01 con identificador 235 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04452.01 con identificador 236 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05067.01 con identificador 237 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00626.02 con identificador 238 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02547.01 con identificador 239 es decir, etiqueta CONFIRMED
# Cargando objeto K00815.01 con identificador 240 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04506.01 con identificador 241 es decir, etiqueta CONFIRMED
# Cargando objeto K02855.01 con identificador 242 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04288.02 con identificador 243 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04288.04 con identificador 244 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04157.01 con identificador 245 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04157.02 con identificador 246 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02691.01 con identificador 247 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05071.01 con identificador 248 es decir, etiqueta CONFIRMED
# Cargando objeto K04353.01 con identificador 249 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08249.01 con identificador 250 es decir, etiqueta CONFIRMED
# Cargando objeto K04680.01 con identificador 251 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03811.01 con identificador 252 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03437.02 con identificador 253 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00143.01 con identificador 254 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01659.01 con identificador 255 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02393.01 con identificador 256 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02393.02 con identificador 257 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02560.01 con identificador 258 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07700.01 con identificador 259 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04056.01 con identificador 260 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03069.01 con identificador 261 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03184.01 con identificador 262 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03184.03 con identificador 263 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01996.02 con identificador 264 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07703.01 con identificador 265 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06120.01 con identificador 266 es decir, etiqueta CONFIRMED
# Cargando objeto K07704.01 con identificador 267 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03572.01 con identificador 268 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04649.01 con identificador 269 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07706.01 con identificador 270 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02971.01 con identificador 271 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02971.02 con identificador 272 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01475.01 con identificador 273 es decir, etiqueta CONFIRMED
# Cargando objeto K01475.02 con identificador 274 es decir, etiqueta CONFIRMED
# Cargando objeto K01475.03 con identificador 275 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02243.03 con identificador 276 es decir, etiqueta CONFIRMED
# Cargando objeto K04367.01 con identificador 277 es decir, etiqueta CONFIRMED
# Cargando objeto K05088.01 con identificador 278 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07708.01 con identificador 279 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04004.01 con identificador 280 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00367.01 con identificador 281 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03823.01 con identificador 282 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01660.01 con identificador 283 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02739.02 con identificador 284 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00605.02 con identificador 285 es decir, etiqueta CONFIRMED
# Cargando objeto K01541.01 con identificador 286 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04813.01 con identificador 287 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04498.01 con identificador 288 es decir, etiqueta CONFIRMED
# Cargando objeto K03469.01 con identificador 289 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02900.01 con identificador 290 es decir, etiqueta CONFIRMED
# Cargando objeto K01884.02 con identificador 291 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03061.01 con identificador 292 es decir, etiqueta CONFIRMED
# Cargando objeto K02120.01 con identificador 293 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01602.01 con identificador 294 es decir, etiqueta CONFIRMED
# Cargando objeto K01602.02 con identificador 295 es decir, etiqueta CONFIRMED
# Cargando objeto K05098.01 con identificador 296 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05104.01 con identificador 297 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01582.01 con identificador 298 es decir, etiqueta CONFIRMED
# Cargando objeto K04766.01 con identificador 299 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02962.01 con identificador 300 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06475.01 con identificador 301 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02899.01 con identificador 302 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07711.01 con identificador 303 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04377.01 con identificador 304 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01936.01 con identificador 305 es decir, etiqueta CONFIRMED
# Cargando objeto K03936.02 con identificador 306 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00501.01 con identificador 307 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07712.01 con identificador 308 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04524.01 con identificador 309 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04524.02 con identificador 310 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04524.03 con identificador 311 es decir, etiqueta CONFIRMED
# Cargando objeto K02237.01 con identificador 312 es decir, etiqueta CONFIRMED
# Cargando objeto K03770.01 con identificador 313 es decir, etiqueta CONFIRMED
# Cargando objeto K00635.01 con identificador 314 es decir, etiqueta CONFIRMED
# Cargando objeto K05117.01 con identificador 315 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01573.01 con identificador 316 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01573.02 con identificador 317 es decir, etiqueta CONFIRMED
# Cargando objeto K04546.01 con identificador 318 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01597.01 con identificador 319 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03065.01 con identificador 320 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02462.01 con identificador 321 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01843.02 con identificador 322 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07715.01 con identificador 323 es decir, etiqueta CONFIRMED
# Cargando objeto K03045.01 con identificador 324 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04320.01 con identificador 325 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02607.01 con identificador 326 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04331.01 con identificador 327 es decir, etiqueta CONFIRMED
# Cargando objeto K07716.01 con identificador 328 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02435.01 con identificador 329 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08253.01 con identificador 330 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02878.01 con identificador 331 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01924.01 con identificador 332 es decir, etiqueta CONFIRMED
# Cargando objeto K01822.01 con identificador 333 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02241.01 con identificador 334 es decir, etiqueta CONFIRMED
# Cargando objeto K04428.01 con identificador 335 es decir, etiqueta CONFIRMED
# Cargando objeto K04208.01 con identificador 336 es decir, etiqueta CONFIRMED
# Cargando objeto K00641.01 con identificador 337 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05129.01 con identificador 338 es decir, etiqueta CONFIRMED
# Cargando objeto K06532.01 con identificador 339 es decir, etiqueta CONFIRMED
# Cargando objeto K02532.01 con identificador 340 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02563.02 con identificador 341 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04246.02 con identificador 342 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05132.01 con identificador 343 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02719.02 con identificador 344 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06538.01 con identificador 345 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03323.01 con identificador 346 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01671.01 con identificador 347 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02695.01 con identificador 348 es decir, etiqueta CONFIRMED
# Cargando objeto K04178.01 con identificador 349 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04912.01 con identificador 350 es decir, etiqueta CONFIRMED
# Cargando objeto K02158.01 con identificador 351 es decir, etiqueta CONFIRMED
# Cargando objeto K02158.02 con identificador 352 es decir, etiqueta CONFIRMED
# Cargando objeto K03474.01 con identificador 353 es decir, etiqueta CONFIRMED
# Cargando objeto K01563.03 con identificador 354 es decir, etiqueta CONFIRMED
# Cargando objeto K04713.01 con identificador 355 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03368.01 con identificador 356 es decir, etiqueta CONFIRMED
# Cargando objeto K06546.01 con identificador 357 es decir, etiqueta CONFIRMED
# Cargando objeto K01545.01 con identificador 358 es decir, etiqueta CONFIRMED
# Cargando objeto K01547.01 con identificador 359 es decir, etiqueta CONFIRMED
# Cargando objeto K05149.01 con identificador 360 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05150.01 con identificador 361 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03463.01 con identificador 362 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06557.01 con identificador 363 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00130.01 con identificador 364 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04750.01 con identificador 365 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04409.01 con identificador 366 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01562.02 con identificador 367 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02666.01 con identificador 368 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02297.01 con identificador 369 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04467.01 con identificador 370 es decir, etiqueta CONFIRMED
# Cargando objeto K06568.01 con identificador 371 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02219.01 con identificador 372 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01675.01 con identificador 373 es decir, etiqueta CONFIRMED
# Cargando objeto K02690.01 con identificador 374 es decir, etiqueta CONFIRMED
# Cargando objeto K05155.01 con identificador 375 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00645.02 con identificador 376 es decir, etiqueta CONFIRMED
# Cargando objeto K00182.01 con identificador 377 es decir, etiqueta CONFIRMED
# Cargando objeto K03444.01 con identificador 378 es decir, etiqueta CONFIRMED
# Cargando objeto K03444.03 con identificador 379 es decir, etiqueta CONFIRMED
# Cargando objeto K02370.01 con identificador 380 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04323.01 con identificador 381 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03813.01 con identificador 382 es decir, etiqueta CONFIRMED
# Cargando objeto K04591.01 con identificador 383 es decir, etiqueta CONFIRMED
# Cargando objeto K05157.01 con identificador 384 es decir, etiqueta CONFIRMED
# Cargando objeto K03856.01 con identificador 385 es decir, etiqueta CONFIRMED
# Cargando objeto K06130.01 con identificador 386 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04558.01 con identificador 387 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02471.01 con identificador 388 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02835.01 con identificador 389 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04907.01 con identificador 390 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00607.01 con identificador 391 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05169.01 con identificador 392 es decir, etiqueta CONFIRMED
# Cargando objeto K00554.01 con identificador 393 es decir, etiqueta CONFIRMED
# Cargando objeto K02970.01 con identificador 394 es decir, etiqueta CONFIRMED
# Cargando objeto K06579.01 con identificador 395 es decir, etiqueta CONFIRMED
# Cargando objeto K04508.01 con identificador 396 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06582.01 con identificador 397 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01599.01 con identificador 398 es decir, etiqueta CONFIRMED
# Cargando objeto K01599.02 con identificador 399 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03050.01 con identificador 400 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01546.01 con identificador 401 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04541.01 con identificador 402 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04541.02 con identificador 403 es decir, etiqueta CONFIRMED
# Cargando objeto K01962.01 con identificador 404 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04067.01 con identificador 405 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00647.02 con identificador 406 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01681.01 con identificador 407 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01681.03 con identificador 408 es decir, etiqueta CONFIRMED
# Cargando objeto K01681.04 con identificador 409 es decir, etiqueta CONFIRMED
# Cargando objeto K02332.01 con identificador 410 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01590.01 con identificador 411 es decir, etiqueta CONFIRMED
# Cargando objeto K01590.02 con identificador 412 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01590.03 con identificador 413 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03226.01 con identificador 414 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03226.02 con identificador 415 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03119.01 con identificador 416 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04495.01 con identificador 417 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03377.01 con identificador 418 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05179.01 con identificador 419 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03309.01 con identificador 420 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06601.01 con identificador 421 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02191.01 con identificador 422 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02369.03 con identificador 423 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03206.01 con identificador 424 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00649.02 con identificador 425 es decir, etiqueta CONFIRMED
# Cargando objeto K02915.01 con identificador 426 es decir, etiqueta CONFIRMED
# Cargando objeto K03341.01 con identificador 427 es decir, etiqueta CONFIRMED
# Cargando objeto K03341.02 con identificador 428 es decir, etiqueta CONFIRMED
# Cargando objeto K02415.01 con identificador 429 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06132.01 con identificador 430 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06132.03 con identificador 431 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04705.01 con identificador 432 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04837.01 con identificador 433 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04778.01 con identificador 434 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04827.01 con identificador 435 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08257.01 con identificador 436 es decir, etiqueta CONFIRMED
# Cargando objeto K04587.01 con identificador 437 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07735.01 con identificador 438 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04097.01 con identificador 439 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01897.01 con identificador 440 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04756.01 con identificador 441 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06617.01 con identificador 442 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02091.01 con identificador 443 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00555.02 con identificador 444 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02783.01 con identificador 445 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04744.01 con identificador 446 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03396.01 con identificador 447 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06619.01 con identificador 448 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02358.01 con identificador 449 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02189.01 con identificador 450 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01793.01 con identificador 451 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04913.01 con identificador 452 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01928.01 con identificador 453 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04002.01 con identificador 454 es decir, etiqueta CONFIRMED
# Cargando objeto K02802.01 con identificador 455 es decir, etiqueta CONFIRMED
# Cargando objeto K00506.01 con identificador 456 es decir, etiqueta CONFIRMED
# Cargando objeto K04443.01 con identificador 457 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04259.01 con identificador 458 es decir, etiqueta CONFIRMED
# Cargando objeto K00650.01 con identificador 459 es decir, etiqueta CONFIRMED
# Cargando objeto K02927.01 con identificador 460 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00841.03 con identificador 461 es decir, etiqueta CONFIRMED
# Cargando objeto K02675.02 con identificador 462 es decir, etiqueta CONFIRMED
# Cargando objeto K06016.01 con identificador 463 es decir, etiqueta CONFIRMED
# Cargando objeto K08107.01 con identificador 464 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04398.01 con identificador 465 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06630.01 con identificador 466 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06137.01 con identificador 467 es decir, etiqueta CONFIRMED
# Cargando objeto K04686.01 con identificador 468 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01839.02 con identificador 469 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08109.01 con identificador 470 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05207.01 con identificador 471 es decir, etiqueta CONFIRMED
# Cargando objeto K06631.01 con identificador 472 es decir, etiqueta CONFIRMED
# Cargando objeto K07744.01 con identificador 473 es decir, etiqueta CONFIRMED
# Cargando objeto K04156.01 con identificador 474 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07746.01 con identificador 475 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02744.02 con identificador 476 es decir, etiqueta CONFIRMED
# Cargando objeto K07749.01 con identificador 477 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07750.01 con identificador 478 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00126.02 con identificador 479 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03692.01 con identificador 480 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03029.01 con identificador 481 es decir, etiqueta CONFIRMED
# Cargando objeto K03029.02 con identificador 482 es decir, etiqueta CONFIRMED
# Cargando objeto K02801.01 con identificador 483 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02377.01 con identificador 484 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04069.01 con identificador 485 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01995.01 con identificador 486 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02250.01 con identificador 487 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02250.02 con identificador 488 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02525.01 con identificador 489 es decir, etiqueta CONFIRMED
# Cargando objeto K05211.01 con identificador 490 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02733.01 con identificador 491 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04633.01 con identificador 492 es decir, etiqueta CONFIRMED
# Cargando objeto K08111.01 con identificador 493 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08259.01 con identificador 494 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01053.02 con identificador 495 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04661.01 con identificador 496 es decir, etiqueta CONFIRMED
# Cargando objeto K02479.01 con identificador 497 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03319.01 con identificador 498 es decir, etiqueta CONFIRMED
# Cargando objeto K06641.01 con identificador 499 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03909.01 con identificador 500 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00191.02 con identificador 501 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00191.03 con identificador 502 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04550.01 con identificador 503 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03140.01 con identificador 504 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00558.01 con identificador 505 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02321.01 con identificador 506 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02321.02 con identificador 507 es decir, etiqueta CONFIRMED
# Cargando objeto K02967.01 con identificador 508 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03190.01 con identificador 509 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05220.01 con identificador 510 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01855.01 con identificador 511 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06646.01 con identificador 512 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05224.01 con identificador 513 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02949.01 con identificador 514 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02949.02 con identificador 515 es decir, etiqueta CONFIRMED
# Cargando objeto K00304.02 con identificador 516 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07759.01 con identificador 517 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04764.01 con identificador 518 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01685.01 con identificador 519 es decir, etiqueta CONFIRMED
# Cargando objeto K03500.01 con identificador 520 es decir, etiqueta CONFIRMED
# Cargando objeto K03500.02 con identificador 521 es decir, etiqueta CONFIRMED
# Cargando objeto K02001.01 con identificador 522 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02315.01 con identificador 523 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04632.01 con identificador 524 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03004.02 con identificador 525 es decir, etiqueta CONFIRMED
# Cargando objeto K07762.01 con identificador 526 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07764.01 con identificador 527 es decir, etiqueta CONFIRMED
# Cargando objeto K01058.01 con identificador 528 es decir, etiqueta CONFIRMED
# Cargando objeto K06666.01 con identificador 529 es decir, etiqueta CONFIRMED
# Cargando objeto K03307.01 con identificador 530 es decir, etiqueta CONFIRMED
# Cargando objeto K01051.01 con identificador 531 es decir, etiqueta CONFIRMED
# Cargando objeto K04123.01 con identificador 532 es decir, etiqueta CONFIRMED
# Cargando objeto K04602.01 con identificador 533 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02469.01 con identificador 534 es decir, etiqueta CONFIRMED
# Cargando objeto K03179.01 con identificador 535 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02542.01 con identificador 536 es decir, etiqueta CONFIRMED
# Cargando objeto K04496.01 con identificador 537 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04216.01 con identificador 538 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06672.01 con identificador 539 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02829.01 con identificador 540 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04463.01 con identificador 541 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02636.01 con identificador 542 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02398.01 con identificador 543 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03397.01 con identificador 544 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05249.01 con identificador 545 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01750.02 con identificador 546 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02638.01 con identificador 547 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04793.01 con identificador 548 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06145.03 con identificador 549 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04274.01 con identificador 550 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07773.01 con identificador 551 es decir, etiqueta CONFIRMED
# Cargando objeto K04715.01 con identificador 552 es decir, etiqueta CONFIRMED
# Cargando objeto K06680.01 con identificador 553 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01613.02 con identificador 554 es decir, etiqueta CONFIRMED
# Cargando objeto K01613.03 con identificador 555 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04477.01 con identificador 556 es decir, etiqueta CONFIRMED
# Cargando objeto K04477.02 con identificador 557 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07774.01 con identificador 558 es decir, etiqueta CONFIRMED
# Cargando objeto K07775.01 con identificador 559 es decir, etiqueta CONFIRMED
# Cargando objeto K00415.01 con identificador 560 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04302.01 con identificador 561 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00308.01 con identificador 562 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00212.01 con identificador 563 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06687.01 con identificador 564 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02050.02 con identificador 565 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00611.01 con identificador 566 es decir, etiqueta CONFIRMED
# Cargando objeto K04627.01 con identificador 567 es decir, etiqueta CONFIRMED
# Cargando objeto K02065.01 con identificador 568 es decir, etiqueta CONFIRMED
# Cargando objeto K06689.01 con identificador 569 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02775.01 con identificador 570 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04410.01 con identificador 571 es decir, etiqueta CONFIRMED
# Cargando objeto K07776.01 con identificador 572 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08263.01 con identificador 573 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02948.01 con identificador 574 es decir, etiqueta CONFIRMED
# Cargando objeto K03040.01 con identificador 575 es decir, etiqueta CONFIRMED
# Cargando objeto K04794.01 con identificador 576 es decir, etiqueta CONFIRMED
# Cargando objeto K01127.03 con identificador 577 es decir, etiqueta CONFIRMED
# Cargando objeto K04391.01 con identificador 578 es decir, etiqueta CONFIRMED
# Cargando objeto K02404.01 con identificador 579 es decir, etiqueta CONFIRMED
# Cargando objeto K03503.01 con identificador 580 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05276.01 con identificador 581 es decir, etiqueta CONFIRMED
# Cargando objeto K04554.01 con identificador 582 es decir, etiqueta CONFIRMED
# Cargando objeto K02811.01 con identificador 583 es decir, etiqueta CONFIRMED
# Cargando objeto K05278.01 con identificador 584 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00239.02 con identificador 585 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05279.01 con identificador 586 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06705.01 con identificador 587 es decir, etiqueta CONFIRMED
# Cargando objeto K04900.01 con identificador 588 es decir, etiqueta CONFIRMED
# Cargando objeto K04861.01 con identificador 589 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03554.01 con identificador 590 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04054.01 con identificador 591 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02757.01 con identificador 592 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02828.02 con identificador 593 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06707.01 con identificador 594 es decir, etiqueta CONFIRMED
# Cargando objeto K02976.01 con identificador 595 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01246.01 con identificador 596 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05284.01 con identificador 597 es decir, etiqueta FALSE POSITIVE
# ...
# Cargando objeto K01863.01 con identificador 1600 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01427.02 con identificador 1601 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07410.01 con identificador 1602 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04896.01 con identificador 1603 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04896.02 con identificador 1604 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07411.01 con identificador 1605 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03027.01 con identificador 1606 es decir, etiqueta CONFIRMED
# Cargando objeto K00760.01 con identificador 1607 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08043.01 con identificador 1608 es decir, etiqueta CONFIRMED
# Cargando objeto K05874.01 con identificador 1609 es decir, etiqueta CONFIRMED
# Cargando objeto K04601.01 con identificador 1610 es decir, etiqueta CONFIRMED
# Cargando objeto K01648.01 con identificador 1611 es decir, etiqueta CONFIRMED
# Cargando objeto K00971.01 con identificador 1612 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04653.01 con identificador 1613 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08046.01 con identificador 1614 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00252.01 con identificador 1615 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07416.01 con identificador 1616 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00347.01 con identificador 1617 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00977.01 con identificador 1618 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02329.01 con identificador 1619 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02813.01 con identificador 1620 es decir, etiqueta CONFIRMED
# Cargando objeto K07426.01 con identificador 1621 es decir, etiqueta CONFIRMED
# Cargando objeto K07427.01 con identificador 1622 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03933.01 con identificador 1623 es decir, etiqueta CONFIRMED
# Cargando objeto K02796.01 con identificador 1624 es decir, etiqueta CONFIRMED
# Cargando objeto K01972.01 con identificador 1625 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07430.01 con identificador 1626 es decir, etiqueta CONFIRMED
# Cargando objeto K04622.02 con identificador 1627 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07432.01 con identificador 1628 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07434.01 con identificador 1629 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07435.01 con identificador 1630 es decir, etiqueta CONFIRMED
# Cargando objeto K04716.01 con identificador 1631 es decir, etiqueta CONFIRMED
# Cargando objeto K08047.01 con identificador 1632 es decir, etiqueta CONFIRMED
# Cargando objeto K08048.01 con identificador 1633 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07437.01 con identificador 1634 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01857.01 con identificador 1635 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04666.01 con identificador 1636 es decir, etiqueta CONFIRMED
# Cargando objeto K01649.01 con identificador 1637 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04735.01 con identificador 1638 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04509.01 con identificador 1639 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08050.01 con identificador 1640 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04464.01 con identificador 1641 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08052.01 con identificador 1642 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02163.03 con identificador 1643 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02422.02 con identificador 1644 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02551.01 con identificador 1645 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02639.01 con identificador 1646 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08053.01 con identificador 1647 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00349.01 con identificador 1648 es decir, etiqueta CONFIRMED
# Cargando objeto K00350.01 con identificador 1649 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04823.01 con identificador 1650 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05895.01 con identificador 1651 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07445.01 con identificador 1652 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00351.07 con identificador 1653 es decir, etiqueta CONFIRMED
# Cargando objeto K08054.01 con identificador 1654 es decir, etiqueta CONFIRMED
# Cargando objeto K08223.01 con identificador 1655 es decir, etiqueta CONFIRMED
# Cargando objeto K08055.01 con identificador 1656 es decir, etiqueta CONFIRMED
# Cargando objeto K07446.01 con identificador 1657 es decir, etiqueta CONFIRMED
# Cargando objeto K05901.01 con identificador 1658 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02124.01 con identificador 1659 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04150.01 con identificador 1660 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02620.01 con identificador 1661 es decir, etiqueta CONFIRMED
# Cargando objeto K04586.01 con identificador 1662 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04748.01 con identificador 1663 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03104.01 con identificador 1664 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05909.01 con identificador 1665 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02226.01 con identificador 1666 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01781.03 con identificador 1667 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03013.01 con identificador 1668 es decir, etiqueta CONFIRMED
# Cargando objeto K00353.01 con identificador 1669 es decir, etiqueta CONFIRMED
# Cargando objeto K00353.02 con identificador 1670 es decir, etiqueta CONFIRMED
# Cargando objeto K00353.03 con identificador 1671 es decir, etiqueta CONFIRMED
# Cargando objeto K02361.01 con identificador 1672 es decir, etiqueta CONFIRMED
# Cargando objeto K00354.02 con identificador 1673 es decir, etiqueta CONFIRMED
# Cargando objeto K01856.01 con identificador 1674 es decir, etiqueta CONFIRMED
# Cargando objeto K01437.01 con identificador 1675 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05917.01 con identificador 1676 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01831.03 con identificador 1677 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01831.04 con identificador 1678 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07460.01 con identificador 1679 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04792.01 con identificador 1680 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03022.01 con identificador 1681 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03022.02 con identificador 1682 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02550.01 con identificador 1683 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04643.01 con identificador 1684 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03370.01 con identificador 1685 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04771.01 con identificador 1686 es decir, etiqueta CONFIRMED
# Cargando objeto K07471.01 con identificador 1687 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05928.01 con identificador 1688 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02199.01 con identificador 1689 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02199.02 con identificador 1690 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08061.01 con identificador 1691 es decir, etiqueta CONFIRMED
# Cargando objeto K08063.01 con identificador 1692 es decir, etiqueta CONFIRMED
# Cargando objeto K05929.01 con identificador 1693 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02310.01 con identificador 1694 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04444.01 con identificador 1695 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00253.01 con identificador 1696 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00253.02 con identificador 1697 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03403.02 con identificador 1698 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02626.01 con identificador 1699 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04551.01 con identificador 1700 es decir, etiqueta CONFIRMED
# Cargando objeto K02582.01 con identificador 1701 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01906.01 con identificador 1702 es decir, etiqueta CONFIRMED
# Cargando objeto K07479.01 con identificador 1703 es decir, etiqueta CONFIRMED
# Cargando objeto K05932.01 con identificador 1704 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00436.01 con identificador 1705 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03344.01 con identificador 1706 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03344.03 con identificador 1707 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02467.01 con identificador 1708 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00777.01 con identificador 1709 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02581.01 con identificador 1710 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01728.01 con identificador 1711 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01494.01 con identificador 1712 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00247.01 con identificador 1713 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03263.01 con identificador 1714 es decir, etiqueta CONFIRMED
# Cargando objeto K01833.02 con identificador 1715 es decir, etiqueta CONFIRMED
# Cargando objeto K06246.01 con identificador 1716 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00120.01 con identificador 1717 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01510.01 con identificador 1718 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08232.01 con identificador 1719 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02779.01 con identificador 1720 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07489.01 con identificador 1721 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01764.01 con identificador 1722 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08068.01 con identificador 1723 es decir, etiqueta CONFIRMED
# Cargando objeto K03312.01 con identificador 1724 es decir, etiqueta CONFIRMED
# Cargando objeto K03875.01 con identificador 1725 es decir, etiqueta CONFIRMED
# Cargando objeto K00780.02 con identificador 1726 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03408.01 con identificador 1727 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05943.01 con identificador 1728 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04021.01 con identificador 1729 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04021.02 con identificador 1730 es decir, etiqueta CONFIRMED
# Cargando objeto K02433.03 con identificador 1731 es decir, etiqueta CONFIRMED
# Cargando objeto K02433.04 con identificador 1732 es decir, etiqueta CONFIRMED
# Cargando objeto K04011.01 con identificador 1733 es decir, etiqueta CONFIRMED
# Cargando objeto K04893.01 con identificador 1734 es decir, etiqueta CONFIRMED
# Cargando objeto K04129.01 con identificador 1735 es decir, etiqueta CONFIRMED
# Cargando objeto K03194.01 con identificador 1736 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07506.01 con identificador 1737 es decir, etiqueta CONFIRMED
# Cargando objeto K02590.02 con identificador 1738 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02106.01 con identificador 1739 es decir, etiqueta CONFIRMED
# Cargando objeto K03522.01 con identificador 1740 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02061.02 con identificador 1741 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07510.01 con identificador 1742 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04914.01 con identificador 1743 es decir, etiqueta CONFIRMED
# Cargando objeto K03017.01 con identificador 1744 es decir, etiqueta CONFIRMED
# Cargando objeto K00141.01 con identificador 1745 es decir, etiqueta CONFIRMED
# Cargando objeto K04457.01 con identificador 1746 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00547.03 con identificador 1747 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02597.03 con identificador 1748 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01458.01 con identificador 1749 es decir, etiqueta CONFIRMED
# Cargando objeto K02290.01 con identificador 1750 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02004.03 con identificador 1751 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02588.01 con identificador 1752 es decir, etiqueta CONFIRMED
# Cargando objeto K08076.01 con identificador 1753 es decir, etiqueta CONFIRMED
# Cargando objeto K03105.01 con identificador 1754 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04590.01 con identificador 1755 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02449.01 con identificador 1756 es decir, etiqueta CONFIRMED
# Cargando objeto K02449.02 con identificador 1757 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K01947.01 con identificador 1758 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03310.01 con identificador 1759 es decir, etiqueta CONFIRMED
# Cargando objeto K02264.02 con identificador 1760 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02577.01 con identificador 1761 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04595.01 con identificador 1762 es decir, etiqueta CONFIRMED
# Cargando objeto K08077.01 con identificador 1763 es decir, etiqueta CONFIRMED
# Cargando objeto K01522.02 con identificador 1764 es decir, etiqueta CONFIRMED
# Cargando objeto K05964.01 con identificador 1765 es decir, etiqueta CONFIRMED
# Cargando objeto K02059.02 con identificador 1766 es decir, etiqueta CONFIRMED
# Cargando objeto K07520.01 con identificador 1767 es decir, etiqueta CONFIRMED
# Cargando objeto K08078.01 con identificador 1768 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05965.01 con identificador 1769 es decir, etiqueta CONFIRMED
# Cargando objeto K03094.01 con identificador 1770 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00787.03 con identificador 1771 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K06250.01 con identificador 1772 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04829.01 con identificador 1773 es decir, etiqueta CONFIRMED
# Cargando objeto K01476.01 con identificador 1774 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03091.01 con identificador 1775 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K03091.02 con identificador 1776 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04895.01 con identificador 1777 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00622.01 con identificador 1778 es decir, etiqueta CONFIRMED
# Cargando objeto K04329.01 con identificador 1779 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04605.01 con identificador 1780 es decir, etiqueta CONFIRMED
# Cargando objeto K02543.01 con identificador 1781 es decir, etiqueta CONFIRMED
# Cargando objeto K02154.01 con identificador 1782 es decir, etiqueta CONFIRMED
# Cargando objeto K02353.01 con identificador 1783 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K05974.01 con identificador 1784 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08238.01 con identificador 1785 es decir, etiqueta CONFIRMED
# Cargando objeto K04714.01 con identificador 1786 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K07540.01 con identificador 1787 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00548.02 con identificador 1788 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02853.01 con identificador 1789 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K08082.01 con identificador 1790 es decir, etiqueta CONFIRMED
# Cargando objeto K04497.01 con identificador 1791 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04530.01 con identificador 1792 es decir, etiqueta CONFIRMED
# Cargando objeto K08241.01 con identificador 1793 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K04245.01 con identificador 1794 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K00298.02 con identificador 1795 es decir, etiqueta FALSE POSITIVE
# Cargando objeto K02184.02 con identificador 1796 es decir, etiqueta CONFIRMED

# %%
#all_kois=np.concatenate([np.asarray(kois_fp),np.asarray(kois_con)])
x_train=np.expand_dims(np.asarray(x_train), axis=-1)
x_val=np.expand_dims(np.asarray(x_val), axis=-1)
x_test=np.expand_dims(np.asarray(x_test), axis=-1)

print ("Objetos de entrenamiento:",x_train.shape)
print ("Objetos de validación:",x_val.shape)
print ("Objetos de testing:",x_test.shape)
# Out:
# Objetos de entrenamiento: (8383, 15, 15, 1)
# Objetos de validación: (2797, 15, 15, 1)
# Objetos de testing: (3594, 15, 15, 1)

# %%
class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)#{0: 3.,   1: 6.,   2: 5.,  3: 3.}
print (class_weights)
# Out:
# [0.86762575 1.18003941]

# %%
hist=model.fit(x_train, y_train, batch_size=64, epochs=50, verbose=1, class_weight=class_weights, validation_data=(x_val,y_val))
plt.plot(hist.history['loss'],label="train_loss")
plt.plot(hist.history['val_loss'],label="val_loss")
plt.title("Model Loss BCE CNN") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend
# Epoch 42/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.4269 - acc: 0.7513 - val_loss: 0.6749 - val_acc: 0.6839
# Epoch 43/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.4163 - acc: 0.7574 - val_loss: 0.7100 - val_acc: 0.6389
# Epoch 44/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.4193 - acc: 0.7608 - val_loss: 0.6970 - val_acc: 0.6782
# Epoch 45/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.4155 - acc: 0.7547 - val_loss: 0.7028 - val_acc: 0.6839
# Epoch 46/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.4051 - acc: 0.7637 - val_loss: 0.7576 - val_acc: 0.6864
# Epoch 47/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.4228 - acc: 0.7556 - val_loss: 0.6643 - val_acc: 0.6789
# Epoch 48/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.4042 - acc: 0.7671 - val_loss: 0.7154 - val_acc: 0.6793
# Epoch 49/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.4026 - acc: 0.7662 - val_loss: 0.7019 - val_acc: 0.6671
# Epoch 50/50
# 8383/8383 [==============================] - 20s 2ms/step - loss: 0.3987 - acc: 0.7664 - val_loss: 0.7551 - val_acc: 0.6686

# %%
predichos=model.predict_classes(x_val)
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 50 epochs CNN + reverse LC'))
# Out:
#                 Precision raw  Recall raw    F1 raw  F1 weighted  F1 macro  \
# False Positive       0.768414    0.688864  0.726468     0.673431   0.65303
# Confirmed            0.534728    0.632673  0.579592     0.673431   0.65303
#
#                 F1 micro
# False Positive  0.668573
# Confirmed       0.668573
# {'Precision raw': array([0.76841448, 0.53472803]), 'Recall raw': array([0.68886402, 0.63267327]), 'F1 raw': array([0.72646798, 0.57959184]), 'F1 weighted': 0.6734308343520711, 'F1 macro': 0.6530299106954673, 'F1 micro': 0.6685734715766893, 'Confusion Matrix': array([[1231,  556],
#        [ 371,  639]])}

# %%
hist1=model1.fit(x_train, y_train, batch_size=64, epochs=50, verbose=1, class_weight=class_weights, validation_data=(x_val,y_val))
plt.plot(hist1.history['loss'],label="train_loss")
plt.plot(hist1.history['val_loss'],label="val_loss")
plt.title("Model Loss BCE CNN1") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist1.history['acc'],label="Train accuracy" )
plt.plot(hist1.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy BCE CNN1") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()
# Out:
# Train on 8383 samples, validate on 2797 samples
# Epoch 1/50
# 8383/8383 [==============================] - 3s 397us/step - loss: 0.5723 - acc: 0.6442 - val_loss: 0.6115 - val_acc: 0.5438
# Epoch 2/50
# 8383/8383 [==============================] - 3s 318us/step - loss: 0.5614 - acc: 0.6591 - val_loss: 0.6218 - val_acc: 0.5427
# Epoch 3/50
# Epoch 44/50
# 8383/8383 [==============================] - 2s 278us/step - loss: 0.4246 - acc: 0.7587 - val_loss: 0.6754 - val_acc: 0.6464
# Epoch 45/50
# 8383/8383 [==============================] - 2s 282us/step - loss: 0.4216 - acc: 0.7640 - val_loss: 0.6610 - val_acc: 0.6407
# Epoch 46/50
# 8383/8383 [==============================] - 2s 283us/step - loss: 0.4136 - acc: 0.7681 - val_loss: 0.6748 - val_acc: 0.6325
# Epoch 47/50
# 8383/8383 [==============================] - 2s 285us/step - loss: 0.4146 - acc: 0.7680 - val_loss: 0.6674 - val_acc: 0.6332
# Epoch 48/50
# 8383/8383 [==============================] - 2s 285us/step - loss: 0.4023 - acc: 0.7735 - val_loss: 0.7953 - val_acc: 0.6239
# Epoch 49/50
# 8383/8383 [==============================] - 2s 282us/step - loss: 0.4064 - acc: 0.7708 - val_loss: 0.6964 - val_acc: 0.6425
# Epoch 50/50
# 8383/8383 [==============================] - 2s 286us/step - loss: 0.3987 - acc: 0.7748 - val_loss: 0.7220 - val_acc: 0.6482

# %%
predichos=model1.predict_classes(x_val)
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 50 epochs CNN 1 + Reverse LC'))
# Out:
#                 Precision raw  Recall raw    F1 raw  F1 weighted  F1 macro  \
# False Positive       0.787402    0.615557  0.690955     0.655114  0.641328
# Confirmed            0.509286    0.705941  0.591701     0.655114  0.641328
#
#                 F1 micro
# False Positive  0.648194
# Confirmed       0.648194
# {'Precision raw': array([0.78740157, 0.50928571]), 'Recall raw': array([0.6155568 , 0.70594059]), 'F1 raw': array([0.69095477, 0.59170124]), 'F1 weighted': 0.6551142074243596, 'F1 macro': 0.6413280093413124, 'F1 micro': 0.6481944941008223, 'Confusion Matrix': array([[1100,  687],
#        [ 297,  713]])}

# %%
def focal_loss(gamma=2., weights=1):   #weights np.asarray()
    weights= K.variable(weights)
    def focal_loss_fixed(y_true, y_pred):
        y_true = K.clip(y_true, K.epsilon(),1)
        y_pred = K.clip(y_pred,K.epsilon(),1)
        return - K.sum(weights* K.pow(1. - y_pred, gamma)* y_true * K.log(y_pred), axis=-1) 
    return focal_loss_fixed

# %%
model2 = Sequential()
model2.add(Conv2D(64, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model2.add(MaxPooling2D((2,2)))
model2.add(Dropout(0.1))
model2.add(Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"))
model2.add(Conv2D(256, (3, 3), strides=(1, 1), activation="relu", padding="same"))
#model1.add(Flatten())
model2.add(GlobalAveragePooling2D())
model2.add(Dense(256,activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(128, activation='relu'))
model2.add(Dense(2, activation='softmax'))
model2.summary()

model2.compile(loss=focal_loss(2,weights=class_weights),optimizer='adam',metrics=['acc'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 15, 15, 64)        640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 468,610
# Trainable params: 468,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train_cat=to_categorical(y_train, 2)
y_train_cat[:3]
y_val_cat=to_categorical(y_val, 2)
y_val_cat[:3]
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [1., 0.]], dtype=float32)

# %%
hist2=model2.fit(x_train, y_train_cat, batch_size=64, epochs=50, verbose=1, class_weight=class_weights, validation_data=(x_val,y_val_cat))
plt.plot(hist2.history['loss'],label="train_loss")
plt.plot(hist2.history['val_loss'],label="val_loss")
plt.title("Model Loss Focal CNN1 + Reverse LC") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist2.history['acc'],label="Train accuracy" )
plt.plot(hist2.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy Focal CNN1 + Reverse LC") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()
# Out:
# Train on 8383 samples, validate on 2797 samples
# Epoch 1/50
# 8383/8383 [==============================] - 3s 380us/step - loss: 0.1458 - acc: 0.6523 - val_loss: 0.1557 - val_acc: 0.5388
# Epoch 2/50
# 8383/8383 [==============================] - 2s 298us/step - loss: 0.1450 - acc: 0.6487 - val_loss: 0.1665 - val_acc: 0.5080
# Epoch 3/50
# 8383/8383 [==============================] - 2s 292us/step - loss: 0.1429 - acc: 0.6526 - val_loss: 0.1576 - val_acc: 0.5463
# Epoch 4/50
# 8383/8383 [==============================] - 2s 288us/step - loss: 0.1414 - acc: 0.6598 - val_loss: 0.1601 - val_acc: 0.5223
# Epoch 5/50
# 8383/8383 [==============================] - 2s 287us/step - loss: 0.1410 - acc: 0.6595 - val_loss: 0.1550 - val_acc: 0.5509
# Epoch 6/50
# 8383/8383 [==============================] - 2s 289us/step - loss: 0.1407 - acc: 0.6603 - val_loss: 0.1538 - val_acc: 0.5424
# Epoch 7/50
# 8383/8383 [==============================] - 2s 291us/step - loss: 0.1397 - acc: 0.6650 - val_loss: 0.1601 - val_acc: 0.5184
# Epoch 8/50
# 8383/8383 [==============================] - 2s 294us/step - loss: 0.1388 - acc: 0.6711 - val_loss: 0.1522 - val_acc: 0.5692
# Epoch 9/50
# 8383/8383 [==============================] - 2s 288us/step - loss: 0.1386 - acc: 0.6722 - val_loss: 0.1482 - val_acc: 0.5810
# Epoch 10/50
# 8383/8383 [==============================] - 2s 286us/step - loss: 0.1383 - acc: 0.6755 - val_loss: 0.1555 - val_acc: 0.5409
# Epoch 11/50
# 8383/8383 [==============================] - 2s 289us/step - loss: 0.1363 - acc: 0.6815 - val_loss: 0.1517 - val_acc: 0.5610
# Epoch 12/50
# 8383/8383 [==============================] - 2s 290us/step - loss: 0.1360 - acc: 0.6834 - val_loss: 0.1550 - val_acc: 0.5463
# Epoch 13/50
# 8383/8383 [==============================] - 2s 288us/step - loss: 0.1357 - acc: 0.6862 - val_loss: 0.1524 - val_acc: 0.5592
# Epoch 14/50
# {'Precision raw': array([0.84903519, 0.45772443]), 'Recall raw': array([0.41857862, 0.86831683]), 'F1 raw': array([0.56071964, 0.59945318]), 'F1 weighted': 0.574706366530587, 'F1 macro': 0.5800864092902285, 'F1 micro': 0.5809796210225241, 'Confusion Matrix': array([[ 748, 1039],
#        [ 133,  877]])}

# %% [markdown]
# # Segundo Modelo

# %%
model3 = Sequential()
model3.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model3.add(Dropout(0.25))
model3.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model3.add(Dropout(0.15))
model3.add(GlobalAveragePooling2D())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.25))
model3.add(Dense(128,activation='relu'))
model3.add(Dense(1, activation='sigmoid'))
model3.summary()

model3.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 15, 15, 32)        320
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 15, 32)        9248
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 32)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               8448
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 51,041
# Trainable params: 51,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4 = Sequential()
model4.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model4.add(Dropout(0.2))
model4.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model4.add(Dropout(0.1))
model4.add(GlobalAveragePooling2D())
model4.add(Dense(256, activation='relu'))
model4.add(Dropout(0.2))
model4.add(Dense(128, activation='relu'))
model4.add(Dense(2, activation='softmax'))
model4.summary()
model4.compile(loss=focal_loss(2,weights=class_weights),optimizer='adam',metrics=['acc'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 15, 15, 32)        320
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 15, 15, 32)        9248
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               8448
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 51,170
# Trainable params: 51,170
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist3=model3.fit(x_train, y_train, batch_size=64, epochs=100, verbose=1, class_weight=class_weights, validation_data=(x_val,y_val))
plt.plot(hist3.history['loss'],label="train_loss")
plt.plot(hist3.history['val_loss'],label="val_loss")
plt.title("Model Loss BCE CNN 3 + Reverse LC") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist3.history['acc'],label="Train accuracy" )
plt.plot(hist3.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy BCE CNN 3 + Reverse LC") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend
# Confirmed            0.559091    0.608911  0.582938     0.688023  0.665178
#
#                 F1 micro
# False Positive  0.685377
# Confirmed       0.685377
# {'Precision raw': array([0.7672363 , 0.55909091]), 'Recall raw': array([0.72859541, 0.60891089]), 'F1 raw': array([0.74741676, 0.58293839]), 'F1 weighted': 0.6880234275356611, 'F1 macro': 0.6651775754838638, 'F1 micro': 0.6853771898462638, 'Confusion Matrix': array([[1302,  485],
#        [ 395,  615]])}

# %%
hist4=model4.fit(x_train, y_train_cat, batch_size=64, epochs=100, verbose=1, class_weight=class_weights, validation_data=(x_val,y_val_cat))
plt.plot(hist4.history['loss'],label="train_loss")
plt.plot(hist4.history['val_loss'],label="val_loss")
plt.title("Model Loss Focal CNN4 + Reverse LC") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist4.history['acc'],label="Train accuracy" )
plt.plot(hist4.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy Focal CNN4 + Reverse LC") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

predichos=model4.predict_classes(x_val)
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 50 epochs CNN 1 Focal + Reverse LC'))
# Out:
# Train on 8383 samples, validate on 2797 samples
# Epoch 1/100
# 8383/8383 [==============================] - 2s 284us/step - loss: 0.1482 - acc: 0.6480 - val_loss: 0.1574 - val_acc: 0.5341
# Epoch 2/100
# 8383/8383 [==============================] - 2s 218us/step - loss: 0.1425 - acc: 0.6547 - val_loss: 0.1566 - val_acc: 0.5574
# Epoch 3/100
# 8383/8383 [==============================] - 2s 199us/step - loss: 0.1423 - acc: 0.6557 - val_loss: 0.1572 - val_acc: 0.5227
# Epoch 4/100
# 8383/8383 [==============================] - 2s 181us/step - loss: 0.1417 - acc: 0.6526 - val_loss: 0.1543 - val_acc: 0.5467
# Epoch 5/100
# 8383/8383 [==============================] - 1s 179us/step - loss: 0.1414 - acc: 0.6568 - val_loss: 0.1537 - val_acc: 0.5420
# Epoch 6/100
# 8383/8383 [==============================] - 2s 180us/step - loss: 0.1414 - acc: 0.6567 - val_loss: 0.1581 - val_acc: 0.5341
# Epoch 7/100
# 8383/8383 [==============================] - 2s 180us/step - loss: 0.1409 - acc: 0.6621 - val_loss: 0.1572 - val_acc: 0.5313
# Epoch 8/100
# 8383/8383 [==============================] - 2s 179us/step - loss: 0.1404 - acc: 0.6570 - val_loss: 0.1562 - val_acc: 0.5438
# Epoch 9/100
# 8383/8383 [==============================] - 1s 176us/step - loss: 0.1405 - acc: 0.6605 - val_loss: 0.1544 - val_acc: 0.5484
# Epoch 10/100
# 8383/8383 [==============================] - 1s 175us/step - loss: 0.1405 - acc: 0.6593 - val_loss: 0.1612 - val_acc: 0.5173
# Epoch 11/100
# 8383/8383 [==============================] - 1s 175us/step - loss: 0.1404 - acc: 0.6594 - val_loss: 0.1555 - val_acc: 0.5356
# Epoch 12/100
# 8383/8383 [==============================] - 1s 175us/step - loss: 0.1398 - acc: 0.6609 - val_loss: 0.1549 - val_acc: 0.5306
# Epoch 13/100
# Epoch 94/100
# 8383/8383 [==============================] - 2s 208us/step - loss: 0.1286 - acc: 0.7049 - val_loss: 0.1485 - val_acc: 0.5863
# Epoch 95/100
# 8383/8383 [==============================] - 2s 211us/step - loss: 0.1292 - acc: 0.7063 - val_loss: 0.1528 - val_acc: 0.5692
# Epoch 96/100
# 8383/8383 [==============================] - 2s 210us/step - loss: 0.1283 - acc: 0.7051 - val_loss: 0.1511 - val_acc: 0.5763
# Epoch 97/100
# 8383/8383 [==============================] - 2s 211us/step - loss: 0.1282 - acc: 0.7037 - val_loss: 0.1496 - val_acc: 0.5867
# Epoch 98/100
# 8383/8383 [==============================] - 2s 209us/step - loss: 0.1290 - acc: 0.7025 - val_loss: 0.1476 - val_acc: 0.5846
# Epoch 99/100
# 8383/8383 [==============================] - 2s 203us/step - loss: 0.1283 - acc: 0.7026 - val_loss: 0.1508 - val_acc: 0.5971
# Epoch 100/100
# 8383/8383 [==============================] - 2s 201us/step - loss: 0.1284 - acc: 0.7046 - val_loss: 0.1486 - val_acc: 0.5913
#                 Precision raw  Recall raw    F1 raw  F1 weighted  F1 macro  \
# False Positive       0.869266    0.424175  0.570139     0.584736  0.590351
# Confirmed            0.465455    0.887129  0.610562     0.584736  0.590351
#
#                 F1 micro
# False Positive  0.591348
# Confirmed       0.591348
# {'Precision raw': array([0.86926606, 0.46545455]), 'Recall raw': array([0.42417459, 0.88712871]), 'F1 raw': array([0.57013915, 0.61056218]), 'F1 weighted': 0.5847359540707248, 'F1 macro': 0.5903506653178143, 'F1 micro': 0.5913478727207723, 'Confusion Matrix': array([[ 758, 1029],
#        [ 114,  896]])}

# %%
#mini-batches ?
hist3=model3.fit(x_train, y_train, batch_size=256 , epochs=50, verbose=1, class_weight=class_weights, validation_data=(x_val,y_val))
plt.plot(hist3.history['loss'],label="train_loss")
plt.plot(hist3.history['val_loss'],label="val_loss")
plt.title("Model Loss BCE CNN  + Reverse LC") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist3.history['acc'],label="Train accuracy" )
plt.plot(hist3.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy BCE CNN  + Reverse LC") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

predichos=model3.predict_classes(x_val)
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 50 epochs CNN BCE + Reverse LC'))
# Out:
# Train on 8383 samples, validate on 2797 samples
# Epoch 1/50
# 8383/8383 [==============================] - 1s 126us/step - loss: 0.5063 - acc: 0.7063 - val_loss: 0.5849 - val_acc: 0.6757
# Epoch 2/50
# 8383/8383 [==============================] - 1s 116us/step - loss: 0.5024 - acc: 0.7137 - val_loss: 0.5810 - val_acc: 0.6857
# Epoch 3/50
# 8383/8383 [==============================] - 1s 118us/step - loss: 0.5038 - acc: 0.7114 - val_loss: 0.5781 - val_acc: 0.6897
# Epoch 4/50
# 8383/8383 [==============================] - 1s 115us/step - loss: 0.5061 - acc: 0.7113 - val_loss: 0.5775 - val_acc: 0.6915
# 8383/8383 [==============================] - 1s 113us/step - loss: 0.5026 - acc: 0.7148 - val_loss: 0.5793 - val_acc: 0.6904
# Epoch 46/50
# 8383/8383 [==============================] - 1s 112us/step - loss: 0.5036 - acc: 0.7136 - val_loss: 0.5867 - val_acc: 0.6864
# Epoch 47/50
# 8383/8383 [==============================] - 1s 109us/step - loss: 0.5014 - acc: 0.7108 - val_loss: 0.5819 - val_acc: 0.6893
# Epoch 48/50
# 8383/8383 [==============================] - 1s 111us/step - loss: 0.5025 - acc: 0.7107 - val_loss: 0.5794 - val_acc: 0.6982
# Epoch 49/50
# 8383/8383 [==============================] - 1s 111us/step - loss: 0.5024 - acc: 0.7108 - val_loss: 0.5931 - val_acc: 0.6761
# Epoch 50/50
# 8383/8383 [==============================] - 1s 112us/step - loss: 0.5003 - acc: 0.7136 - val_loss: 0.6011 - val_acc: 0.6686
#                 Precision raw  Recall raw    F1 raw  F1 weighted  F1 macro  \
# False Positive       0.778859    0.672076  0.721538     0.674303  0.656133
# Confirmed            0.533068    0.662376  0.590728     0.674303  0.656133
#
#                 F1 micro
# False Positive  0.668573
# Confirmed       0.668573
# {'Precision raw': array([0.77885863, 0.53306773]), 'Recall raw': array([0.67207611, 0.66237624]), 'F1 raw': array([0.721538  , 0.59072848]), 'F1 weighted': 0.6743025264625702, 'F1 macro': 0.6561332381102056, 'F1 micro': 0.6685734715766893, 'Confusion Matrix': array([[1201,  586],
#        [ 341,  669]])}

# %%
predichos=model3.predict_classes(x_train)
print (calculate_metrics(y_train,predichos,'[TRAIN] Confusion Matrix 50 epochs CNN BCE + Reverse LC'))
# Out:
#                 Precision raw  Recall raw    F1 raw  F1 weighted  F1 macro  \
# False Positive       0.755663    0.745808  0.750703     0.714859  0.708406
# Confirmed            0.660304    0.672016  0.666109     0.714859  0.708406
#
#                 F1 micro
# False Positive  0.714541
# Confirmed       0.714541
# {'Precision raw': array([0.75566275, 0.66030429]), 'Recall raw': array([0.74580832, 0.67201577]), 'F1 raw': array([0.7507032 , 0.66610855]), 'F1 weighted': 0.7148592068856634, 'F1 macro': 0.7084058756701858, 'F1 micro': 0.7145413336514375, 'Confusion Matrix': array([[3603, 1228],
#        [1165, 2387]])}

# %% [markdown]
# ## modificar completamente los modelos!

# %%
model5 = Sequential()
model5.add(Conv2D(16, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model5.add(BatchNormalization())
model5.add(Conv2D(16, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model5.add(BatchNormalization())
model5.add(MaxPooling2D((2,2)))
model5.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model5.add(BatchNormalization())
model5.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model5.add(BatchNormalization())
model5.add(GlobalAveragePooling2D())
model5.add(Dropout(0.25))
model5.add(Dense(128, activation='relu'))
model5.add(Dropout(0.25))
model5.add(Dense(2, activation='softmax'))
model5.summary()
model5.compile(loss=focal_loss(2,weights=class_weights),optimizer='adam',metrics=['acc'])
# Out:
# W0719 03:48:41.826738 140316414314304 deprecation_wrapper.py:119] From /users/mbugueno/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 15, 15, 16)        160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 16)        64
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 15, 15, 16)        2320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 16)        64
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 7, 7, 32)          4640
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 7, 7, 32)          9248
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 32)                0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               4224
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 21,234
# Trainable params: 21,042
# Non-trainable params: 192
# _________________________________________________________________

# %%
hist5=model5.fit(x_train, y_train_cat, batch_size=256, epochs=50, verbose=1, class_weight=class_weights, validation_data=(x_val,y_val_cat))
plt.plot(hist5.history['loss'],label="train_loss")
plt.plot(hist5.history['val_loss'],label="val_loss")
plt.title("Model Loss BCE CNN 3") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()
plt.plot(hist5.history['acc'],label="Train accuracy" )
plt.plot(hist5.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy BCE CNN 3") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()
predichos=model5.predict_classes(x_val)
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 100 epochs CNN 5 BCE'))
# Out:
# Train on 8383 samples, validate on 2797 samples
# Epoch 1/50
# 8383/8383 [==============================] - 2s 207us/step - loss: 0.1468 - acc: 0.6400 - val_loss: 0.5826 - val_acc: 0.6257
# Epoch 2/50
# 8383/8383 [==============================] - 2s 198us/step - loss: 0.1408 - acc: 0.6653 - val_loss: 0.4107 - val_acc: 0.5638
# Epoch 3/50
# 8383/8383 [==============================] - 2s 197us/step - loss: 0.1372 - acc: 0.6786 - val_loss: 0.1736 - val_acc: 0.6282
# Epoch 4/50
# 8383/8383 [==============================] - 2s 197us/step - loss: 0.1355 - acc: 0.6827 - val_loss: 0.1637 - val_acc: 0.5692
# Epoch 5/50
# 8383/8383 [==============================] - 2s 196us/step - loss: 0.1344 - acc: 0.6883 - val_loss: 0.1523 - val_acc: 0.5856
# Epoch 6/50
# 8383/8383 [==============================] - 2s 196us/step - loss: 0.1315 - acc: 0.6965 - val_loss: 0.1561 - val_acc: 0.5810
# Epoch 7/50
# 8383/8383 [==============================] - 2s 200us/step - loss: 0.1296 - acc: 0.6972 - val_loss: 0.1600 - val_acc: 0.5345
# Epoch 8/50
# 8383/8383 [==============================] - 2s 197us/step - loss: 0.1287 - acc: 0.7003 - val_loss: 0.1675 - val_acc: 0.5206
# Epoch 9/50
# 8383/8383 [==============================] - 2s 195us/step - loss: 0.1261 - acc: 0.7052 - val_loss: 0.1676 - val_acc: 0.5059
# Epoch 10/50
# 8383/8383 [==============================] - 2s 194us/step - loss: 0.1234 - acc: 0.7144 - val_loss: 0.1911 - val_acc: 0.5581
# Epoch 11/50
# Confirmed            0.477612    0.570297  0.519856     0.625379  0.602438
#
#                 F1 micro
# False Positive  0.619592
# Confirmed       0.619592
# {'Precision raw': array([0.72721559, 0.47761194]), 'Recall raw': array([0.64745383, 0.57029703]), 'F1 raw': array([0.68502072, 0.5198556 ]), 'F1 weighted': 0.6253794002188048, 'F1 macro': 0.602438158994385, 'F1 micro': 0.6195924204504827, 'Confusion Matrix': array([[1157,  630],
#        [ 434,  576]])}

# %%
model6 = Sequential()
model6.add(Conv2D(16, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model6.add(BatchNormalization())
model6.add(Conv2D(16, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model6.add(BatchNormalization())
model6.add(MaxPooling2D((2,2)))

model6.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model6.add(BatchNormalization())
model6.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model6.add(BatchNormalization())

model6.add(GlobalAveragePooling2D())
model6.add(Dense(128, activation='relu'))
model6.add(BatchNormalization())
model6.add(Dropout(0.2))
model6.add(Dense(2, activation='softmax'))
model6.summary()
model6.compile(loss=focal_loss(2,weights=class_weights),optimizer='adam',metrics=['acc'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 15, 15, 16)        160
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 15, 15, 16)        64
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 15, 15, 16)        2320
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 15, 15, 16)        64
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 7, 7, 32)          4640
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 7, 7, 32)          9248
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# global_average_pooling2d_14  (None, 32)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               4224
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 21,746
# Trainable params: 21,298
# Non-trainable params: 448
# _________________________________________________________________

# %%
hist6=model6.fit(x_train, y_train_cat, batch_size=128, epochs=100, verbose=0, class_weight=class_weights, validation_data=(x_val,y_val_cat))
plt.plot(hist6.history['loss'],label="train_loss")
plt.plot(hist6.history['val_loss'],label="val_loss")
plt.title("Model Loss Focal CNN 6") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist6.history['acc'],label="Train accuracy" )
plt.plot(hist6.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy Focal CNN 6") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

predichos=model6.predict_classes(x_val)
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 100 epochs CNN 6 Focal'))
# Out:
#                 F1 macro  F1 micro    F1 raw  F1 weighted  Precision raw  \
# False Positive  0.585637  0.611502  0.689162      0.62235       0.752232
# Confirmed       0.585637  0.611502  0.482112      0.62235       0.423019
#
#                 Recall raw
# False Positive    0.635849
# Confirmed         0.560396
# {'F1 macro': 0.5856369951540362, 'Recall raw': array([0.63584906, 0.56039604]), 'Confusion Matrix': array([[674, 386],
#        [222, 283]]), 'Precision raw': array([0.75223214, 0.42301943]), 'F1 weighted': 0.6223501774327563, 'F1 micro': 0.6115015974440895, 'F1 raw': array([0.68916155, 0.48211244])}

# %%
model7 = Sequential()
model7.add(Conv2D(16, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model7.add(Conv2D(16, (3, 3), strides=(1, 1), activation="relu", padding="same"))
model7.add(MaxPooling2D((2,2)))
model7.add(Dropout(0.25))

#model7.add(Dropout(0.15))
model7.add(Conv2D(32, (3, 3), strides=(1, 1), activation="relu", padding="same"))
model7.add(Conv2D(32, (3, 3), strides=(1, 1), activation="relu", padding="same"))
model7.add(MaxPooling2D((2,2)))
model7.add(Dropout(0.25))

model7.add(Conv2D(64, (3, 3), strides=(1, 1), activation="relu", padding="same"))
model7.add(Conv2D(64, (3, 3), strides=(1, 1), activation="relu", padding="same"))
#model7.add(MaxPooling2D((2,2)))
model7.add(Dropout(0.25))

model7.add(GlobalAveragePooling2D())
#model7.add(Dropout(0.15))
model7.add(Dense(1, activation='sigmoid'))
model7.summary()

model7.compile(loss='binary_crossentropy',optimizer='adam',metrics=['acc'])

hist7=model7.fit(x_train, y_train, batch_size=128, epochs=100, verbose=0, class_weight=class_weights, validation_data=(x_val,y_val))
plt.plot(hist7.history['loss'],label="train_loss")
plt.plot(hist7.history['val_loss'],label="val_loss")
plt.title("Model Loss BCE CNN 7") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist7.history['acc'],label="Train accuracy" )
plt.plot(hist7.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy BCE CNN 7") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

predichos=model7.predict_classes(x_val)
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 100 epochs CNN 7 BCE'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_40 (Conv2D)           (None, 15, 15, 16)        160
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 15, 15, 16)        2320
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 7, 7, 16)          0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 7, 7, 16)          0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 7, 7, 32)          4640
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 7, 7, 32)          9248
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 3, 3, 32)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 3, 3, 32)          0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 3, 3, 64)          18496
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 3, 3, 64)          36928
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 3, 3, 64)          0
# _________________________________________________________________
# global_average_pooling2d_9 ( (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 71,857
# Trainable params: 71,857
# Non-trainable params: 0
# _________________________________________________________________
#                 F1 macro  F1 micro    F1 raw  F1 weighted  Precision raw  \
# False Positive  0.630743  0.660064  0.734796     0.667643       0.779070
# Confirmed       0.630743  0.660064  0.526690     0.667643       0.478191
#
#                 Recall raw
# False Positive    0.695283
# Confirmed         0.586139
# {'F1 macro': 0.6307430023097966, 'Recall raw': array([0.69528302, 0.58613861]), 'Confusion Matrix': array([[737, 323],
#        [209, 296]]), 'Precision raw': array([0.77906977, 0.47819063]), 'F1 weighted': 0.6676434489693178, 'F1 micro': 0.6600638977635783, 'F1 raw': array([0.73479561, 0.52669039])}

# %%
model8 = Sequential()
model8.add(Conv2D(32, (3, 3), input_shape=(15,15,1), strides=(1, 1),activation="relu", padding="same"))
model8.add(Dropout(0.15))
model8.add(Conv2D(64, (3, 3), strides=(1, 1), activation="relu", padding="same"))
model8.add(Dropout(0.15))
model8.add(Conv2D(128, (3, 3), strides=(1, 1), activation="relu", padding="same"))
model8.add(GlobalAveragePooling2D())
model8.add(Dense(256,activation='relu'))
model8.add(Dropout(0.3))
model8.add(Dense(128, activation='relu'))
model8.add(Dropout(0.15))
model8.add(Dense(2, activation='softmax'))
model8.summary()

model8.compile(loss=focal_loss(2,weights=class_weights),optimizer='adam',metrics=['acc'])

hist8=model8.fit(x_train, y_train_cat, batch_size=128, epochs=150, verbose=0, class_weight=class_weights, validation_data=(x_val,y_val_cat))
plt.plot(hist8.history['loss'],label="train_loss")
plt.plot(hist8.history['val_loss'],label="val_loss")
plt.title("Model Loss Focal CNN 8") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist8.history['acc'],label="Train accuracy" )
plt.plot(hist8.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy Focal CNN 8") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

predichos=model8.predict_classes(x_val)
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 150 epochs CNN 8 Focal'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 15, 15, 32)        320
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 158,850
# Trainable params: 158,850
# Non-trainable params: 0
# _________________________________________________________________
#                 F1 macro  F1 micro    F1 raw  F1 weighted  Precision raw  \
# False Positive  0.560537  0.561022  0.575139     0.565716       0.834829
# Confirmed       0.560537  0.561022  0.545935     0.565716       0.409722
#
#                 Recall raw
# False Positive    0.438679
# Confirmed         0.817822
# {'F1 macro': 0.5605371872957559, 'Recall raw': array([0.43867925, 0.81782178]), 'Confusion Matrix': array([[465, 595],
#        [ 92, 413]]), 'Precision raw': array([0.83482944, 0.40972222]), 'F1 weighted': 0.5657155179001898, 'F1 micro': 0.5610223642172524, 'F1 raw': array([0.57513915, 0.54593523])}

# %%
x_train.shape
# Out:
# (4692, 15, 15, 1)

# %%
model9 = Sequential()
model9.add(Conv1D(32, 3, input_shape=(15,15), strides=1,activation="relu", padding="same"))
model9.add(Conv1D(32, 3, strides=1, activation="relu", padding="same"))
model9.add(MaxPooling1D(2))
model9.add(Dropout(0.25))

#model7.add(Dropout(0.15))
model9.add(Conv1D(64, 3, strides=1, activation="relu", padding="same"))
model9.add(Conv1D(64, 3, strides=1, activation="relu", padding="same"))
model9.add(MaxPooling1D(2))
model9.add(Dropout(0.25))

model9.add(Conv1D(128, 3, strides=1, activation="relu", padding="same"))
model9.add(Conv1D(128, 3, strides=1, activation="relu", padding="same"))
#model7.add(MaxPooling2D((2,2)))
model9.add(Dropout(0.25))

model9.add(GlobalAveragePooling1D())
model9.add(Dense(128,activation='relu'))
model9.add(Dropout(0.5))
model9.add(Dense(1, activation='sigmoid'))
model9.summary()

model9.compile(loss='binary_crossentropy',optimizer='adam',metrics=['acc'])

hist9=model9.fit(np.squeeze(x_train), y_train, batch_size=128, epochs=100, verbose=0, class_weight=class_weights, validation_data=(np.squeeze(x_val),y_val))
plt.plot(hist9.history['loss'],label="train_loss")
plt.plot(hist9.history['val_loss'],label="val_loss")
plt.title("Model Loss BCE CNN 7") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

plt.plot(hist9.history['acc'],label="Train accuracy" )
plt.plot(hist9.history['val_acc'],label="Val accuracy" )
plt.title("Model Accuracy BCE CNN 7") 
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()

predichos=model9.predict_classes(np.squeeze(x_val))
print (calculate_metrics(y_val,predichos,'[VAL] Confusion Matrix 100 epochs CNN 9 BCE'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_20 (Conv1D)           (None, 15, 32)            1472
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 15, 32)            3104
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 7, 32)             0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 7, 32)             0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 7, 64)             6208
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 7, 64)             12352
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 3, 64)             0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 3, 64)             0
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 3, 128)            24704
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 3, 128)            49280
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 3, 128)            0
# _________________________________________________________________
# global_average_pooling1d_3 ( (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 113,761
# Trainable params: 113,761
# Non-trainable params: 0
# _________________________________________________________________
#                 F1 macro  F1 micro    F1 raw  F1 weighted  Precision raw  \
# False Positive  0.600958  0.661981  0.757005     0.656297       0.737690
# Confirmed       0.600958  0.661981  0.444911     0.656297       0.473214
#
#                 Recall raw
# False Positive    0.777358
# Confirmed         0.419802
# {'F1 macro': 0.6009579303999024, 'Recall raw': array([0.77735849, 0.41980198]), 'Confusion Matrix': array([[824, 236],
#        [293, 212]]), 'Precision raw': array([0.73769024, 0.47321429]), 'F1 weighted': 0.6562973252535271, 'F1 micro': 0.6619808306709265, 'F1 raw': array([0.75700505, 0.44491081])}
